# %% [markdown]
# <img src="./Data/公式.png" style="zoom:50%;" />

# %% [markdown]
# # Import

# %%
pip install pyDOE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.7.3)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=30caedd6e3d2c6b2314292e4a418f862e14f74f506a99277fa0c44a24f80b7f8
#   Stored in directory: /root/.cache/pip/wheels/83/ce/8a/87b25c685bfeca1872d13b8dc101e087a9c6e3fb5ebb47022a
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
from sympy import*
import numpy as np
from pyDOE import lhs         #Latin Hypercube Sampling
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   
import tensorflow as tf
from tensorflow import keras
import time

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Setting

# %%
x = symbols('x')
y = symbols('y')
t = symbols('t')

a = v1 = v2 = k =1 #a=4 ,v1=5,v2=10,k=1/4
c1 = 1 + v1/k ;c2 = -v1/v2;c3 = c2 - c1
g1 = g2 =0

u1 = a*x*(1-x)*(1-y)*exp(-t)
u2 = a*x*(1-x)*(c1 + c2*y + c3*y**2)*exp(-t)

f1 = diff(u1,t) - v1*( diff(u1,x,2) + diff(u1,y,2))
f2 = diff(u2,t) - v2*( diff(u2,x,2) + diff(u2,y,2))

u1 = lambdify((x,y,t),u1)
u2 = lambdify((x,y,t),u2)

f1 = lambdify((x,y,t),f1,'tensorflow')
f2 = lambdify((x,y,t),f2,'tensorflow')

# %% [markdown]
# # TrainingData & TestData

# %%
def trainingdata(N_u,N_f,N_i,omga,u,interface):    
    '''
      x1 = x,  x2 = y
      interface = 0, 则x2_range[0] 作为 interface ； interfacer = 1 则 x2_range[1]作为interface
    
      Return: X_u_train (N_u x 3),u_train (N_u x 1), X_f_train (N_f x 3), X_i_train (N_i x 3)
    '''
    x1_range = omga[0]
    x2_range = omga[1]
    t_range = [0.,1.]
    
    # Initial Condition t=0 , x1_range[0]<= x1 <= x_range[1] , x2_range[0] <= x2 <= x2_range[1]
    initial_X = np.ones((N_u,3))
    initial_X[:,0] = np.random.rand(N_u) * (x1_range[1] - x1_range[0]) + x1_range[0]
    initial_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    initial_X[:,2] = initial_X[:,2] * t_range[0]
    #initial_u = np.ones((N_u,1))
    initial_u = u(initial_X[:,0], initial_X[:,1], initial_X[:,2])
    initial_u = initial_u.reshape(-1,1)


    # BC_left: x1=x1_range[0], 0<=t<=1, x2_range[0] <= x2 <= x2_range[1]
    leftedge_X = np.ones(shape=(N_u,3))
    leftedge_X[:,0] = leftedge_X[:,0] * x1_range[0]
    leftedge_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    leftedge_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    leftedge_u = np.ones(shape=(N_u,1))
    leftedge_u = u(leftedge_X[:,0], leftedge_X[:,1], leftedge_X[:,2])
    leftedge_u = leftedge_u.reshape(-1,1)
    
    # BC_right: x1=x1_range[1], 0<=t<=1, x2_range[0] <= x2 <= x2_range[1]
    rightedge_X = np.ones(shape=(N_u,3))
    rightedge_X[:,0] = rightedge_X[:,0] * x1_range[1]
    rightedge_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    rightedge_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    rightedge_u = np.ones(shape=(N_u,1))
    rightedge_u = u(rightedge_X[:,0], rightedge_X[:,1], rightedge_X[:,2])
    rightedge_u = rightedge_u.reshape(-1,1)

    # BC_top or BC_bottom ,depends on interface. x2 = x2_range[bc], 0<=t<=1 ,x1_range[0]<= x1 <= x_range[1]
    bc = (interface+1)%2
    BC_X = np.ones(shape=(N_u,3))
    BC_X[:,0] = np.random.rand(N_u) * (x1_range[1] - x1_range[0]) + x1_range[0]
    BC_X[:,1] = BC_X[:,1] * x2_range[bc]
    BC_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    BC_u = np.ones(shape=(N_u,1))
    BC_u = u(BC_X[:,0], BC_X[:,1], BC_X[:,2])
    BC_u = BC_u.reshape(-1,1)
    
    all_X_u_train =  np.vstack([initial_X,leftedge_X,rightedge_X,BC_X])
    all_u_train = np.vstack([initial_u,leftedge_u,rightedge_u,BC_u])
    
    idx = np.random.choice(all_X_u_train.shape[0],all_X_u_train.shape[0], replace=False) 
    
    X_u_train = all_X_u_train[idx,:]
    u_train = all_u_train[idx,:]
    
    # BC_interface: x2 = x2_range[interface], 0<=t<=1 ,x1_range[0]<= x1 <= x_range[1]
    X_i_train = np.ones(shape=(N_i,3))
    X_i_train[:,0] = np.random.rand(N_i) * (x1_range[1] - x1_range[0]) + x1_range[0]
    X_i_train[:,1] = X_i_train[:,1] * x2_range[interface]
    X_i_train[:,2] = np.random.rand(N_i) * (t_range[1] - t_range[0]) + t_range[0]     
            
            
    '''Collocation Points'''
    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x1,x2,t)
    lb = np.array([x1_range[0],x2_range[0],t_range[0]])
    ub = np.array([x1_range[1],x2_range[1],t_range[1]])
    X_f_train = lb + (ub-lb)*lhs(3,N_f) 
    #X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    
    return X_u_train,u_train,X_f_train,X_i_train

def ds_train_n_batch(X_u1_train,u1_train,X_f1_train,X_u2_train,u2_train,X_f2_train,X_i_train,n = 5):
    batch_u1 = int(len(X_u1_train)/n) # = int(len(u1_train)/n)
    batch_f1 = int(len(X_f1_train)/n)

    batch_u2 = int(len(X_u2_train)/n) # = int(len(u2_train)/n)
    batch_f2 = int(len(X_f2_train)/n)
    
    batch_i = int(len(X_i_train)/n)
    
    ds_u1 = tf.data.Dataset.from_tensor_slices( ((X_u1_train,u1_train)) ).batch( batch_u1 )
    ds_f1 = tf.data.Dataset.from_tensor_slices( X_f1_train ).batch( batch_f1 )
    
    ds_u2 = tf.data.Dataset.from_tensor_slices( ((X_u2_train,u2_train)) ).batch( batch_u2 )
    ds_f2 = tf.data.Dataset.from_tensor_slices( X_f2_train ).batch( batch_f2 )
    
    ds_i = tf.data.Dataset.from_tensor_slices(X_i_train).batch(batch_i)

    ds = tf.data.Dataset.zip((ds_u1,ds_f1,ds_u2,ds_f2,ds_i))
    return ds

# %%
omga1 = [[0.,1.],[0.,1.]]  # (x,y)的取值范围 
omga2 = [[0.,1.],[-1.,0.]] 
def test_data(N,omga,u,t=1.):
  # Output: X,Y,T,U shape=(N,N)
  x_range = tf.linspace(omga[0][0],omga[0][1],N)
  y_range = tf.linspace(omga[1][0],omga[1][1],N)

  X,Y = tf.meshgrid(x_range,y_range)
  T = tf.ones(shape=X.shape)*t
  U = u(X,Y,T)
  return X,Y,T,U

def pred_data(X,Y,T,model):
  #Input: X,Y,T shape=(N,N)
  #Output: U_pred shape=(N,N)
  Shape = X.shape
  dim = len(Shape)
  X = tf.reshape(X,shape=(Shape[0]**dim,1))
  Y = tf.reshape(Y,shape=(Shape[0]**dim,1))
  T = tf.reshape(T,shape=(Shape[0]**dim,1))

  Inputs = tf.concat([X,Y,T],axis=1)
  U_pred = model(Inputs)
  U_pred = tf.reshape(U_pred,shape=Shape)
  return U_pred

# %% [markdown]
# # PINN Model

# %%
class MyPinn(keras.Sequential): 
    def __init__(self,Layers,v,n,k,f,name = None): #Layers=[3,20,20,1]
        super(MyPinn, self).__init__(name=name)
        self.add(keras.Input(shape=(Layers[0],) ,dtype=tf.float64))
        for i in range(1,len(Layers)-1):
            self.add(keras.layers.Dense(Layers[i], dtype=tf.float64, activation='tanh'))
        self.add(keras.layers.Dense(Layers[-1],dtype=tf.float64, name="outputs"))
        self.v = tf.constant(v,dtype=tf.float64)
        self.n = tf.constant(n,dtype=tf.float64)
        self.k = tf.constant(k,dtype=tf.float64)
        self.f = f
        
    @tf.function
    def loss_U(self,X_u_train,u_train):
        u= self(X_u_train)
        loss_u = tf.reduce_mean(tf.square(u_train - u))
        return loss_u
    #   
    @tf.function
    def loss_PDE(self,X_f_train):
        x = X_f_train[:,0:1]
        y = X_f_train[:,1:2]
        t = X_f_train[:,2:3]
        with tf.GradientTape(persistent=True) as tape:
            tape.watch([x,y,t])
            X = tf.stack([x[:,0],y[:,0],t[:,0]],axis=1)
            u = self(X)  
            u_x = tape.gradient(u,x)
            u_y = tape.gradient(u,y)
            #u_t = tape.gradient(u,t)
        #tf.print(u_x)    
        u_t = tape.gradient(u, t)     
        u_xx = tape.gradient(u_x, x)
        u_yy = tape.gradient(u_y, y)

        del tape
      
        loss_f = u_t - self.v *(u_xx + u_yy) - self.f(x,y,t)
        loss_f = tf.reduce_mean(tf.square(loss_f))
        return loss_f
    """以下为单区域PINN 训练方法"""    
    @tf.function
    def train_loop(self,X_u_train,u_train,X_f_train):
      with tf.GradientTape() as tape:
        loss = self.loss_U(X_u_train,u_train) + self.loss_PDE(X_f_train)
      gradients = tape.gradient(loss,self.trainable_variables)
      self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

      return loss

    def train(self,X_u_train,u_train,X_f_train,epochs=200):
      for epoch in tf.range(1,epochs+1):
          loss = self.train_loop(X_u_train,u_train,X_f_train)
          if epoch % 50 == 0:                
              tf.print(
                  "Training loss (for per 10 epoches) at epoch ",epoch,":",loss
              )

# %%
class CouplePinn(keras.Model):
  def __init__(self,model_1,model_2,name=None):
    super(CouplePinn,self).__init__(name=name)
    self.m1 = model_1 
    self.m2 = model_2
    
    # Metrics
    self.loss_tracker = keras.metrics.Mean(name="loss")
    self.loss_adaptive = keras.metrics.Mean(name="loss_adaptive")
    self.loss_u1 = keras.metrics.Mean(name="loss_u1")
    self.loss_u2 = keras.metrics.Mean(name="loss_u2")
    self.loss_i = keras.metrics.Mean(name="loss_i")

    # Self-Adaptive factors     
    self.alpha1 = tf.Variable(0.0, dtype = tf.float64, trainable = True)     
    self.alpha2 = tf.Variable(0.0, dtype = tf.float64, trainable = True)
    #self.alpha_i = tf.Variable(1.0, dtype = tf.float64, trainable = True)

    self.optimizer_alpha = keras.optimizers.Adam(learning_rate=0.05)
    #self.optimizer_alpha_m2 = keras.optimizers.Adam(learning_rate=0.001)
    #self.optimizer_alpha_i = keras.optimizers.Adam(learning_rate=0.001)
  @property
  def metrics(self):
      # We list our `Metric` objects here so that `reset_states()` can be
      # called automatically at the start of each epoch
      # or at the start of `evaluate()`.
      # If you don't implement this property, you have to call
      # `reset_states()` yourself at the time of your choosing.
      return [self.loss_adaptive,self.loss_tracker,self.loss_u1,self.loss_u2,self.loss_i] 


  """ 交界处损失函数 """
  @tf.function
  def loss_I(self,X_i_train):
      x = X_i_train[:,0:1]
      y = X_i_train[:,1:2]
      t = X_i_train[:,2:3]
      
      with tf.GradientTape(persistent=True) as tape:
          tape.watch([x,y,t])
          X = tf.stack([x[:,0],y[:,0],t[:,0]],axis=1)
          U1 = self.m1(X)
          U2 = self.m2(X)
      
      U1_x = tape.gradient(U1, x)
      U1_y = tape.gradient(U1, y)
      U2_x = tape.gradient(U2, x)
      U2_y = tape.gradient(U2, y)

      del tape
      
      loss_i1 = -self.m1.v * ( U1_x*self.m1.n[0] + U1_y*self.m1.n[1]) - self.m1.k * (U1-U2)
      loss_i2 = -self.m2.v * ( U2_x*self.m2.n[0] + U2_y*self.m2.n[1]) - self.m2.k * (U2-U1)

      loss_i1 = tf.reduce_mean(tf.square(loss_i1)) 
      loss_i2 = tf.reduce_mean(tf.square(loss_i2))

      return loss_i1,loss_i2

  """耦合区域 PINN训练方法"""
  @tf.function
  def train_step(self,data):
      (X_u1_train,u1_train),X_f1_train,(X_u2_train,u2_train),X_f2_train,X_i_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss_m1 = self.m1.loss_U(X_u1_train,u1_train) + self.m1.loss_PDE(X_f1_train)
          loss_m2 = self.m2.loss_U(X_u2_train,u2_train) + self.m2.loss_PDE(X_f2_train)
          loss_i1,loss_i2 = self.loss_I(X_i_train)

          a1 = tf.math.sigmoid(2*self.alpha1+0.5) * 2
          a2 = tf.math.sigmoid(2*self.alpha2+0.5) * 2
          loss_adaptive = a1*(loss_m1+loss_i1) + a2*(loss_m2+loss_i2)
          #loss_adaptive = (loss_m1+loss_i1) + (loss_m2+loss_i2)

      loss = loss_m1 + loss_m2 + loss_i1 + loss_i2
      # Compute gradients
      gradients_m1 = tape.gradient(loss_adaptive,self.m1.trainable_variables)
      gradients_m2 = tape.gradient(loss_adaptive,self.m2.trainable_variables)
      gradient_a1pha1 = -tape.gradient(loss_adaptive,self.alpha1)
      gradient_alpha2 = -tape.gradient(loss_adaptive,self.alpha2)

      del tape

      # Updata parameters
      self.m1.optimizer.apply_gradients(zip(gradients_m1, self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_m2, self.m2.trainable_variables))
      self.optimizer_alpha.apply_gradients( zip([gradient_a1pha1,gradient_alpha2], [self.alpha1,self.alpha2]) )

      # Updata Metric
      self.loss_adaptive.update_state(loss_adaptive)
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_m1+loss_i1)
      self.loss_u2.update_state(loss_m2+loss_i2)
      self.loss_i.update_state(loss_i1+loss_i2)

      return {m.name : m.result() for m in self.metrics}

# %% [markdown]
# # Train

# %%
""" Training Data """
n1 = [0.,-1.]
n2 = [0.,1.]

omga1 = [[0.,1.],[0.,1.]]  # (x,y)的取值范围 
omga2 = [[0.,1.],[-1.,0.]] 

N_i = 500

N_u1 = 500; N_f1 = 2000  ;omga = omga1; interface=0; u = u1
X_u1_train,u1_train,X_f1_train,X_i_train= trainingdata(N_u1,N_f1,N_i,omga,u,interface)


N_u2 = 500; N_f2= 2000 ; omga = omga2; interface=1; u = u2
X_u2_train,u2_train,X_f2_train,X_i_train= trainingdata(N_u2,N_f2,N_i,omga,u,interface)

""" Test Data """
N = 100
X_u1,Y_u1,T_u1,U1 = test_data(N,omga1,u1,t=1.0)
X_u2,Y_u2,T_u2,U2 = test_data(N,omga2,u2,t=1.0)

# %%
Layers=[3,20,20,20,20,1]
model_u1 = MyPinn(Layers,v1,n1,k,f1,name="model_1")
model_u1.compile(optimizer=keras.optimizers.Adam())

model_u2 = MyPinn(Layers,v2,n2,k,f2,name="model_2")
model_u2.compile(optimizer=keras.optimizers.Adam())

ds = ds_train_n_batch(X_u1_train, u1_train , X_f1_train , X_u2_train , u2_train , X_f2_train , X_i_train ,n = 10)

# %%
model_u1.train(X_u1_train,u1_train,X_f1_train,epochs=1000) #单区域PINN训练
model_u2.train(X_u2_train,u2_train,X_f2_train,epochs=1000) #单区域PINN训练
# Out:
# Training loss (for per 10 epoches) at epoch  50 : 0.070458691426636383
# Training loss (for per 10 epoches) at epoch  100 : 0.018384293301757369
# Training loss (for per 10 epoches) at epoch  150 : 0.011014140265853005
# Training loss (for per 10 epoches) at epoch  200 : 0.0076205891753122357
# Training loss (for per 10 epoches) at epoch  250 : 0.00618301486962335
# Training loss (for per 10 epoches) at epoch  300 : 0.0054422806822153683
# Training loss (for per 10 epoches) at epoch  350 : 0.0049843474182736051
# Training loss (for per 10 epoches) at epoch  400 : 0.004667479812109152
# Training loss (for per 10 epoches) at epoch  450 : 0.0044293736072210472
# Training loss (for per 10 epoches) at epoch  500 : 0.00424028704852069
# Training loss (for per 10 epoches) at epoch  550 : 0.0040840545481560528
# Training loss (for per 10 epoches) at epoch  600 : 0.0039505364245247193
# Training loss (for per 10 epoches) at epoch  650 : 0.0038328101819370547
# Training loss (for per 10 epoches) at epoch  700 : 0.0037260721034364803
# Training loss (for per 10 epoches) at epoch  750 : 0.0036270058747545041
# Training loss (for per 10 epoches) at epoch  800 : 0.0035332779453962561
# Training loss (for per 10 epoches) at epoch  850 : 0.003443153160245203
# Training loss (for per 10 epoches) at epoch  900 : 0.0033552615946999143
# Training loss (for per 10 epoches) at epoch  950 : 0.0032684919439613606
# Training loss (for per 10 epoches) at epoch  1000 : 0.0031819568884668709
# Training loss (for per 10 epoches) at epoch  50 : 1.0596479984807274
# Training loss (for per 10 epoches) at epoch  100 : 0.45707317492977284
# Training loss (for per 10 epoches) at epoch  150 : 0.31795294141553321
# Training loss (for per 10 epoches) at epoch  200 : 0.23760360146384846
# Training loss (for per 10 epoches) at epoch  250 : 0.160939973353616
# Training loss (for per 10 epoches) at epoch  300 : 0.10931929968184886
# Training loss (for per 10 epoches) at epoch  350 : 0.073734608292701315
# Training loss (for per 10 epoches) at epoch  400 : 0.05012953568204314
# Training loss (for per 10 epoches) at epoch  450 : 0.036938937547618941
# Training loss (for per 10 epoches) at epoch  500 : 0.030089116796111925
# Training loss (for per 10 epoches) at epoch  550 : 0.02627567989302293
# Training loss (for per 10 epoches) at epoch  600 : 0.023876192693023053
# Training loss (for per 10 epoches) at epoch  650 : 0.022182319602368633
# Training loss (for per 10 epoches) at epoch  700 : 0.020865649310872165
# Training loss (for per 10 epoches) at epoch  750 : 0.019755183924504809
# Training loss (for per 10 epoches) at epoch  800 : 0.018754817396499413
# Training loss (for per 10 epoches) at epoch  850 : 0.017808528482204003
# Training loss (for per 10 epoches) at epoch  900 : 0.016883101286227359
# Training loss (for per 10 epoches) at epoch  950 : 0.01596045868465849
# Training loss (for per 10 epoches) at epoch  1000 : 0.015035063238231073

# %%
couple_model = CouplePinn(model_u1,model_u2) 
couple_model.compile()

# %%
couple_model.fit(ds,epochs=1500)#耦合PINN训练
# Out:
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0094 - loss: 0.0047 - loss_u1: 0.0010 - loss_u2: 0.0037 - loss_i: 3.5515e-04
# Epoch 160/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0093 - loss: 0.0047 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.5406e-04
# Epoch 161/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0093 - loss: 0.0047 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.5305e-04
# Epoch 162/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0092 - loss: 0.0046 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.5210e-04
# Epoch 163/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0092 - loss: 0.0046 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.5122e-04
# Epoch 164/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0092 - loss: 0.0046 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.5040e-04
# Epoch 165/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0091 - loss: 0.0046 - loss_u1: 0.0010 - loss_u2: 0.0036 - loss_i: 3.4964e-04
# Epoch 166/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0091 - loss: 0.0046 - loss_u1: 0.0010 - loss_u2: 0.0035 - loss_i: 3.4893e-04
# Epoch 167/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0091 - loss: 0.0045 - loss_u1: 0.0010 - loss_u2: 0.0035 - loss_i: 3.4827e-04
# Epoch 168/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0090 - loss: 0.0045 - loss_u1: 0.0010 - loss_u2: 0.0035 - loss_i: 3.4765e-04
# Epoch 169/1500
# 10/10 [==============================] - 0s 50ms/step - loss_adaptive: 0.0090 - loss: 0.0045 - loss_u1: 0.0010 - loss_u2: 0.0035 - loss_i: 3.4707e-04
# Epoch 170/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 0.0089 - loss: 0.0045 - loss_u1: 9.9878e-04 - loss_u2: 0.0035 - loss_i: 3.4652e-04
# Epoch 171/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0089 - loss: 0.0045 - loss_u1: 9.9492e-04 - loss_u2: 0.0035 - loss_i: 3.4601e-04
# Epoch 172/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0089 - loss: 0.0045 - loss_u1: 9.9112e-04 - loss_u2: 0.0035 - loss_i: 3.4553e-04
# Epoch 173/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0088 - loss: 0.0044 - loss_u1: 9.8738e-04 - loss_u2: 0.0035 - loss_i: 3.4506e-04
# Epoch 174/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0088 - loss: 0.0044 - loss_u1: 9.8368e-04 - loss_u2: 0.0034 - loss_i: 3.4462e-04
# Epoch 175/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0088 - loss: 0.0044 - loss_u1: 9.8002e-04 - loss_u2: 0.0034 - loss_i: 3.4420e-04
# Epoch 176/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0087 - loss: 0.0044 - loss_u1: 9.7639e-04 - loss_u2: 0.0034 - loss_i: 3.4379e-04
# Epoch 177/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0087 - loss: 0.0044 - loss_u1: 9.7278e-04 - loss_u2: 0.0034 - loss_i: 3.4339e-04
# Epoch 178/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0087 - loss: 0.0044 - loss_u1: 9.6919e-04 - loss_u2: 0.0034 - loss_i: 3.4299e-04
# Epoch 179/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0086 - loss: 0.0043 - loss_u1: 9.6561e-04 - loss_u2: 0.0034 - loss_i: 3.4261e-04
# Epoch 180/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0086 - loss: 0.0043 - loss_u1: 9.6204e-04 - loss_u2: 0.0034 - loss_i: 3.4223e-04
# Epoch 181/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0086 - loss: 0.0043 - loss_u1: 9.5847e-04 - loss_u2: 0.0033 - loss_i: 3.4185e-04
# Epoch 182/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0085 - loss: 0.0043 - loss_u1: 9.5490e-04 - loss_u2: 0.0033 - loss_i: 3.4147e-04
# Epoch 183/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0085 - loss: 0.0043 - loss_u1: 9.5132e-04 - loss_u2: 0.0033 - loss_i: 3.4109e-04
# Epoch 184/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0085 - loss: 0.0043 - loss_u1: 9.4774e-04 - loss_u2: 0.0033 - loss_i: 3.4071e-04
# Epoch 185/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0085 - loss: 0.0042 - loss_u1: 9.4415e-04 - loss_u2: 0.0033 - loss_i: 3.4033e-04
# Epoch 186/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0084 - loss: 0.0042 - loss_u1: 9.4055e-04 - loss_u2: 0.0033 - loss_i: 3.3995e-04
# Epoch 187/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0084 - loss: 0.0042 - loss_u1: 9.3695e-04 - loss_u2: 0.0033 - loss_i: 3.3957e-04
# Epoch 188/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0084 - loss: 0.0042 - loss_u1: 9.3334e-04 - loss_u2: 0.0033 - loss_i: 3.3918e-04
# Epoch 189/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0083 - loss: 0.0042 - loss_u1: 9.2972e-04 - loss_u2: 0.0032 - loss_i: 3.3879e-04
# Epoch 190/1500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0083 - loss: 0.0042 - loss_u1: 9.2610e-04 - loss_u2: 0.0032 - loss_i: 3.3840e-04
# Epoch 191/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0083 - loss: 0.0041 - loss_u1: 9.2246e-04 - loss_u2: 0.0032 - loss_i: 3.3800e-04
# Epoch 192/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0082 - loss: 0.0041 - loss_u1: 9.1883e-04 - loss_u2: 0.0032 - loss_i: 3.3761e-04
# Epoch 193/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0082 - loss: 0.0041 - loss_u1: 9.1519e-04 - loss_u2: 0.0032 - loss_i: 3.3721e-04
# Epoch 194/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0082 - loss: 0.0041 - loss_u1: 9.1155e-04 - loss_u2: 0.0032 - loss_i: 3.3681e-04
# Epoch 195/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0081 - loss: 0.0041 - loss_u1: 9.0791e-04 - loss_u2: 0.0032 - loss_i: 3.3640e-04
# Epoch 196/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0081 - loss: 0.0041 - loss_u1: 9.0427e-04 - loss_u2: 0.0032 - loss_i: 3.3600e-04
# Epoch 197/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0081 - loss: 0.0041 - loss_u1: 9.0064e-04 - loss_u2: 0.0032 - loss_i: 3.3559e-04
# Epoch 198/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0081 - loss: 0.0040 - loss_u1: 8.9700e-04 - loss_u2: 0.0031 - loss_i: 3.3518e-04
# Epoch 199/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0080 - loss: 0.0040 - loss_u1: 8.9338e-04 - loss_u2: 0.0031 - loss_i: 3.3477e-04
# Epoch 200/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0080 - loss: 0.0040 - loss_u1: 8.8975e-04 - loss_u2: 0.0031 - loss_i: 3.3435e-04
# Epoch 201/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0080 - loss: 0.0040 - loss_u1: 8.8614e-04 - loss_u2: 0.0031 - loss_i: 3.3394e-04
# Epoch 202/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0079 - loss: 0.0040 - loss_u1: 8.8253e-04 - loss_u2: 0.0031 - loss_i: 3.3352e-04
# Epoch 203/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0079 - loss: 0.0040 - loss_u1: 8.7894e-04 - loss_u2: 0.0031 - loss_i: 3.3311e-04
# Epoch 204/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0079 - loss: 0.0040 - loss_u1: 8.7535e-04 - loss_u2: 0.0031 - loss_i: 3.3269e-04
# Epoch 205/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0079 - loss: 0.0039 - loss_u1: 8.7178e-04 - loss_u2: 0.0031 - loss_i: 3.3227e-04
# Epoch 206/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0078 - loss: 0.0039 - loss_u1: 8.6822e-04 - loss_u2: 0.0031 - loss_i: 3.3185e-04
# Epoch 207/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0078 - loss: 0.0039 - loss_u1: 8.6467e-04 - loss_u2: 0.0030 - loss_i: 3.3142e-04
# Epoch 208/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0078 - loss: 0.0039 - loss_u1: 8.6114e-04 - loss_u2: 0.0030 - loss_i: 3.3100e-04
# Epoch 209/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0077 - loss: 0.0039 - loss_u1: 8.5762e-04 - loss_u2: 0.0030 - loss_i: 3.3057e-04
# Epoch 210/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0077 - loss: 0.0039 - loss_u1: 8.5412e-04 - loss_u2: 0.0030 - loss_i: 3.3014e-04
# Epoch 211/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0077 - loss: 0.0039 - loss_u1: 8.5063e-04 - loss_u2: 0.0030 - loss_i: 3.2971e-04
# Epoch 212/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0077 - loss: 0.0038 - loss_u1: 8.4715e-04 - loss_u2: 0.0030 - loss_i: 3.2928e-04
# Epoch 213/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0076 - loss: 0.0038 - loss_u1: 8.4370e-04 - loss_u2: 0.0030 - loss_i: 3.2884e-04
# Epoch 214/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0076 - loss: 0.0038 - loss_u1: 8.4026e-04 - loss_u2: 0.0030 - loss_i: 3.2840e-04
# Epoch 215/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0076 - loss: 0.0038 - loss_u1: 8.3684e-04 - loss_u2: 0.0030 - loss_i: 3.2796e-04
# Epoch 216/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0075 - loss: 0.0038 - loss_u1: 8.3343e-04 - loss_u2: 0.0029 - loss_i: 3.2751e-04
# Epoch 217/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0075 - loss: 0.0038 - loss_u1: 8.3004e-04 - loss_u2: 0.0029 - loss_i: 3.2706e-04
# Epoch 218/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0075 - loss: 0.0038 - loss_u1: 8.2667e-04 - loss_u2: 0.0029 - loss_i: 3.2660e-04
# Epoch 219/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0075 - loss: 0.0037 - loss_u1: 8.2331e-04 - loss_u2: 0.0029 - loss_i: 3.2613e-04
# Epoch 220/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0074 - loss: 0.0037 - loss_u1: 8.1997e-04 - loss_u2: 0.0029 - loss_i: 3.2566e-04
# Epoch 221/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 0.0074 - loss: 0.0037 - loss_u1: 8.1664e-04 - loss_u2: 0.0029 - loss_i: 3.2518e-04
# Epoch 222/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0074 - loss: 0.0037 - loss_u1: 8.1333e-04 - loss_u2: 0.0029 - loss_i: 3.2469e-04
# Epoch 223/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0073 - loss: 0.0037 - loss_u1: 8.1003e-04 - loss_u2: 0.0029 - loss_i: 3.2418e-04
# Epoch 224/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0073 - loss: 0.0037 - loss_u1: 8.0675e-04 - loss_u2: 0.0029 - loss_i: 3.2367e-04
# Epoch 225/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0073 - loss: 0.0037 - loss_u1: 8.0348e-04 - loss_u2: 0.0029 - loss_i: 3.2314e-04
# Epoch 226/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0073 - loss: 0.0036 - loss_u1: 8.0022e-04 - loss_u2: 0.0028 - loss_i: 3.2260e-04
# Epoch 227/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0072 - loss: 0.0036 - loss_u1: 7.9696e-04 - loss_u2: 0.0028 - loss_i: 3.2203e-04
# Epoch 228/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0072 - loss: 0.0036 - loss_u1: 7.9372e-04 - loss_u2: 0.0028 - loss_i: 3.2145e-04
# Epoch 229/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0072 - loss: 0.0036 - loss_u1: 7.9049e-04 - loss_u2: 0.0028 - loss_i: 3.2085e-04
# Epoch 230/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0072 - loss: 0.0036 - loss_u1: 7.8726e-04 - loss_u2: 0.0028 - loss_i: 3.2023e-04
# Epoch 231/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 0.0071 - loss: 0.0036 - loss_u1: 7.8403e-04 - loss_u2: 0.0028 - loss_i: 3.1958e-04
# Epoch 232/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0071 - loss: 0.0036 - loss_u1: 7.8081e-04 - loss_u2: 0.0028 - loss_i: 3.1890e-04
# Epoch 233/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0071 - loss: 0.0036 - loss_u1: 7.7758e-04 - loss_u2: 0.0028 - loss_i: 3.1820e-04
# Epoch 234/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0071 - loss: 0.0035 - loss_u1: 7.7436e-04 - loss_u2: 0.0028 - loss_i: 3.1746e-04
# Epoch 235/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0070 - loss: 0.0035 - loss_u1: 7.7113e-04 - loss_u2: 0.0028 - loss_i: 3.1669e-04
# Epoch 236/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0070 - loss: 0.0035 - loss_u1: 7.6790e-04 - loss_u2: 0.0027 - loss_i: 3.1588e-04
# Epoch 237/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0070 - loss: 0.0035 - loss_u1: 7.6466e-04 - loss_u2: 0.0027 - loss_i: 3.1504e-04
# Epoch 238/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0070 - loss: 0.0035 - loss_u1: 7.6141e-04 - loss_u2: 0.0027 - loss_i: 3.1415e-04
# Epoch 239/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0069 - loss: 0.0035 - loss_u1: 7.5814e-04 - loss_u2: 0.0027 - loss_i: 3.1323e-04
# Epoch 240/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0069 - loss: 0.0035 - loss_u1: 7.5487e-04 - loss_u2: 0.0027 - loss_i: 3.1225e-04
# Epoch 241/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0069 - loss: 0.0034 - loss_u1: 7.5158e-04 - loss_u2: 0.0027 - loss_i: 3.1124e-04
# Epoch 242/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0069 - loss: 0.0034 - loss_u1: 7.4827e-04 - loss_u2: 0.0027 - loss_i: 3.1017e-04
# Epoch 243/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 7.4494e-04 - loss_u2: 0.0027 - loss_i: 3.0906e-04
# Epoch 244/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 7.4159e-04 - loss_u2: 0.0027 - loss_i: 3.0790e-04
# Epoch 245/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 7.3822e-04 - loss_u2: 0.0027 - loss_i: 3.0669e-04
# Epoch 246/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 7.3483e-04 - loss_u2: 0.0026 - loss_i: 3.0542e-04
# Epoch 247/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 0.0067 - loss: 0.0034 - loss_u1: 7.3141e-04 - loss_u2: 0.0026 - loss_i: 3.0411e-04
# Epoch 248/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0067 - loss: 0.0034 - loss_u1: 7.2797e-04 - loss_u2: 0.0026 - loss_i: 3.0274e-04
# Epoch 249/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0067 - loss: 0.0033 - loss_u1: 7.2450e-04 - loss_u2: 0.0026 - loss_i: 3.0132e-04
# Epoch 250/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 7.2100e-04 - loss_u2: 0.0026 - loss_i: 2.9985e-04
# Epoch 251/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 7.1748e-04 - loss_u2: 0.0026 - loss_i: 2.9833e-04
# Epoch 252/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 7.1393e-04 - loss_u2: 0.0026 - loss_i: 2.9677e-04
# Epoch 253/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 7.1035e-04 - loss_u2: 0.0026 - loss_i: 2.9515e-04
# Epoch 254/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 7.0674e-04 - loss_u2: 0.0026 - loss_i: 2.9349e-04
# Epoch 255/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 7.0311e-04 - loss_u2: 0.0026 - loss_i: 2.9178e-04
# Epoch 256/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 6.9945e-04 - loss_u2: 0.0026 - loss_i: 2.9002e-04
# Epoch 257/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0065 - loss: 0.0032 - loss_u1: 6.9577e-04 - loss_u2: 0.0025 - loss_i: 2.8823e-04
# Epoch 258/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 6.9206e-04 - loss_u2: 0.0025 - loss_i: 2.8639e-04
# Epoch 259/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 6.8834e-04 - loss_u2: 0.0025 - loss_i: 2.8452e-04
# Epoch 260/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 6.8459e-04 - loss_u2: 0.0025 - loss_i: 2.8261e-04
# Epoch 261/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 6.8082e-04 - loss_u2: 0.0025 - loss_i: 2.8068e-04
# Epoch 262/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 6.7704e-04 - loss_u2: 0.0025 - loss_i: 2.7871e-04
# Epoch 263/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 6.7324e-04 - loss_u2: 0.0025 - loss_i: 2.7673e-04
# Epoch 264/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0063 - loss: 0.0031 - loss_u1: 6.6944e-04 - loss_u2: 0.0025 - loss_i: 2.7472e-04
# Epoch 265/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 6.6563e-04 - loss_u2: 0.0025 - loss_i: 2.7270e-04
# Epoch 266/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 6.6182e-04 - loss_u2: 0.0024 - loss_i: 2.7068e-04
# Epoch 267/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 6.5801e-04 - loss_u2: 0.0024 - loss_i: 2.6866e-04
# Epoch 268/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 6.5421e-04 - loss_u2: 0.0024 - loss_i: 2.6664e-04
# Epoch 269/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 6.5042e-04 - loss_u2: 0.0024 - loss_i: 2.6463e-04
# Epoch 270/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 6.4665e-04 - loss_u2: 0.0024 - loss_i: 2.6265e-04
# Epoch 271/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0061 - loss: 0.0030 - loss_u1: 6.4291e-04 - loss_u2: 0.0024 - loss_i: 2.6070e-04
# Epoch 272/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 6.3919e-04 - loss_u2: 0.0024 - loss_i: 2.5878e-04
# Epoch 273/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 6.3551e-04 - loss_u2: 0.0024 - loss_i: 2.5691e-04
# Epoch 274/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 6.3186e-04 - loss_u2: 0.0024 - loss_i: 2.5509e-04
# Epoch 275/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 6.2826e-04 - loss_u2: 0.0024 - loss_i: 2.5334e-04
# Epoch 276/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 6.2471e-04 - loss_u2: 0.0023 - loss_i: 2.5165e-04
# Epoch 277/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 6.2120e-04 - loss_u2: 0.0023 - loss_i: 2.5003e-04
# Epoch 278/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0059 - loss: 0.0029 - loss_u1: 6.1775e-04 - loss_u2: 0.0023 - loss_i: 2.4848e-04
# Epoch 279/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 6.1434e-04 - loss_u2: 0.0023 - loss_i: 2.4701e-04
# Epoch 280/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 6.1100e-04 - loss_u2: 0.0023 - loss_i: 2.4563e-04
# Epoch 281/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 6.0770e-04 - loss_u2: 0.0023 - loss_i: 2.4432e-04
# Epoch 282/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 6.0446e-04 - loss_u2: 0.0023 - loss_i: 2.4310e-04
# Epoch 283/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 6.0128e-04 - loss_u2: 0.0023 - loss_i: 2.4195e-04
# Epoch 284/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 5.9814e-04 - loss_u2: 0.0023 - loss_i: 2.4089e-04
# Epoch 285/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 5.9506e-04 - loss_u2: 0.0023 - loss_i: 2.3991e-04
# Epoch 286/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0057 - loss: 0.0028 - loss_u1: 5.9203e-04 - loss_u2: 0.0022 - loss_i: 2.3900e-04
# Epoch 287/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 5.8904e-04 - loss_u2: 0.0022 - loss_i: 2.3817e-04
# Epoch 288/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 5.8611e-04 - loss_u2: 0.0022 - loss_i: 2.3742e-04
# Epoch 289/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 5.8322e-04 - loss_u2: 0.0022 - loss_i: 2.3674e-04
# Epoch 290/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 5.8037e-04 - loss_u2: 0.0022 - loss_i: 2.3613e-04
# Epoch 291/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0055 - loss: 0.0028 - loss_u1: 5.7757e-04 - loss_u2: 0.0022 - loss_i: 2.3558e-04
# Epoch 292/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0055 - loss: 0.0028 - loss_u1: 5.7482e-04 - loss_u2: 0.0022 - loss_i: 2.3510e-04
# Epoch 293/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0055 - loss: 0.0028 - loss_u1: 5.7211e-04 - loss_u2: 0.0022 - loss_i: 2.3469e-04
# Epoch 294/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0055 - loss: 0.0027 - loss_u1: 5.6944e-04 - loss_u2: 0.0022 - loss_i: 2.3434e-04
# Epoch 295/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0054 - loss: 0.0027 - loss_u1: 5.6681e-04 - loss_u2: 0.0022 - loss_i: 2.3404e-04
# Epoch 296/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0054 - loss: 0.0027 - loss_u1: 5.6423e-04 - loss_u2: 0.0022 - loss_i: 2.3380e-04
# Epoch 297/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0054 - loss: 0.0027 - loss_u1: 5.6168e-04 - loss_u2: 0.0021 - loss_i: 2.3361e-04
# Epoch 298/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0054 - loss: 0.0027 - loss_u1: 5.5918e-04 - loss_u2: 0.0021 - loss_i: 2.3346e-04
# Epoch 299/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0054 - loss: 0.0027 - loss_u1: 5.5672e-04 - loss_u2: 0.0021 - loss_i: 2.3337e-04
# Epoch 300/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0053 - loss: 0.0027 - loss_u1: 5.5430e-04 - loss_u2: 0.0021 - loss_i: 2.3331e-04
# Epoch 301/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0053 - loss: 0.0027 - loss_u1: 5.5191e-04 - loss_u2: 0.0021 - loss_i: 2.3329e-04
# Epoch 302/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0053 - loss: 0.0027 - loss_u1: 5.4956e-04 - loss_u2: 0.0021 - loss_i: 2.3331e-04
# Epoch 303/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 0.0053 - loss: 0.0026 - loss_u1: 5.4725e-04 - loss_u2: 0.0021 - loss_i: 2.3335e-04
# Epoch 304/1500
# 10/10 [==============================] - 0s 50ms/step - loss_adaptive: 0.0052 - loss: 0.0026 - loss_u1: 5.4497e-04 - loss_u2: 0.0021 - loss_i: 2.3342e-04
# Epoch 305/1500
# 10/10 [==============================] - 1s 60ms/step - loss_adaptive: 0.0052 - loss: 0.0026 - loss_u1: 5.4273e-04 - loss_u2: 0.0021 - loss_i: 2.3351e-04
# Epoch 306/1500
# 10/10 [==============================] - 1s 50ms/step - loss_adaptive: 0.0052 - loss: 0.0026 - loss_u1: 5.4051e-04 - loss_u2: 0.0021 - loss_i: 2.3361e-04
# Epoch 307/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 0.0052 - loss: 0.0026 - loss_u1: 5.3833e-04 - loss_u2: 0.0021 - loss_i: 2.3373e-04
# Epoch 308/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0052 - loss: 0.0026 - loss_u1: 5.3617e-04 - loss_u2: 0.0021 - loss_i: 2.3385e-04
# Epoch 309/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0051 - loss: 0.0026 - loss_u1: 5.3404e-04 - loss_u2: 0.0020 - loss_i: 2.3398e-04
# Epoch 310/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0051 - loss: 0.0026 - loss_u1: 5.3193e-04 - loss_u2: 0.0020 - loss_i: 2.3411e-04
# Epoch 311/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0051 - loss: 0.0026 - loss_u1: 5.2984e-04 - loss_u2: 0.0020 - loss_i: 2.3423e-04
# Epoch 312/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0051 - loss: 0.0025 - loss_u1: 5.2777e-04 - loss_u2: 0.0020 - loss_i: 2.3434e-04
# Epoch 313/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0051 - loss: 0.0025 - loss_u1: 5.2572e-04 - loss_u2: 0.0020 - loss_i: 2.3444e-04
# Epoch 314/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0050 - loss: 0.0025 - loss_u1: 5.2368e-04 - loss_u2: 0.0020 - loss_i: 2.3453e-04
# Epoch 315/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0050 - loss: 0.0025 - loss_u1: 5.2166e-04 - loss_u2: 0.0020 - loss_i: 2.3460e-04
# Epoch 316/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0050 - loss: 0.0025 - loss_u1: 5.1965e-04 - loss_u2: 0.0020 - loss_i: 2.3465e-04
# Epoch 317/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0050 - loss: 0.0025 - loss_u1: 5.1765e-04 - loss_u2: 0.0020 - loss_i: 2.3468e-04
# Epoch 318/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0050 - loss: 0.0025 - loss_u1: 5.1566e-04 - loss_u2: 0.0020 - loss_i: 2.3469e-04
# Epoch 319/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0049 - loss: 0.0025 - loss_u1: 5.1367e-04 - loss_u2: 0.0020 - loss_i: 2.3468e-04
# Epoch 320/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0049 - loss: 0.0025 - loss_u1: 5.1170e-04 - loss_u2: 0.0020 - loss_i: 2.3464e-04
# Epoch 321/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0049 - loss: 0.0025 - loss_u1: 5.0974e-04 - loss_u2: 0.0019 - loss_i: 2.3458e-04
# Epoch 322/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0049 - loss: 0.0024 - loss_u1: 5.0778e-04 - loss_u2: 0.0019 - loss_i: 2.3450e-04
# Epoch 323/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0049 - loss: 0.0024 - loss_u1: 5.0582e-04 - loss_u2: 0.0019 - loss_i: 2.3439e-04
# Epoch 324/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0048 - loss: 0.0024 - loss_u1: 5.0388e-04 - loss_u2: 0.0019 - loss_i: 2.3426e-04
# Epoch 325/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0048 - loss: 0.0024 - loss_u1: 5.0194e-04 - loss_u2: 0.0019 - loss_i: 2.3411e-04
# Epoch 326/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0048 - loss: 0.0024 - loss_u1: 5.0001e-04 - loss_u2: 0.0019 - loss_i: 2.3394e-04
# Epoch 327/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0048 - loss: 0.0024 - loss_u1: 4.9809e-04 - loss_u2: 0.0019 - loss_i: 2.3375e-04
# Epoch 328/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0048 - loss: 0.0024 - loss_u1: 4.9618e-04 - loss_u2: 0.0019 - loss_i: 2.3354e-04
# Epoch 329/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 0.0047 - loss: 0.0024 - loss_u1: 4.9428e-04 - loss_u2: 0.0019 - loss_i: 2.3332e-04
# Epoch 330/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0047 - loss: 0.0024 - loss_u1: 4.9239e-04 - loss_u2: 0.0019 - loss_i: 2.3309e-04
# Epoch 331/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0047 - loss: 0.0023 - loss_u1: 4.9051e-04 - loss_u2: 0.0019 - loss_i: 2.3285e-04
# Epoch 332/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0047 - loss: 0.0023 - loss_u1: 4.8865e-04 - loss_u2: 0.0018 - loss_i: 2.3260e-04
# Epoch 333/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0046 - loss: 0.0023 - loss_u1: 4.8680e-04 - loss_u2: 0.0018 - loss_i: 2.3234e-04
# Epoch 334/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0046 - loss: 0.0023 - loss_u1: 4.8496e-04 - loss_u2: 0.0018 - loss_i: 2.3208e-04
# Epoch 335/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0046 - loss: 0.0023 - loss_u1: 4.8315e-04 - loss_u2: 0.0018 - loss_i: 2.3182e-04
# Epoch 336/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 0.0046 - loss: 0.0023 - loss_u1: 4.8135e-04 - loss_u2: 0.0018 - loss_i: 2.3156e-04
# Epoch 337/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0046 - loss: 0.0023 - loss_u1: 4.7957e-04 - loss_u2: 0.0018 - loss_i: 2.3131e-04
# Epoch 338/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0045 - loss: 0.0023 - loss_u1: 4.7782e-04 - loss_u2: 0.0018 - loss_i: 2.3107e-04
# Epoch 339/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0045 - loss: 0.0023 - loss_u1: 4.7609e-04 - loss_u2: 0.0018 - loss_i: 2.3084e-04
# Epoch 340/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0045 - loss: 0.0023 - loss_u1: 4.7438e-04 - loss_u2: 0.0018 - loss_i: 2.3062e-04
# Epoch 341/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0045 - loss: 0.0022 - loss_u1: 4.7270e-04 - loss_u2: 0.0018 - loss_i: 2.3041e-04
# Epoch 342/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0045 - loss: 0.0022 - loss_u1: 4.7104e-04 - loss_u2: 0.0018 - loss_i: 2.3023e-04
# Epoch 343/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0044 - loss: 0.0022 - loss_u1: 4.6941e-04 - loss_u2: 0.0018 - loss_i: 2.3006e-04
# Epoch 344/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0044 - loss: 0.0022 - loss_u1: 4.6782e-04 - loss_u2: 0.0017 - loss_i: 2.2991e-04
# Epoch 345/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0044 - loss: 0.0022 - loss_u1: 4.6624e-04 - loss_u2: 0.0017 - loss_i: 2.2978e-04
# Epoch 346/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0044 - loss: 0.0022 - loss_u1: 4.6470e-04 - loss_u2: 0.0017 - loss_i: 2.2967e-04
# Epoch 347/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0044 - loss: 0.0022 - loss_u1: 4.6318e-04 - loss_u2: 0.0017 - loss_i: 2.2959e-04
# Epoch 348/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0043 - loss: 0.0022 - loss_u1: 4.6169e-04 - loss_u2: 0.0017 - loss_i: 2.2951e-04
# Epoch 349/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0043 - loss: 0.0022 - loss_u1: 4.6022e-04 - loss_u2: 0.0017 - loss_i: 2.2945e-04
# Epoch 350/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0043 - loss: 0.0022 - loss_u1: 4.5877e-04 - loss_u2: 0.0017 - loss_i: 2.2941e-04
# Epoch 351/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0043 - loss: 0.0021 - loss_u1: 4.5735e-04 - loss_u2: 0.0017 - loss_i: 2.2937e-04
# Epoch 352/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0043 - loss: 0.0021 - loss_u1: 4.5593e-04 - loss_u2: 0.0017 - loss_i: 2.2933e-04
# Epoch 353/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0043 - loss: 0.0021 - loss_u1: 4.5453e-04 - loss_u2: 0.0017 - loss_i: 2.2929e-04
# Epoch 354/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0042 - loss: 0.0021 - loss_u1: 4.5314e-04 - loss_u2: 0.0017 - loss_i: 2.2925e-04
# Epoch 355/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0042 - loss: 0.0021 - loss_u1: 4.5176e-04 - loss_u2: 0.0017 - loss_i: 2.2920e-04
# Epoch 356/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0042 - loss: 0.0021 - loss_u1: 4.5038e-04 - loss_u2: 0.0017 - loss_i: 2.2913e-04
# Epoch 357/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0042 - loss: 0.0021 - loss_u1: 4.4900e-04 - loss_u2: 0.0016 - loss_i: 2.2904e-04
# Epoch 358/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0042 - loss: 0.0021 - loss_u1: 4.4763e-04 - loss_u2: 0.0016 - loss_i: 2.2894e-04
# Epoch 359/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0041 - loss: 0.0021 - loss_u1: 4.4625e-04 - loss_u2: 0.0016 - loss_i: 2.2881e-04
# Epoch 360/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0041 - loss: 0.0021 - loss_u1: 4.4486e-04 - loss_u2: 0.0016 - loss_i: 2.2866e-04
# Epoch 361/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0041 - loss: 0.0021 - loss_u1: 4.4347e-04 - loss_u2: 0.0016 - loss_i: 2.2848e-04
# Epoch 362/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 0.0041 - loss: 0.0021 - loss_u1: 4.4208e-04 - loss_u2: 0.0016 - loss_i: 2.2827e-04
# Epoch 363/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 0.0041 - loss: 0.0020 - loss_u1: 4.4067e-04 - loss_u2: 0.0016 - loss_i: 2.2804e-04
# Epoch 364/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0041 - loss: 0.0020 - loss_u1: 4.3927e-04 - loss_u2: 0.0016 - loss_i: 2.2779e-04
# Epoch 365/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3786e-04 - loss_u2: 0.0016 - loss_i: 2.2751e-04
# Epoch 366/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3644e-04 - loss_u2: 0.0016 - loss_i: 2.2721e-04
# Epoch 367/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3501e-04 - loss_u2: 0.0016 - loss_i: 2.2689e-04
# Epoch 368/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3358e-04 - loss_u2: 0.0016 - loss_i: 2.2655e-04
# Epoch 369/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3215e-04 - loss_u2: 0.0016 - loss_i: 2.2619e-04
# Epoch 370/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0040 - loss: 0.0020 - loss_u1: 4.3071e-04 - loss_u2: 0.0016 - loss_i: 2.2581e-04
# Epoch 371/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0039 - loss: 0.0020 - loss_u1: 4.2927e-04 - loss_u2: 0.0015 - loss_i: 2.2541e-04
# Epoch 372/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0039 - loss: 0.0020 - loss_u1: 4.2782e-04 - loss_u2: 0.0015 - loss_i: 2.2500e-04
# Epoch 373/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0039 - loss: 0.0020 - loss_u1: 4.2637e-04 - loss_u2: 0.0015 - loss_i: 2.2457e-04
# Epoch 374/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0039 - loss: 0.0020 - loss_u1: 4.2491e-04 - loss_u2: 0.0015 - loss_i: 2.2413e-04
# Epoch 375/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0039 - loss: 0.0019 - loss_u1: 4.2345e-04 - loss_u2: 0.0015 - loss_i: 2.2368e-04
# Epoch 376/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0039 - loss: 0.0019 - loss_u1: 4.2199e-04 - loss_u2: 0.0015 - loss_i: 2.2321e-04
# Epoch 377/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0039 - loss: 0.0019 - loss_u1: 4.2052e-04 - loss_u2: 0.0015 - loss_i: 2.2272e-04
# Epoch 378/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1905e-04 - loss_u2: 0.0015 - loss_i: 2.2223e-04
# Epoch 379/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1757e-04 - loss_u2: 0.0015 - loss_i: 2.2172e-04
# Epoch 380/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1609e-04 - loss_u2: 0.0015 - loss_i: 2.2121e-04
# Epoch 381/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1461e-04 - loss_u2: 0.0015 - loss_i: 2.2068e-04
# Epoch 382/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1312e-04 - loss_u2: 0.0015 - loss_i: 2.2015e-04
# Epoch 383/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0038 - loss: 0.0019 - loss_u1: 4.1164e-04 - loss_u2: 0.0015 - loss_i: 2.1960e-04
# Epoch 384/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0037 - loss: 0.0019 - loss_u1: 4.1015e-04 - loss_u2: 0.0015 - loss_i: 2.1905e-04
# Epoch 385/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0037 - loss: 0.0019 - loss_u1: 4.0865e-04 - loss_u2: 0.0015 - loss_i: 2.1849e-04
# Epoch 386/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0037 - loss: 0.0019 - loss_u1: 4.0716e-04 - loss_u2: 0.0015 - loss_i: 2.1793e-04
# Epoch 387/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0037 - loss: 0.0019 - loss_u1: 4.0567e-04 - loss_u2: 0.0014 - loss_i: 2.1736e-04
# Epoch 388/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0037 - loss: 0.0018 - loss_u1: 4.0417e-04 - loss_u2: 0.0014 - loss_i: 2.1678e-04
# Epoch 389/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0037 - loss: 0.0018 - loss_u1: 4.0268e-04 - loss_u2: 0.0014 - loss_i: 2.1620e-04
# Epoch 390/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0037 - loss: 0.0018 - loss_u1: 4.0119e-04 - loss_u2: 0.0014 - loss_i: 2.1562e-04
# Epoch 391/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9970e-04 - loss_u2: 0.0014 - loss_i: 2.1503e-04
# Epoch 392/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9821e-04 - loss_u2: 0.0014 - loss_i: 2.1445e-04
# Epoch 393/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9673e-04 - loss_u2: 0.0014 - loss_i: 2.1386e-04
# Epoch 394/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9525e-04 - loss_u2: 0.0014 - loss_i: 2.1328e-04
# Epoch 395/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9377e-04 - loss_u2: 0.0014 - loss_i: 2.1269e-04
# Epoch 396/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9230e-04 - loss_u2: 0.0014 - loss_i: 2.1210e-04
# Epoch 397/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0036 - loss: 0.0018 - loss_u1: 3.9083e-04 - loss_u2: 0.0014 - loss_i: 2.1152e-04
# Epoch 398/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0035 - loss: 0.0018 - loss_u1: 3.8936e-04 - loss_u2: 0.0014 - loss_i: 2.1094e-04
# Epoch 399/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0035 - loss: 0.0018 - loss_u1: 3.8790e-04 - loss_u2: 0.0014 - loss_i: 2.1036e-04
# Epoch 400/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0035 - loss: 0.0018 - loss_u1: 3.8645e-04 - loss_u2: 0.0014 - loss_i: 2.0978e-04
# Epoch 401/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0035 - loss: 0.0018 - loss_u1: 3.8500e-04 - loss_u2: 0.0014 - loss_i: 2.0920e-04
# Epoch 402/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 0.0035 - loss: 0.0017 - loss_u1: 3.8356e-04 - loss_u2: 0.0014 - loss_i: 2.0863e-04
# Epoch 403/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0035 - loss: 0.0017 - loss_u1: 3.8212e-04 - loss_u2: 0.0014 - loss_i: 2.0806e-04
# Epoch 404/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0035 - loss: 0.0017 - loss_u1: 3.8069e-04 - loss_u2: 0.0013 - loss_i: 2.0749e-04
# Epoch 405/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7926e-04 - loss_u2: 0.0013 - loss_i: 2.0692e-04
# Epoch 406/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7784e-04 - loss_u2: 0.0013 - loss_i: 2.0635e-04
# Epoch 407/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7643e-04 - loss_u2: 0.0013 - loss_i: 2.0579e-04
# Epoch 408/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7502e-04 - loss_u2: 0.0013 - loss_i: 2.0523e-04
# Epoch 409/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7362e-04 - loss_u2: 0.0013 - loss_i: 2.0467e-04
# Epoch 410/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7223e-04 - loss_u2: 0.0013 - loss_i: 2.0411e-04
# Epoch 411/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0034 - loss: 0.0017 - loss_u1: 3.7084e-04 - loss_u2: 0.0013 - loss_i: 2.0355e-04
# Epoch 412/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0033 - loss: 0.0017 - loss_u1: 3.6945e-04 - loss_u2: 0.0013 - loss_i: 2.0299e-04
# Epoch 413/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0033 - loss: 0.0017 - loss_u1: 3.6807e-04 - loss_u2: 0.0013 - loss_i: 2.0244e-04
# Epoch 414/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0033 - loss: 0.0017 - loss_u1: 3.6670e-04 - loss_u2: 0.0013 - loss_i: 2.0188e-04
# Epoch 415/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0033 - loss: 0.0017 - loss_u1: 3.6533e-04 - loss_u2: 0.0013 - loss_i: 2.0132e-04
# Epoch 416/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0033 - loss: 0.0016 - loss_u1: 3.6397e-04 - loss_u2: 0.0013 - loss_i: 2.0076e-04
# Epoch 417/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 0.0033 - loss: 0.0016 - loss_u1: 3.6261e-04 - loss_u2: 0.0013 - loss_i: 2.0019e-04
# Epoch 418/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 0.0033 - loss: 0.0016 - loss_u1: 3.6125e-04 - loss_u2: 0.0013 - loss_i: 1.9963e-04
# Epoch 419/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5990e-04 - loss_u2: 0.0013 - loss_i: 1.9906e-04
# Epoch 420/1500
# 10/10 [==============================] - 1s 52ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5855e-04 - loss_u2: 0.0013 - loss_i: 1.9849e-04
# Epoch 421/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5721e-04 - loss_u2: 0.0013 - loss_i: 1.9791e-04
# Epoch 422/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5587e-04 - loss_u2: 0.0013 - loss_i: 1.9732e-04
# Epoch 423/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5453e-04 - loss_u2: 0.0012 - loss_i: 1.9673e-04
# Epoch 424/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5320e-04 - loss_u2: 0.0012 - loss_i: 1.9613e-04
# Epoch 425/1500
# 10/10 [==============================] - 0s 34ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5186e-04 - loss_u2: 0.0012 - loss_i: 1.9552e-04
# Epoch 426/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0032 - loss: 0.0016 - loss_u1: 3.5053e-04 - loss_u2: 0.0012 - loss_i: 1.9491e-04
# Epoch 427/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0031 - loss: 0.0016 - loss_u1: 3.4920e-04 - loss_u2: 0.0012 - loss_i: 1.9427e-04
# Epoch 428/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0031 - loss: 0.0016 - loss_u1: 3.4786e-04 - loss_u2: 0.0012 - loss_i: 1.9363e-04
# Epoch 429/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0031 - loss: 0.0016 - loss_u1: 3.4652e-04 - loss_u2: 0.0012 - loss_i: 1.9297e-04
# Epoch 430/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0031 - loss: 0.0016 - loss_u1: 3.4519e-04 - loss_u2: 0.0012 - loss_i: 1.9229e-04
# Epoch 431/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0031 - loss: 0.0015 - loss_u1: 3.4384e-04 - loss_u2: 0.0012 - loss_i: 1.9158e-04
# Epoch 432/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0031 - loss: 0.0015 - loss_u1: 3.4249e-04 - loss_u2: 0.0012 - loss_i: 1.9085e-04
# Epoch 433/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0031 - loss: 0.0015 - loss_u1: 3.4113e-04 - loss_u2: 0.0012 - loss_i: 1.9009e-04
# Epoch 434/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0031 - loss: 0.0015 - loss_u1: 3.3977e-04 - loss_u2: 0.0012 - loss_i: 1.8930e-04
# Epoch 435/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3839e-04 - loss_u2: 0.0012 - loss_i: 1.8847e-04
# Epoch 436/1500
# 10/10 [==============================] - 0s 36ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3699e-04 - loss_u2: 0.0012 - loss_i: 1.8759e-04
# Epoch 437/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3558e-04 - loss_u2: 0.0012 - loss_i: 1.8666e-04
# Epoch 438/1500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3414e-04 - loss_u2: 0.0012 - loss_i: 1.8567e-04
# Epoch 439/1500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3269e-04 - loss_u2: 0.0012 - loss_i: 1.8462e-04
# Epoch 440/1500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.3121e-04 - loss_u2: 0.0012 - loss_i: 1.8350e-04
# Epoch 441/1500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0030 - loss: 0.0015 - loss_u1: 3.2971e-04 - loss_u2: 0.0011 - loss_i: 1.8231e-04
# Epoch 442/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0029 - loss: 0.0015 - loss_u1: 3.2819e-04 - loss_u2: 0.0011 - loss_i: 1.8107e-04
# Epoch 443/1500
# ...
# Epoch 1413/1500
# 10/10 [==============================] - 0s 48ms/step - loss_adaptive: 8.8487e-04 - loss: 4.4247e-04 - loss_u1: 1.4075e-04 - loss_u2: 3.0172e-04 - loss_i: 1.1822e-04
# Epoch 1414/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 5.9993e-04 - loss: 2.9999e-04 - loss_u1: 1.0812e-04 - loss_u2: 1.9187e-04 - loss_i: 6.9729e-05
# Epoch 1415/1500
# 10/10 [==============================] - 0s 50ms/step - loss_adaptive: 5.4091e-04 - loss: 2.7047e-04 - loss_u1: 8.0832e-05 - loss_u2: 1.8964e-04 - loss_i: 3.2381e-05
# Epoch 1416/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 4.3094e-04 - loss: 2.1549e-04 - loss_u1: 7.3765e-05 - loss_u2: 1.4172e-04 - loss_i: 2.0655e-05
# Epoch 1417/1500
# 10/10 [==============================] - 0s 46ms/step - loss_adaptive: 4.7813e-04 - loss: 2.3908e-04 - loss_u1: 8.4610e-05 - loss_u2: 1.5447e-04 - loss_i: 3.6059e-05
# Epoch 1418/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 5.0643e-04 - loss: 2.5323e-04 - loss_u1: 9.2653e-05 - loss_u2: 1.6058e-04 - loss_i: 5.2271e-05
# Epoch 1419/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 8.7678e-04 - loss: 4.3842e-04 - loss_u1: 1.1657e-04 - loss_u2: 3.2185e-04 - loss_i: 8.6838e-05
# Epoch 1420/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 9.9968e-04 - loss: 4.9987e-04 - loss_u1: 1.0565e-04 - loss_u2: 3.9422e-04 - loss_i: 6.9277e-05
# Epoch 1421/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 6.6500e-04 - loss: 3.3252e-04 - loss_u1: 9.5694e-05 - loss_u2: 2.3683e-04 - loss_i: 5.1463e-05
# Epoch 1422/1500
# 10/10 [==============================] - 1s 59ms/step - loss_adaptive: 8.1310e-04 - loss: 4.0658e-04 - loss_u1: 1.3541e-04 - loss_u2: 2.7117e-04 - loss_i: 1.1233e-04
# Epoch 1423/1500
# 10/10 [==============================] - 1s 72ms/step - loss_adaptive: 5.8340e-04 - loss: 2.9172e-04 - loss_u1: 1.0146e-04 - loss_u2: 1.9026e-04 - loss_i: 6.1471e-05
# Epoch 1424/1500
# 10/10 [==============================] - 1s 56ms/step - loss_adaptive: 5.2425e-04 - loss: 2.6214e-04 - loss_u1: 7.8773e-05 - loss_u2: 1.8337e-04 - loss_i: 2.9767e-05
# Epoch 1425/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 4.2823e-04 - loss: 2.1413e-04 - loss_u1: 7.3848e-05 - loss_u2: 1.4028e-04 - loss_i: 2.1520e-05
# Epoch 1426/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 4.8219e-04 - loss: 2.4111e-04 - loss_u1: 8.5662e-05 - loss_u2: 1.5545e-04 - loss_i: 3.8567e-05
# Epoch 1427/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 5.1364e-04 - loss: 2.5684e-04 - loss_u1: 9.2695e-05 - loss_u2: 1.6414e-04 - loss_i: 5.3494e-05
# Epoch 1428/1500
# 10/10 [==============================] - 0s 48ms/step - loss_adaptive: 9.6817e-04 - loss: 4.8411e-04 - loss_u1: 1.2167e-04 - loss_u2: 3.6244e-04 - loss_i: 9.4707e-05
# Epoch 1429/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 9.0782e-04 - loss: 4.5394e-04 - loss_u1: 9.6292e-05 - loss_u2: 3.5765e-04 - loss_i: 5.6592e-05
# Epoch 1430/1500
# 10/10 [==============================] - 0s 46ms/step - loss_adaptive: 7.3447e-04 - loss: 3.6726e-04 - loss_u1: 1.0798e-04 - loss_u2: 2.5928e-04 - loss_i: 6.7137e-05
# Epoch 1431/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 7.4083e-04 - loss: 3.7044e-04 - loss_u1: 1.2897e-04 - loss_u2: 2.4147e-04 - loss_i: 1.0406e-04
# Epoch 1432/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 5.7128e-04 - loss: 2.8566e-04 - loss_u1: 9.5315e-05 - loss_u2: 1.9035e-04 - loss_i: 5.4610e-05
# Epoch 1433/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 5.0355e-04 - loss: 2.5179e-04 - loss_u1: 7.6797e-05 - loss_u2: 1.7499e-04 - loss_i: 2.7253e-05
# Epoch 1434/1500
# 10/10 [==============================] - 0s 46ms/step - loss_adaptive: 4.3027e-04 - loss: 2.1515e-04 - loss_u1: 7.4443e-05 - loss_u2: 1.4071e-04 - loss_i: 2.3133e-05
# Epoch 1435/1500
# 10/10 [==============================] - 1s 57ms/step - loss_adaptive: 4.8251e-04 - loss: 2.4127e-04 - loss_u1: 8.6206e-05 - loss_u2: 1.5507e-04 - loss_i: 4.0534e-05
# Epoch 1436/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 5.2832e-04 - loss: 2.6418e-04 - loss_u1: 9.2846e-05 - loss_u2: 1.7133e-04 - loss_i: 5.4741e-05
# Epoch 1437/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0011 - loss: 5.3057e-04 - loss_u1: 1.2649e-04 - loss_u2: 4.0408e-04 - loss_i: 1.0230e-04
# Epoch 1438/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 8.0405e-04 - loss: 4.0205e-04 - loss_u1: 8.6958e-05 - loss_u2: 3.1509e-04 - loss_i: 4.4327e-05
# Epoch 1439/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 8.0037e-04 - loss: 4.0021e-04 - loss_u1: 1.1972e-04 - loss_u2: 2.8048e-04 - loss_i: 8.2646e-05
# Epoch 1440/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 6.7993e-04 - loss: 3.3999e-04 - loss_u1: 1.2272e-04 - loss_u2: 2.1727e-04 - loss_i: 9.5141e-05
# Epoch 1441/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 5.5997e-04 - loss: 2.8000e-04 - loss_u1: 8.9589e-05 - loss_u2: 1.9041e-04 - loss_i: 4.8360e-05
# Epoch 1442/1500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 4.8074e-04 - loss: 2.4038e-04 - loss_u1: 7.4865e-05 - loss_u2: 1.6552e-04 - loss_i: 2.4951e-05
# Epoch 1443/1500
# 10/10 [==============================] - 1s 51ms/step - loss_adaptive: 4.3616e-04 - loss: 2.1809e-04 - loss_u1: 7.5497e-05 - loss_u2: 1.4260e-04 - loss_i: 2.5421e-05
# Epoch 1444/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 4.7918e-04 - loss: 2.3961e-04 - loss_u1: 8.6196e-05 - loss_u2: 1.5341e-04 - loss_i: 4.1928e-05
# Epoch 1445/1500
# 10/10 [==============================] - 0s 47ms/step - loss_adaptive: 5.5799e-04 - loss: 2.7901e-04 - loss_u1: 9.3618e-05 - loss_u2: 1.8540e-04 - loss_i: 5.6774e-05
# Epoch 1446/1500
# 10/10 [==============================] - 0s 48ms/step - loss_adaptive: 0.0011 - loss: 5.6206e-04 - loss_u1: 1.2835e-04 - loss_u2: 4.3371e-04 - loss_i: 1.0580e-04
# Epoch 1447/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 6.8998e-04 - loss: 3.4501e-04 - loss_u1: 7.8337e-05 - loss_u2: 2.6667e-04 - loss_i: 3.3493e-05
# Epoch 1448/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 8.5182e-04 - loss: 4.2594e-04 - loss_u1: 1.2805e-04 - loss_u2: 2.9789e-04 - loss_i: 9.5134e-05
# Epoch 1449/1500
# 10/10 [==============================] - 0s 46ms/step - loss_adaptive: 6.4966e-04 - loss: 3.2485e-04 - loss_u1: 1.1919e-04 - loss_u2: 2.0566e-04 - loss_i: 9.0178e-05
# Epoch 1450/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 5.5586e-04 - loss: 2.7795e-04 - loss_u1: 8.5516e-05 - loss_u2: 1.9243e-04 - loss_i: 4.3364e-05
# Epoch 1451/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 4.6261e-04 - loss: 2.3132e-04 - loss_u1: 7.3145e-05 - loss_u2: 1.5818e-04 - loss_i: 2.3191e-05
# Epoch 1452/1500
# 10/10 [==============================] - 0s 50ms/step - loss_adaptive: 4.4471e-04 - loss: 2.2237e-04 - loss_u1: 7.6810e-05 - loss_u2: 1.4556e-04 - loss_i: 2.8026e-05
# Epoch 1453/1500
# 10/10 [==============================] - 1s 52ms/step - loss_adaptive: 4.7818e-04 - loss: 2.3911e-04 - loss_u1: 8.6293e-05 - loss_u2: 1.5281e-04 - loss_i: 4.3490e-05
# Epoch 1454/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 6.0616e-04 - loss: 3.0310e-04 - loss_u1: 9.5659e-05 - loss_u2: 2.0744e-04 - loss_i: 6.0518e-05
# Epoch 1455/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 0.0011 - loss: 5.6038e-04 - loss_u1: 1.2459e-04 - loss_u2: 4.3579e-04 - loss_i: 1.0111e-04
# Epoch 1456/1500
# 10/10 [==============================] - 1s 55ms/step - loss_adaptive: 5.9151e-04 - loss: 2.9577e-04 - loss_u1: 7.2605e-05 - loss_u2: 2.2317e-04 - loss_i: 2.6548e-05
# Epoch 1457/1500
# 10/10 [==============================] - 1s 53ms/step - loss_adaptive: 8.8612e-04 - loss: 4.4309e-04 - loss_u1: 1.3238e-04 - loss_u2: 3.1071e-04 - loss_i: 1.0381e-04
# Epoch 1458/1500
# 10/10 [==============================] - 0s 49ms/step - loss_adaptive: 6.4356e-04 - loss: 3.2180e-04 - loss_u1: 1.1766e-04 - loss_u2: 2.0414e-04 - loss_i: 8.8889e-05
# Epoch 1459/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 5.6597e-04 - loss: 2.8300e-04 - loss_u1: 8.3602e-05 - loss_u2: 1.9940e-04 - loss_i: 4.0358e-05
# Epoch 1460/1500
# 10/10 [==============================] - 0s 48ms/step - loss_adaptive: 4.5277e-04 - loss: 2.2640e-04 - loss_u1: 7.1772e-05 - loss_u2: 1.5462e-04 - loss_i: 2.1993e-05
# Epoch 1461/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 4.5656e-04 - loss: 2.2829e-04 - loss_u1: 7.8399e-05 - loss_u2: 1.4990e-04 - loss_i: 3.0949e-05
# Epoch 1462/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 4.8358e-04 - loss: 2.4180e-04 - loss_u1: 8.7106e-05 - loss_u2: 1.5470e-04 - loss_i: 4.5940e-05
# Epoch 1463/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 6.5824e-04 - loss: 3.2914e-04 - loss_u1: 9.8168e-05 - loss_u2: 2.3097e-04 - loss_i: 6.4809e-05
# Epoch 1464/1500
# 10/10 [==============================] - 0s 48ms/step - loss_adaptive: 0.0011 - loss: 5.2964e-04 - loss_u1: 1.1664e-04 - loss_u2: 4.1300e-04 - loss_i: 9.0103e-05
# Epoch 1465/1500
# 10/10 [==============================] - 0s 49ms/step - loss_adaptive: 5.4068e-04 - loss: 2.7035e-04 - loss_u1: 7.1383e-05 - loss_u2: 1.9897e-04 - loss_i: 2.5264e-05
# Epoch 1466/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 8.9799e-04 - loss: 4.4902e-04 - loss_u1: 1.3393e-04 - loss_u2: 3.1509e-04 - loss_i: 1.0871e-04
# Epoch 1467/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 6.4072e-04 - loss: 3.2038e-04 - loss_u1: 1.1549e-04 - loss_u2: 2.0489e-04 - loss_i: 8.6874e-05
# Epoch 1468/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 5.8584e-04 - loss: 2.9294e-04 - loss_u1: 8.3097e-05 - loss_u2: 2.0984e-04 - loss_i: 3.9383e-05
# Epoch 1469/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 4.5026e-04 - loss: 2.2514e-04 - loss_u1: 7.0840e-05 - loss_u2: 1.5430e-04 - loss_i: 2.1391e-05
# Epoch 1470/1500
# 10/10 [==============================] - 0s 50ms/step - loss_adaptive: 4.7159e-04 - loss: 2.3581e-04 - loss_u1: 8.0164e-05 - loss_u2: 1.5564e-04 - loss_i: 3.4129e-05
# Epoch 1471/1500
# 10/10 [==============================] - 0s 39ms/step - loss_adaptive: 4.9342e-04 - loss: 2.4673e-04 - loss_u1: 8.8390e-05 - loss_u2: 1.5834e-04 - loss_i: 4.8926e-05
# Epoch 1472/1500
# 10/10 [==============================] - 0s 38ms/step - loss_adaptive: 6.9100e-04 - loss: 3.4552e-04 - loss_u1: 9.9376e-05 - loss_u2: 2.4614e-04 - loss_i: 6.7128e-05
# Epoch 1473/1500
# 10/10 [==============================] - 1s 52ms/step - loss_adaptive: 9.9289e-04 - loss: 4.9647e-04 - loss_u1: 1.0948e-04 - loss_u2: 3.8699e-04 - loss_i: 8.0066e-05
# Epoch 1474/1500
# 10/10 [==============================] - 0s 41ms/step - loss_adaptive: 5.2738e-04 - loss: 2.6370e-04 - loss_u1: 7.2229e-05 - loss_u2: 1.9148e-04 - loss_i: 2.6633e-05
# Epoch 1475/1500
# 10/10 [==============================] - 0s 49ms/step - loss_adaptive: 8.9345e-04 - loss: 4.4675e-04 - loss_u1: 1.3369e-04 - loss_u2: 3.1306e-04 - loss_i: 1.1001e-04
# Epoch 1476/1500
# 10/10 [==============================] - 0s 47ms/step - loss_adaptive: 6.3724e-04 - loss: 3.1864e-04 - loss_u1: 1.1297e-04 - loss_u2: 2.0567e-04 - loss_i: 8.4122e-05
# Epoch 1477/1500
# 10/10 [==============================] - 1s 52ms/step - loss_adaptive: 6.0497e-04 - loss: 3.0250e-04 - loss_u1: 8.3015e-05 - loss_u2: 2.1949e-04 - loss_i: 3.9574e-05
# Epoch 1478/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 4.5293e-04 - loss: 2.2648e-04 - loss_u1: 7.0226e-05 - loss_u2: 1.5625e-04 - loss_i: 2.1311e-05
# Epoch 1479/1500
# 10/10 [==============================] - 0s 49ms/step - loss_adaptive: 4.8811e-04 - loss: 2.4407e-04 - loss_u1: 8.1775e-05 - loss_u2: 1.6229e-04 - loss_i: 3.7199e-05
# Epoch 1480/1500
# 10/10 [==============================] - 0s 43ms/step - loss_adaptive: 5.0467e-04 - loss: 2.5235e-04 - loss_u1: 8.9501e-05 - loss_u2: 1.6285e-04 - loss_i: 5.1500e-05
# Epoch 1481/1500
# 10/10 [==============================] - 0s 37ms/step - loss_adaptive: 6.9898e-04 - loss: 3.4951e-04 - loss_u1: 9.8613e-05 - loss_u2: 2.5089e-04 - loss_i: 6.6598e-05
# Epoch 1482/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 9.3876e-04 - loss: 4.6940e-04 - loss_u1: 1.0424e-04 - loss_u2: 3.6517e-04 - loss_i: 7.2935e-05
# Epoch 1483/1500
# 10/10 [==============================] - 0s 44ms/step - loss_adaptive: 5.2004e-04 - loss: 2.6003e-04 - loss_u1: 7.2214e-05 - loss_u2: 1.8782e-04 - loss_i: 2.7050e-05
# Epoch 1484/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 8.9210e-04 - loss: 4.4607e-04 - loss_u1: 1.3266e-04 - loss_u2: 3.1342e-04 - loss_i: 1.0947e-04
# Epoch 1485/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 6.4429e-04 - loss: 3.2217e-04 - loss_u1: 1.1243e-04 - loss_u2: 2.0974e-04 - loss_i: 8.4412e-05
# Epoch 1486/1500
# 10/10 [==============================] - 0s 47ms/step - loss_adaptive: 6.2619e-04 - loss: 3.1311e-04 - loss_u1: 8.3671e-05 - loss_u2: 2.2944e-04 - loss_i: 4.0792e-05
# Epoch 1487/1500
# 10/10 [==============================] - 1s 53ms/step - loss_adaptive: 4.6158e-04 - loss: 2.3080e-04 - loss_u1: 6.9755e-05 - loss_u2: 1.6105e-04 - loss_i: 2.1514e-05
# Epoch 1488/1500
# 10/10 [==============================] - 0s 42ms/step - loss_adaptive: 5.0743e-04 - loss: 2.5373e-04 - loss_u1: 8.3181e-05 - loss_u2: 1.7055e-04 - loss_i: 4.0086e-05
# Epoch 1489/1500
# 10/10 [==============================] - 1s 52ms/step - loss_adaptive: 5.1956e-04 - loss: 2.5979e-04 - loss_u1: 9.0491e-05 - loss_u2: 1.6930e-04 - loss_i: 5.3760e-05
# Epoch 1490/1500
# 10/10 [==============================] - 1s 51ms/step - loss_adaptive: 6.8823e-04 - loss: 3.4413e-04 - loss_u1: 9.6026e-05 - loss_u2: 2.4811e-04 - loss_i: 6.3466e-05
# Epoch 1491/1500
# 10/10 [==============================] - 1s 51ms/step - loss_adaptive: 8.7518e-04 - loss: 4.3761e-04 - loss_u1: 9.8572e-05 - loss_u2: 3.3904e-04 - loss_i: 6.5440e-05
# Epoch 1492/1500
# 10/10 [==============================] - 1s 63ms/step - loss_adaptive: 5.0720e-04 - loss: 2.5362e-04 - loss_u1: 7.1001e-05 - loss_u2: 1.8261e-04 - loss_i: 2.6081e-05
# Epoch 1493/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 9.0220e-04 - loss: 4.5112e-04 - loss_u1: 1.3101e-04 - loss_u2: 3.2011e-04 - loss_i: 1.0808e-04
# Epoch 1494/1500
# 10/10 [==============================] - 0s 45ms/step - loss_adaptive: 6.7150e-04 - loss: 3.3577e-04 - loss_u1: 1.1499e-04 - loss_u2: 2.2078e-04 - loss_i: 8.9646e-05
# Epoch 1495/1500
# 10/10 [==============================] - 0s 46ms/step - loss_adaptive: 6.6026e-04 - loss: 3.3015e-04 - loss_u1: 8.5937e-05 - loss_u2: 2.4421e-04 - loss_i: 4.3677e-05
# Epoch 1496/1500
# 10/10 [==============================] - 0s 40ms/step - loss_adaptive: 4.8067e-04 - loss: 2.4035e-04 - loss_u1: 6.9441e-05 - loss_u2: 1.7091e-04 - loss_i: 2.1995e-05
# Epoch 1497/1500
# 10/10 [==============================] - 1s 54ms/step - loss_adaptive: 5.3806e-04 - loss: 2.6905e-04 - loss_u1: 8.5035e-05 - loss_u2: 1.8401e-04 - loss_i: 4.3695e-05
# Epoch 1498/1500
# 10/10 [==============================] - 1s 61ms/step - loss_adaptive: 5.4875e-04 - loss: 2.7439e-04 - loss_u1: 9.2371e-05 - loss_u2: 1.8202e-04 - loss_i: 5.7314e-05
# Epoch 1499/1500
# 10/10 [==============================] - 1s 55ms/step - loss_adaptive: 6.6509e-04 - loss: 3.3256e-04 - loss_u1: 9.1643e-05 - loss_u2: 2.4092e-04 - loss_i: 5.7735e-05
# Epoch 1500/1500
# 10/10 [==============================] - 0s 47ms/step - loss_adaptive: 7.7365e-04 - loss: 3.8684e-04 - loss_u1: 8.9499e-05 - loss_u2: 2.9734e-04 - loss_i: 5.3183e-05

# %%
couple_model.alpha1
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=4.648054978937277>

# %%
'''
u1_i = u1(X_i_train[:,0],X_i_train[:,1],X_i_train[:,2])
u2_i = u2(X_i_train[:,0],X_i_train[:,1],X_i_train[:,2])
u1_i = u1_i.reshape((u1_i.shape[0],1))
u2_i = u1_i.reshape((u2_i.shape[0],1))

X_u1_train_ = tf.concat([X_u1_train,X_i_train],axis=0)
X_u2_train_ = tf.concat([X_u2_train,X_i_train],axis=0)
u1_train_ = tf.concat([u1_train,u1_i],axis=0)
u2_train_ = tf.concat([u2_train,u2_i],axis=0) 
'''

# %%
"""history_u1 = model_u1.fit(
    X_u1_train,
    u1_train,
    batch_size=64,
    epochs=10,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    #validation_data=(x_val, y_val),
)
history_u2 = model_u2.fit(
    X_u2_train,
    u2_train,
    batch_size=64,
    epochs=10,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    #validation_data=(x_val, y_val),
)"""

# %% [markdown]
# # Plot

# %%
U1_pred = pred_data(X_u1,Y_u1,T_u1,model_u1)
U2_pred = pred_data(X_u2,Y_u2,T_u2,model_u2)
####################################################
plt.figure(1) 
ax1 = plt.axes(projection="3d")
ax1.patch.set_facecolor("white")   #设置 axes 背景颜色

ax1.plot_surface(X_u1,Y_u1,U1,alpha=0.9) #生成曲面z，alpha调节透明度，cmap调节曲面色调
ax1.plot_surface(X_u2,Y_u2,U2,alpha=0.9)

ax1.set_xlabel("X")   
ax1.set_ylabel("Y")
ax1.set_zlabel("U")
ax1.set_title("Real U")
######################################################
plt.figure(2) 
ax2 = plt.axes(projection="3d")
ax2.patch.set_facecolor("white") 

### u1
ax2.plot_surface(X_u1,Y_u1,U1_pred,alpha=0.9)

###u2
ax2.plot_surface(X_u2,Y_u2,U2_pred,alpha=0.9)

ax2.set_xlabel("X")   
ax2.set_ylabel("Y")
ax2.set_zlabel("U")
ax2.set_title("Pred U")
###############################
plt.show()

# %%
u1_real = U1.numpy().flatten()
u1_pred = U1_pred.numpy().flatten()
u2_real = U2.numpy().flatten()
u2_pred = U2_pred.numpy().flatten()

error_u1 = np.linalg.norm((u1_real-u1_pred),2)/np.linalg.norm(u1_real,2)  
print('Test Error For u1:  %.5f'  % (error_u1))

error_u2 = np.linalg.norm((u2_real-u2_pred),2)/np.linalg.norm(u2_real,2)  
print('Test Error For u2:  %.5f'  % (error_u2))
# Out:
# Test Error For u1:  0.06296
# Test Error For u2:  0.02420
