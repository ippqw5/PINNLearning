# %% [markdown]
# <img src="./Data/公式.png" style="zoom:50%;" />

# %% [markdown]
# # Import

# %%
pip install pyDOE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.7.3)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=26bca8a4745d809e86864f1598df39b7aed19deda2f6c1c5d55692b47d63196a
#   Stored in directory: /root/.cache/pip/wheels/83/ce/8a/87b25c685bfeca1872d13b8dc101e087a9c6e3fb5ebb47022a
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
from sympy import*
import numpy as np
from pyDOE import lhs         #Latin Hypercube Sampling
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   
import tensorflow as tf
from tensorflow import keras
import tensorflow_probability as tfp #TFP needs TF>= 2.3
import time

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Setting

# %%
x = symbols('x')
y = symbols('y')
t = symbols('t')

a = v1 = v2 = k =1 #a=4 ,v1=5,v2=10,k=1/4
c1 = 1 + v1/k ;c2 = -v1/v2;c3 = c2 - c1
g1 = g2 =0

u1 = a*x*(1-x)*(1-y)*exp(-t)
u2 = a*x*(1-x)*(c1 + c2*y + c3*y**2)*exp(-t)

f1 = diff(u1,t) - v1*( diff(u1,x,2) + diff(u1,y,2))
f2 = diff(u2,t) - v2*( diff(u2,x,2) + diff(u2,y,2))

u1 = lambdify((x,y,t),u1)
u2 = lambdify((x,y,t),u2)

f1 = lambdify((x,y,t),f1,'tensorflow')
f2 = lambdify((x,y,t),f2,'tensorflow')

# %% [markdown]
# # TrainingData & TestData

# %%
def trainingdata(N_u,N_f,N_i,omga,u,interface):    
    '''
      x1 = x,  x2 = y
      interface = 0, 则x2_range[0] 作为 interface ； interfacer = 1 则 x2_range[1]作为interface
    
      Return: X_u_train (N_u x 3),u_train (N_u x 1), X_f_train (N_f x 3), X_i_train (N_i x 3)
    '''
    x1_range = omga[0]
    x2_range = omga[1]
    t_range = [0.,1.]
    
    # Initial Condition t=0 , x1_range[0]<= x1 <= x_range[1] , x2_range[0] <= x2 <= x2_range[1]
    initial_X = np.ones((N_u,3))
    initial_X[:,0] = np.random.rand(N_u) * (x1_range[1] - x1_range[0]) + x1_range[0]
    initial_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    initial_X[:,2] = initial_X[:,2] * t_range[0]
    #initial_u = np.ones((N_u,1))
    initial_u = u(initial_X[:,0], initial_X[:,1], initial_X[:,2])
    initial_u = initial_u.reshape(-1,1)


    # BC_left: x1=x1_range[0], 0<=t<=1, x2_range[0] <= x2 <= x2_range[1]
    leftedge_X = np.ones(shape=(N_u,3))
    leftedge_X[:,0] = leftedge_X[:,0] * x1_range[0]
    leftedge_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    leftedge_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    leftedge_u = np.ones(shape=(N_u,1))
    leftedge_u = u(leftedge_X[:,0], leftedge_X[:,1], leftedge_X[:,2])
    leftedge_u = leftedge_u.reshape(-1,1)
    
    # BC_right: x1=x1_range[1], 0<=t<=1, x2_range[0] <= x2 <= x2_range[1]
    rightedge_X = np.ones(shape=(N_u,3))
    rightedge_X[:,0] = rightedge_X[:,0] * x1_range[1]
    rightedge_X[:,1] = np.random.rand(N_u) * (x2_range[1] - x2_range[0]) + x2_range[0]
    rightedge_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    rightedge_u = np.ones(shape=(N_u,1))
    rightedge_u = u(rightedge_X[:,0], rightedge_X[:,1], rightedge_X[:,2])
    rightedge_u = rightedge_u.reshape(-1,1)

    # BC_top or BC_bottom ,depends on interface. x2 = x2_range[bc], 0<=t<=1 ,x1_range[0]<= x1 <= x_range[1]
    bc = (interface+1)%2
    BC_X = np.ones(shape=(N_u,3))
    BC_X[:,0] = np.random.rand(N_u) * (x1_range[1] - x1_range[0]) + x1_range[0]
    BC_X[:,1] = BC_X[:,1] * x2_range[bc]
    BC_X[:,2] = np.random.rand(N_u) * (t_range[1] - t_range[0]) + t_range[0]
    BC_u = np.ones(shape=(N_u,1))
    BC_u = u(BC_X[:,0], BC_X[:,1], BC_X[:,2])
    BC_u = BC_u.reshape(-1,1)
    
    all_X_u_train =  np.vstack([initial_X,leftedge_X,rightedge_X,BC_X])
    all_u_train = np.vstack([initial_u,leftedge_u,rightedge_u,BC_u])
    
    idx = np.random.choice(all_X_u_train.shape[0],all_X_u_train.shape[0], replace=False) 
    
    X_u_train = all_X_u_train[idx,:]
    u_train = all_u_train[idx,:]
    
    # BC_interface: x2 = x2_range[interface], 0<=t<=1 ,x1_range[0]<= x1 <= x_range[1]
    X_i_train = np.ones(shape=(N_i,3))
    X_i_train[:,0] = np.random.rand(N_i) * (x1_range[1] - x1_range[0]) + x1_range[0]
    X_i_train[:,1] = X_i_train[:,1] * x2_range[interface]
    X_i_train[:,2] = np.random.rand(N_i) * (t_range[1] - t_range[0]) + t_range[0]     
            
            
    '''Collocation Points'''
    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x1,x2,t)
    lb = np.array([x1_range[0],x2_range[0],t_range[0]])
    ub = np.array([x1_range[1],x2_range[1],t_range[1]])
    X_f_train = lb + (ub-lb)*lhs(3,N_f) 
    #X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    
    return X_u_train,u_train,X_f_train,X_i_train

def ds_train_n_batch(X_u1_train,u1_train,X_f1_train,X_u2_train,u2_train,X_f2_train,X_i_train,n = 5):
    batch_u1 = int(len(X_u1_train)/n) # = int(len(u1_train)/n)
    batch_f1 = int(len(X_f1_train)/n)

    batch_u2 = int(len(X_u2_train)/n) # = int(len(u2_train)/n)
    batch_f2 = int(len(X_f2_train)/n)
    
    batch_i = int(len(X_i_train)/n)
    
    ds_u1 = tf.data.Dataset.from_tensor_slices( ((X_u1_train,u1_train)) ).batch( batch_u1 )
    ds_f1 = tf.data.Dataset.from_tensor_slices( X_f1_train ).batch( batch_f1 )
    
    ds_u2 = tf.data.Dataset.from_tensor_slices( ((X_u2_train,u2_train)) ).batch( batch_u2 )
    ds_f2 = tf.data.Dataset.from_tensor_slices( X_f2_train ).batch( batch_f2 )
    
    ds_i = tf.data.Dataset.from_tensor_slices(X_i_train).batch(batch_i)

    ds = tf.data.Dataset.zip((ds_u1,ds_f1,ds_u2,ds_f2,ds_i))
    return ds

# %%
omga1 = [[0.,1.],[0.,1.]]  # (x,y)的取值范围 
omga2 = [[0.,1.],[-1.,0.]] 
def test_data(N,omga,u,t=1.):
  # Output: X,Y,T,U shape=(N,N)
  x_range = tf.linspace(omga[0][0],omga[0][1],N)
  y_range = tf.linspace(omga[1][0],omga[1][1],N)

  X,Y = tf.meshgrid(x_range,y_range)
  T = tf.ones(shape=X.shape)*t
  U = u(X,Y,T)
  return X,Y,T,U

def pred_data(X,Y,T,model):
  #Input: X,Y,T shape=(N,N)
  #Output: U_pred shape=(N,N)
  Shape = X.shape
  dim = len(Shape)
  X = tf.reshape(X,shape=(Shape[0]**dim,1))
  Y = tf.reshape(Y,shape=(Shape[0]**dim,1))
  T = tf.reshape(T,shape=(Shape[0]**dim,1))

  Inputs = tf.concat([X,Y,T],axis=1)
  U_pred = model(Inputs)
  U_pred = tf.reshape(U_pred,shape=Shape)
  return U_pred

# %% [markdown]
# # PINN Model

# %% [markdown]
# ## Model Define

# %%
class MyPinn(keras.Sequential): 
    def __init__(self,Layers,v,n,k,f,name = None): #Layers=[3,20,20,1]
        super(MyPinn, self).__init__(name=name)
        self.add(keras.Input(shape=(Layers[0],) ,dtype=tf.float64))
        for i in range(1,len(Layers)-1):
            self.add(keras.layers.Dense(Layers[i], dtype=tf.float64, activation='tanh'))
        self.add(keras.layers.Dense(Layers[-1],dtype=tf.float64, name="outputs"))
        self.v = tf.constant(v,dtype=tf.float64)
        self.n = tf.constant(n,dtype=tf.float64)
        self.k = tf.constant(k,dtype=tf.float64)
        self.f = f
        
    @tf.function
    def loss_U(self,X_u_train,u_train):
        u= self(X_u_train)
        loss_u = tf.reduce_mean(tf.square(u_train - u))
        return loss_u
    #   
    @tf.function
    def loss_PDE(self,X_f_train):
        x = X_f_train[:,0:1]
        y = X_f_train[:,1:2]
        t = X_f_train[:,2:3]
        with tf.GradientTape(persistent=True) as tape:
            tape.watch([x,y,t])
            X = tf.stack([x[:,0],y[:,0],t[:,0]],axis=1)
            u = self(X)  
            u_x = tape.gradient(u,x)
            u_y = tape.gradient(u,y)
            #u_t = tape.gradient(u,t)
        #tf.print(u_x)    
        u_t = tape.gradient(u, t)     
        u_xx = tape.gradient(u_x, x)
        u_yy = tape.gradient(u_y, y)

        del tape
      
        loss_f = u_t - self.v *(u_xx + u_yy) - self.f(x,y,t)
        loss_f = tf.reduce_mean(tf.square(loss_f))
        return loss_f
    """以下为单区域PINN 训练方法"""    
    @tf.function
    def train_loop(self,X_u_train,u_train,X_f_train):
      with tf.GradientTape() as tape:
        loss = self.loss_U(X_u_train,u_train) + self.loss_PDE(X_f_train)
      gradients = tape.gradient(loss,self.trainable_variables)
      self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

      return loss

    def train(self,X_u_train,u_train,X_f_train,epochs=200):
      for epoch in tf.range(1,epochs+1):
          loss = self.train_loop(X_u_train,u_train,X_f_train)
          if epoch % 50 == 0:                
              tf.print(
                  "Training loss (for per 10 epoches) at epoch ",epoch,":",loss
              )

# %%
class CouplePinn(keras.Model):
  def __init__(self,model_1,model_2,name=None):
    super(CouplePinn,self).__init__(name=name)
    self.m1 = model_1 
    self.m2 = model_2
    
    # Metrics
    self.loss_tracker = keras.metrics.Mean(name="loss")
    self.loss_adaptive = keras.metrics.Mean(name="loss_adaptive")
    self.loss_u1 = keras.metrics.Mean(name="loss_u1")
    self.loss_u2 = keras.metrics.Mean(name="loss_u2")
    self.loss_i = keras.metrics.Mean(name="loss_i")

    # Self-Adaptive factors     
    self.alpha1 = tf.Variable(0.0, dtype = tf.float64, trainable = True)     
    self.alpha2 = tf.Variable(0.0, dtype = tf.float64, trainable = True)
    #self.alpha_i = tf.Variable(1.0, dtype = tf.float64, trainable = True)

    self.optimizer_alpha = keras.optimizers.Adam(learning_rate=0.05)
    #self.optimizer_alpha_m2 = keras.optimizers.Adam(learning_rate=0.001)
    #self.optimizer_alpha_i = keras.optimizers.Adam(learning_rate=0.001)
  @property
  def metrics(self):
      # We list our `Metric` objects here so that `reset_states()` can be
      # called automatically at the start of each epoch
      # or at the start of `evaluate()`.
      # If you don't implement this property, you have to call
      # `reset_states()` yourself at the time of your choosing.
      return [self.loss_adaptive,self.loss_tracker,self.loss_u1,self.loss_u2,self.loss_i] 


  """ 交界处损失函数 """
  @tf.function
  def loss_I(self,X_i_train):
      x = X_i_train[:,0:1]
      y = X_i_train[:,1:2]
      t = X_i_train[:,2:3]
      
      with tf.GradientTape(persistent=True) as tape:
          tape.watch([x,y,t])
          X = tf.stack([x[:,0],y[:,0],t[:,0]],axis=1)
          U1 = self.m1(X)
          U2 = self.m2(X)
      
      U1_x = tape.gradient(U1, x)
      U1_y = tape.gradient(U1, y)
      U2_x = tape.gradient(U2, x)
      U2_y = tape.gradient(U2, y)

      del tape
      
      loss_i1 = -self.m1.v * ( U1_x*self.m1.n[0] + U1_y*self.m1.n[1]) - self.m1.k * (U1-U2)
      loss_i2 = -self.m2.v * ( U2_x*self.m2.n[0] + U2_y*self.m2.n[1]) - self.m2.k * (U2-U1)

      loss_i1 = tf.reduce_mean(tf.square(loss_i1)) 
      loss_i2 = tf.reduce_mean(tf.square(loss_i2))

      return loss_i1,loss_i2
  @tf.function
  def loss_Total(self,X_u_train,u_train,X_f_train,X_i_train):
    (X_u1_train,X_u2_train) = X_u_train
    (u1_train,u2_train) = u_train
    (X_f1_train,X_f2_train) = X_f_train
    
    loss_m1 = self.m1.loss_U(X_u1_train,u1_train) + self.m1.loss_PDE(X_f1_train)
    loss_m2 = self.m2.loss_U(X_u2_train,u2_train) + self.m2.loss_PDE(X_f2_train)
    loss_i1,loss_i2 = self.loss_I(X_i_train)
    return (loss_m1+loss_i1) + (loss_m2+loss_i2)

  """耦合区域 PINN训练方法"""
  @tf.function
  def train_step(self,data):
      (X_u1_train,u1_train),X_f1_train,(X_u2_train,u2_train),X_f2_train,X_i_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss_m1 = self.m1.loss_U(X_u1_train,u1_train) + self.m1.loss_PDE(X_f1_train)
          loss_m2 = self.m2.loss_U(X_u2_train,u2_train) + self.m2.loss_PDE(X_f2_train)
          loss_i1,loss_i2 = self.loss_I(X_i_train)

          a1 = tf.math.sigmoid(2*self.alpha1+0.5) * 2
          a2 = tf.math.sigmoid(2*self.alpha2+0.5) * 2
          loss_adaptive = a1*(loss_m1+loss_i1) + a2*(loss_m2+loss_i2)
          #loss_adaptive = (loss_m1+loss_i1) + (loss_m2+loss_i2)

      loss = loss_m1 + loss_m2 + loss_i1 + loss_i2
      # Compute gradients
      gradients_m1 = tape.gradient(loss_adaptive,self.m1.trainable_variables)
      gradients_m2 = tape.gradient(loss_adaptive,self.m2.trainable_variables)
      gradient_a1pha1 = -tape.gradient(loss_adaptive,self.alpha1)
      gradient_alpha2 = -tape.gradient(loss_adaptive,self.alpha2)

      del tape

      # Updata parameters
      self.m1.optimizer.apply_gradients(zip(gradients_m1, self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_m2, self.m2.trainable_variables))
      self.optimizer_alpha.apply_gradients( zip([gradient_a1pha1,gradient_alpha2], [self.alpha1,self.alpha2]) )

      # Updata Metric
      self.loss_adaptive.update_state(loss_adaptive)
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_m1+loss_i1)
      self.loss_u2.update_state(loss_m2+loss_i2)
      self.loss_i.update_state(loss_i1+loss_i2)

      return {m.name : m.result() for m in self.metrics}

# %% [markdown]
# ## function factory

# %%
def function_factory(model,loss,X_u_train,u_train,X_f_train,X_i_train):
    """A factory to create a function required by tfp.optimizer.lbfgs_minimize.
    Args:
        model [in]: an instance of `tf.keras.Model` or its subclasses.
        loss [in]: a loss function in model
    Returns:
        A function that has a signature of:
            loss_value, gradients = f(model_parameters).
    """

    # obtain the shapes of all trainable parameters in the model
    shapes = [tf.shape_n(model.m1.trainable_variables),tf.shape_n(model.m2.trainable_variables)]
    n_tensors = [len(shapes[0]),len(shapes[1])]

    # we'll use tf.dynamic_stitch and tf.dynamic_partition later, so we need to
    # prepare required information first
    count = [0,0]
    idx = [[],[]] # stitch indices
    part = [[],[]] # partition indices

    for i,shapes_i in enumerate(shapes):
      for j, shape in enumerate(shapes_i):
          n = np.product(shape)
          idx[i].append(tf.reshape(tf.range(count[i], count[i]+n, dtype=tf.int32), shape))
          part[i].extend([j]*n)
          count[i] += n

    part = [ tf.constant(part[0]), tf.constant(part[1]) ]

    @tf.function
    def assign_new_model_parameters(params_1d):
        """A function updating the model's parameters with a 1D tf.Tensor.
        Args:
            params_1d [in]: a 1D tf.Tensor representing the model's trainable parameters.
        """
        count0 = count[0]
        count1 = count[1]

        params0 = tf.dynamic_partition(params_1d[0:count0], part[0], n_tensors[0])
        for i, (shape, param) in enumerate(zip(shapes[0], params0)):
            model.m1.trainable_variables[i].assign(tf.reshape(param, shape))
        
        params1 = tf.dynamic_partition(params_1d[count0:count0+count1], part[1], n_tensors[1])
        for i, (shape, param) in enumerate(zip(shapes[1], params1)):
            model.m2.trainable_variables[i].assign(tf.reshape(param, shape))
        '''
        num = 0
        for k in tf.range(0,2):
          params = tf.dynamic_partition(params_1d[num:num+count[k]], part[k], n_tensors[k])
          for i, (shape, param) in enumerate(zip(shapes, params)):
            model.m[k].trainable_variables[i].assign(tf.reshape(param, shape))
          num += count[k]
        '''
    # now create a function that will be returned by this factory
    @tf.function
    def f(params_1d):
        """A function that can be used by tfp.optimizer.lbfgs_minimize.
        This function is created by function_factory.
        Args:
           params_1d [in]: a 1D tf.Tensor.
        Returns:
            A scalar loss and the gradients w.r.t. the `params_1d`.
        """

        # use GradientTape so that we can calculate the gradient of loss w.r.t. parameters
        with tf.GradientTape(persistent=True) as tape:
            # update the parameters in the model
            assign_new_model_parameters(params_1d)
            # calculate the loss
            loss_total = loss(X_u_train,u_train,X_f_train,X_i_train)

        # calculate gradients and convert to 1D tf.Tensor
        grads_m1 = tape.gradient(loss_total, model.m1.trainable_variables)
        grads_m2 = tape.gradient(loss_total, model.m2.trainable_variables)

        grads_m1 = tf.dynamic_stitch(idx[0], grads_m1)
        grads_m2 = tf.dynamic_stitch(idx[1], grads_m2)

        grads = tf.concat([grads_m1,grads_m2],axis=0)
        
        del tape

        # print out iteration & loss
        f.iter.assign_add(1)
        if (f.iter % 50 == 0) :
          tf.print("Iter:", f.iter, "loss:", loss_total)

        # store loss value so we can retrieve later
        tf.py_function(f.history.append, inp=[loss_total], Tout=[])

        return loss_total, grads

    # store these information as members so we can use them outside the scope
    f.iter = tf.Variable(0)
    f.idx = idx
    f.part = part
    f.shapes = shapes
    f.assign_new_model_parameters = assign_new_model_parameters
    f.history = []
    f.count = count
    return f

# %% [markdown]
# # Train

# %%
""" Training Data """
n1 = [0.,-1.]
n2 = [0.,1.]

omga1 = [[0.,1.],[0.,1.]]  # (x,y)的取值范围 
omga2 = [[0.,1.],[-1.,0.]] 

N_i = 200

N_u1 = 200; N_f1 = 2000  ;omga = omga1; interface=0; u = u1
X_u1_train,u1_train,X_f1_train,X_i_train= trainingdata(N_u1,N_f1,N_i,omga,u,interface)


N_u2 = 200; N_f2= 2000 ; omga = omga2; interface=1; u = u2
X_u2_train,u2_train,X_f2_train,X_i_train= trainingdata(N_u2,N_f2,N_i,omga,u,interface)

""" Test Data """
N = 100
X_u1,Y_u1,T_u1,U1 = test_data(N,omga1,u1,t=1.0)
X_u2,Y_u2,T_u2,U2 = test_data(N,omga2,u2,t=1.0)

# %%
Layers=[3,20,20,20,20,1]
model_u1 = MyPinn(Layers,v1,n1,k,f1,name="model_1")
model_u1.compile(optimizer=keras.optimizers.Adam())

model_u2 = MyPinn(Layers,v2,n2,k,f2,name="model_2")
model_u2.compile(optimizer=keras.optimizers.Adam())

ds = ds_train_n_batch(X_u1_train, u1_train , X_f1_train , X_u2_train , u2_train , X_f2_train , X_i_train ,n = 10)

# %%
model_u1.train(X_u1_train,u1_train,X_f1_train,epochs=200) #单区域PINN训练
model_u2.train(X_u2_train,u2_train,X_f2_train,epochs=200) #单区域PINN训练
# Out:
# Training loss (for per 10 epoches) at epoch  50 : 0.04389884782956998
# Training loss (for per 10 epoches) at epoch  100 : 0.017933608467324468
# Training loss (for per 10 epoches) at epoch  150 : 0.010973849891651767
# Training loss (for per 10 epoches) at epoch  200 : 0.00832521649979497
# Training loss (for per 10 epoches) at epoch  50 : 0.80525135569436324
# Training loss (for per 10 epoches) at epoch  100 : 0.46217011814903053
# Training loss (for per 10 epoches) at epoch  150 : 0.32408977623153662
# Training loss (for per 10 epoches) at epoch  200 : 0.23416002018285631

# %%
couple_model = CouplePinn(model_u1,model_u2) 
couple_model.compile()

# %%
couple_model.fit(ds,epochs=500) #耦合PINN训练 Adam
# Out:
# Epoch 1/500
# 10/10 [==============================] - 30s 26ms/step - loss_adaptive: 0.9861 - loss: 0.7021 - loss_u1: 0.1433 - loss_u2: 0.5588 - loss_i: 0.3987
# Epoch 2/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.8116 - loss: 0.4781 - loss_u1: 0.1048 - loss_u2: 0.3733 - loss_i: 0.1237
# Epoch 3/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.7154 - loss: 0.3906 - loss_u1: 0.0648 - loss_u2: 0.3257 - loss_i: 0.0980
# Epoch 4/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.6090 - loss: 0.3227 - loss_u1: 0.0583 - loss_u2: 0.2644 - loss_i: 0.0963
# Epoch 5/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.4970 - loss: 0.2598 - loss_u1: 0.0555 - loss_u2: 0.2043 - loss_i: 0.0681
# Epoch 6/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.3951 - loss: 0.2050 - loss_u1: 0.0495 - loss_u2: 0.1555 - loss_i: 0.0519
# Epoch 7/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.3194 - loss: 0.1652 - loss_u1: 0.0512 - loss_u2: 0.1140 - loss_i: 0.0423
# Epoch 8/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.2758 - loss: 0.1422 - loss_u1: 0.0515 - loss_u2: 0.0907 - loss_i: 0.0370
# Epoch 9/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.2542 - loss: 0.1308 - loss_u1: 0.0492 - loss_u2: 0.0815 - loss_i: 0.0342
# Epoch 10/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.2409 - loss: 0.1236 - loss_u1: 0.0463 - loss_u2: 0.0773 - loss_i: 0.0320
# Epoch 11/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.2302 - loss: 0.1180 - loss_u1: 0.0429 - loss_u2: 0.0750 - loss_i: 0.0298
# Epoch 12/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.2213 - loss: 0.1132 - loss_u1: 0.0398 - loss_u2: 0.0734 - loss_i: 0.0277
# Epoch 13/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.2135 - loss: 0.1090 - loss_u1: 0.0373 - loss_u2: 0.0717 - loss_i: 0.0258
# Epoch 14/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.2062 - loss: 0.1052 - loss_u1: 0.0352 - loss_u2: 0.0700 - loss_i: 0.0243
# Epoch 15/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1994 - loss: 0.1016 - loss_u1: 0.0335 - loss_u2: 0.0682 - loss_i: 0.0229
# Epoch 16/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.1932 - loss: 0.0984 - loss_u1: 0.0320 - loss_u2: 0.0664 - loss_i: 0.0216
# Epoch 17/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.1874 - loss: 0.0954 - loss_u1: 0.0306 - loss_u2: 0.0647 - loss_i: 0.0204
# Epoch 18/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.1821 - loss: 0.0926 - loss_u1: 0.0294 - loss_u2: 0.0632 - loss_i: 0.0192
# Epoch 19/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.1771 - loss: 0.0900 - loss_u1: 0.0284 - loss_u2: 0.0616 - loss_i: 0.0181
# Epoch 20/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1724 - loss: 0.0876 - loss_u1: 0.0274 - loss_u2: 0.0601 - loss_i: 0.0171
# Epoch 21/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1679 - loss: 0.0852 - loss_u1: 0.0266 - loss_u2: 0.0586 - loss_i: 0.0162
# Epoch 22/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.1636 - loss: 0.0830 - loss_u1: 0.0258 - loss_u2: 0.0572 - loss_i: 0.0154
# Epoch 23/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.1595 - loss: 0.0809 - loss_u1: 0.0251 - loss_u2: 0.0558 - loss_i: 0.0146
# Epoch 24/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.1555 - loss: 0.0788 - loss_u1: 0.0244 - loss_u2: 0.0544 - loss_i: 0.0138
# Epoch 25/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1516 - loss: 0.0768 - loss_u1: 0.0237 - loss_u2: 0.0531 - loss_i: 0.0132
# Epoch 26/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.1479 - loss: 0.0749 - loss_u1: 0.0230 - loss_u2: 0.0519 - loss_i: 0.0125
# Epoch 27/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1442 - loss: 0.0730 - loss_u1: 0.0223 - loss_u2: 0.0507 - loss_i: 0.0119
# Epoch 28/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.1407 - loss: 0.0712 - loss_u1: 0.0217 - loss_u2: 0.0495 - loss_i: 0.0114
# Epoch 29/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.1373 - loss: 0.0694 - loss_u1: 0.0211 - loss_u2: 0.0484 - loss_i: 0.0109
# Epoch 30/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1340 - loss: 0.0678 - loss_u1: 0.0204 - loss_u2: 0.0473 - loss_i: 0.0104
# Epoch 31/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1308 - loss: 0.0661 - loss_u1: 0.0198 - loss_u2: 0.0463 - loss_i: 0.0100
# Epoch 32/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.1277 - loss: 0.0646 - loss_u1: 0.0192 - loss_u2: 0.0453 - loss_i: 0.0096
# Epoch 33/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.1248 - loss: 0.0631 - loss_u1: 0.0187 - loss_u2: 0.0444 - loss_i: 0.0093
# Epoch 34/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.1219 - loss: 0.0616 - loss_u1: 0.0181 - loss_u2: 0.0435 - loss_i: 0.0089
# Epoch 35/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.1192 - loss: 0.0602 - loss_u1: 0.0176 - loss_u2: 0.0426 - loss_i: 0.0086
# Epoch 36/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.1165 - loss: 0.0588 - loss_u1: 0.0170 - loss_u2: 0.0418 - loss_i: 0.0084
# Epoch 37/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.1139 - loss: 0.0575 - loss_u1: 0.0165 - loss_u2: 0.0410 - loss_i: 0.0081
# Epoch 38/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.1115 - loss: 0.0563 - loss_u1: 0.0160 - loss_u2: 0.0402 - loss_i: 0.0078
# Epoch 39/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.1090 - loss: 0.0550 - loss_u1: 0.0156 - loss_u2: 0.0395 - loss_i: 0.0076
# Epoch 40/500
# 10/10 [==============================] - 0s 21ms/step - loss_adaptive: 0.1067 - loss: 0.0538 - loss_u1: 0.0151 - loss_u2: 0.0388 - loss_i: 0.0074
# Epoch 41/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.1045 - loss: 0.0527 - loss_u1: 0.0146 - loss_u2: 0.0381 - loss_i: 0.0072
# Epoch 42/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.1023 - loss: 0.0516 - loss_u1: 0.0142 - loss_u2: 0.0374 - loss_i: 0.0070
# Epoch 43/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.1001 - loss: 0.0505 - loss_u1: 0.0138 - loss_u2: 0.0367 - loss_i: 0.0068
# Epoch 44/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0981 - loss: 0.0494 - loss_u1: 0.0134 - loss_u2: 0.0361 - loss_i: 0.0067
# Epoch 45/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0961 - loss: 0.0484 - loss_u1: 0.0130 - loss_u2: 0.0354 - loss_i: 0.0065
# Epoch 46/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0941 - loss: 0.0474 - loss_u1: 0.0126 - loss_u2: 0.0348 - loss_i: 0.0063
# Epoch 47/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0922 - loss: 0.0465 - loss_u1: 0.0122 - loss_u2: 0.0342 - loss_i: 0.0062
# Epoch 48/500
# 10/10 [==============================] - 0s 21ms/step - loss_adaptive: 0.0903 - loss: 0.0455 - loss_u1: 0.0119 - loss_u2: 0.0336 - loss_i: 0.0060
# Epoch 49/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0885 - loss: 0.0446 - loss_u1: 0.0116 - loss_u2: 0.0330 - loss_i: 0.0059
# Epoch 50/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0867 - loss: 0.0437 - loss_u1: 0.0112 - loss_u2: 0.0325 - loss_i: 0.0057
# Epoch 51/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0850 - loss: 0.0428 - loss_u1: 0.0109 - loss_u2: 0.0319 - loss_i: 0.0056
# Epoch 52/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0833 - loss: 0.0420 - loss_u1: 0.0106 - loss_u2: 0.0314 - loss_i: 0.0055
# Epoch 53/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0817 - loss: 0.0411 - loss_u1: 0.0103 - loss_u2: 0.0308 - loss_i: 0.0053
# Epoch 54/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0801 - loss: 0.0403 - loss_u1: 0.0100 - loss_u2: 0.0303 - loss_i: 0.0052
# Epoch 55/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0785 - loss: 0.0395 - loss_u1: 0.0098 - loss_u2: 0.0298 - loss_i: 0.0051
# Epoch 56/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0770 - loss: 0.0388 - loss_u1: 0.0095 - loss_u2: 0.0293 - loss_i: 0.0050
# Epoch 57/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0755 - loss: 0.0380 - loss_u1: 0.0092 - loss_u2: 0.0288 - loss_i: 0.0048
# Epoch 58/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0740 - loss: 0.0373 - loss_u1: 0.0090 - loss_u2: 0.0283 - loss_i: 0.0047
# Epoch 59/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0726 - loss: 0.0365 - loss_u1: 0.0087 - loss_u2: 0.0278 - loss_i: 0.0046
# Epoch 60/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0712 - loss: 0.0358 - loss_u1: 0.0085 - loss_u2: 0.0273 - loss_i: 0.0045
# Epoch 61/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0698 - loss: 0.0351 - loss_u1: 0.0083 - loss_u2: 0.0268 - loss_i: 0.0044
# Epoch 62/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0685 - loss: 0.0345 - loss_u1: 0.0081 - loss_u2: 0.0264 - loss_i: 0.0043
# Epoch 63/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0672 - loss: 0.0338 - loss_u1: 0.0078 - loss_u2: 0.0259 - loss_i: 0.0042
# Epoch 64/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0659 - loss: 0.0332 - loss_u1: 0.0076 - loss_u2: 0.0255 - loss_i: 0.0041
# Epoch 65/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0646 - loss: 0.0325 - loss_u1: 0.0074 - loss_u2: 0.0251 - loss_i: 0.0040
# Epoch 66/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0634 - loss: 0.0319 - loss_u1: 0.0072 - loss_u2: 0.0247 - loss_i: 0.0039
# Epoch 67/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0623 - loss: 0.0313 - loss_u1: 0.0070 - loss_u2: 0.0243 - loss_i: 0.0038
# Epoch 68/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0611 - loss: 0.0307 - loss_u1: 0.0069 - loss_u2: 0.0239 - loss_i: 0.0037
# Epoch 69/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0600 - loss: 0.0302 - loss_u1: 0.0067 - loss_u2: 0.0235 - loss_i: 0.0036
# Epoch 70/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0589 - loss: 0.0296 - loss_u1: 0.0065 - loss_u2: 0.0231 - loss_i: 0.0035
# Epoch 71/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0579 - loss: 0.0291 - loss_u1: 0.0063 - loss_u2: 0.0228 - loss_i: 0.0034
# Epoch 72/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0569 - loss: 0.0286 - loss_u1: 0.0062 - loss_u2: 0.0225 - loss_i: 0.0034
# Epoch 73/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0560 - loss: 0.0281 - loss_u1: 0.0060 - loss_u2: 0.0221 - loss_i: 0.0033
# Epoch 74/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0550 - loss: 0.0277 - loss_u1: 0.0058 - loss_u2: 0.0218 - loss_i: 0.0032
# Epoch 75/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0542 - loss: 0.0272 - loss_u1: 0.0057 - loss_u2: 0.0215 - loss_i: 0.0032
# Epoch 76/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0533 - loss: 0.0268 - loss_u1: 0.0056 - loss_u2: 0.0213 - loss_i: 0.0031
# Epoch 77/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0525 - loss: 0.0264 - loss_u1: 0.0054 - loss_u2: 0.0210 - loss_i: 0.0031
# Epoch 78/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0517 - loss: 0.0260 - loss_u1: 0.0053 - loss_u2: 0.0207 - loss_i: 0.0030
# Epoch 79/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0510 - loss: 0.0256 - loss_u1: 0.0052 - loss_u2: 0.0205 - loss_i: 0.0030
# Epoch 80/500
# 10/10 [==============================] - 0s 21ms/step - loss_adaptive: 0.0502 - loss: 0.0253 - loss_u1: 0.0050 - loss_u2: 0.0202 - loss_i: 0.0029
# Epoch 81/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0496 - loss: 0.0249 - loss_u1: 0.0049 - loss_u2: 0.0200 - loss_i: 0.0029
# Epoch 82/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0489 - loss: 0.0246 - loss_u1: 0.0048 - loss_u2: 0.0198 - loss_i: 0.0029
# Epoch 83/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0482 - loss: 0.0242 - loss_u1: 0.0047 - loss_u2: 0.0196 - loss_i: 0.0029
# Epoch 84/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0476 - loss: 0.0239 - loss_u1: 0.0046 - loss_u2: 0.0193 - loss_i: 0.0028
# Epoch 85/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0470 - loss: 0.0236 - loss_u1: 0.0045 - loss_u2: 0.0191 - loss_i: 0.0028
# Epoch 86/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0464 - loss: 0.0233 - loss_u1: 0.0044 - loss_u2: 0.0189 - loss_i: 0.0028
# Epoch 87/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0459 - loss: 0.0231 - loss_u1: 0.0043 - loss_u2: 0.0188 - loss_i: 0.0028
# Epoch 88/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0453 - loss: 0.0228 - loss_u1: 0.0042 - loss_u2: 0.0186 - loss_i: 0.0028
# Epoch 89/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0448 - loss: 0.0225 - loss_u1: 0.0041 - loss_u2: 0.0184 - loss_i: 0.0027
# Epoch 90/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0443 - loss: 0.0223 - loss_u1: 0.0040 - loss_u2: 0.0182 - loss_i: 0.0027
# Epoch 91/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0438 - loss: 0.0220 - loss_u1: 0.0040 - loss_u2: 0.0180 - loss_i: 0.0027
# Epoch 92/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0433 - loss: 0.0218 - loss_u1: 0.0039 - loss_u2: 0.0179 - loss_i: 0.0027
# Epoch 93/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0428 - loss: 0.0215 - loss_u1: 0.0038 - loss_u2: 0.0177 - loss_i: 0.0027
# Epoch 94/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0424 - loss: 0.0213 - loss_u1: 0.0037 - loss_u2: 0.0175 - loss_i: 0.0027
# Epoch 95/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0419 - loss: 0.0211 - loss_u1: 0.0037 - loss_u2: 0.0174 - loss_i: 0.0027
# Epoch 96/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0415 - loss: 0.0208 - loss_u1: 0.0036 - loss_u2: 0.0172 - loss_i: 0.0027
# Epoch 97/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0410 - loss: 0.0206 - loss_u1: 0.0035 - loss_u2: 0.0171 - loss_i: 0.0026
# Epoch 98/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0406 - loss: 0.0204 - loss_u1: 0.0035 - loss_u2: 0.0169 - loss_i: 0.0026
# Epoch 99/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0402 - loss: 0.0202 - loss_u1: 0.0034 - loss_u2: 0.0168 - loss_i: 0.0026
# Epoch 100/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0398 - loss: 0.0200 - loss_u1: 0.0034 - loss_u2: 0.0166 - loss_i: 0.0026
# Epoch 101/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0394 - loss: 0.0198 - loss_u1: 0.0033 - loss_u2: 0.0165 - loss_i: 0.0026
# Epoch 102/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0390 - loss: 0.0196 - loss_u1: 0.0032 - loss_u2: 0.0163 - loss_i: 0.0026
# Epoch 103/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0386 - loss: 0.0194 - loss_u1: 0.0032 - loss_u2: 0.0162 - loss_i: 0.0026
# Epoch 104/500
# 10/10 [==============================] - 0s 21ms/step - loss_adaptive: 0.0382 - loss: 0.0192 - loss_u1: 0.0031 - loss_u2: 0.0161 - loss_i: 0.0026
# Epoch 105/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0378 - loss: 0.0190 - loss_u1: 0.0031 - loss_u2: 0.0159 - loss_i: 0.0026
# Epoch 106/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0374 - loss: 0.0188 - loss_u1: 0.0030 - loss_u2: 0.0158 - loss_i: 0.0026
# Epoch 107/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0371 - loss: 0.0186 - loss_u1: 0.0030 - loss_u2: 0.0156 - loss_i: 0.0026
# Epoch 108/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0367 - loss: 0.0184 - loss_u1: 0.0029 - loss_u2: 0.0155 - loss_i: 0.0025
# Epoch 109/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0363 - loss: 0.0182 - loss_u1: 0.0029 - loss_u2: 0.0154 - loss_i: 0.0025
# Epoch 110/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0360 - loss: 0.0181 - loss_u1: 0.0028 - loss_u2: 0.0152 - loss_i: 0.0025
# Epoch 111/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0356 - loss: 0.0179 - loss_u1: 0.0028 - loss_u2: 0.0151 - loss_i: 0.0025
# Epoch 112/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0353 - loss: 0.0177 - loss_u1: 0.0027 - loss_u2: 0.0150 - loss_i: 0.0025
# Epoch 113/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0349 - loss: 0.0175 - loss_u1: 0.0027 - loss_u2: 0.0149 - loss_i: 0.0025
# Epoch 114/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0346 - loss: 0.0174 - loss_u1: 0.0026 - loss_u2: 0.0147 - loss_i: 0.0025
# Epoch 115/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0342 - loss: 0.0172 - loss_u1: 0.0026 - loss_u2: 0.0146 - loss_i: 0.0025
# Epoch 116/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0339 - loss: 0.0170 - loss_u1: 0.0025 - loss_u2: 0.0145 - loss_i: 0.0025
# Epoch 117/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0335 - loss: 0.0168 - loss_u1: 0.0025 - loss_u2: 0.0143 - loss_i: 0.0025
# Epoch 118/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0332 - loss: 0.0167 - loss_u1: 0.0025 - loss_u2: 0.0142 - loss_i: 0.0024
# Epoch 119/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0329 - loss: 0.0165 - loss_u1: 0.0024 - loss_u2: 0.0141 - loss_i: 0.0024
# Epoch 120/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0326 - loss: 0.0164 - loss_u1: 0.0024 - loss_u2: 0.0140 - loss_i: 0.0024
# Epoch 121/500
# 10/10 [==============================] - 0s 21ms/step - loss_adaptive: 0.0322 - loss: 0.0162 - loss_u1: 0.0023 - loss_u2: 0.0139 - loss_i: 0.0024
# Epoch 122/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0319 - loss: 0.0160 - loss_u1: 0.0023 - loss_u2: 0.0137 - loss_i: 0.0024
# Epoch 123/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0316 - loss: 0.0159 - loss_u1: 0.0023 - loss_u2: 0.0136 - loss_i: 0.0024
# Epoch 124/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0313 - loss: 0.0157 - loss_u1: 0.0022 - loss_u2: 0.0135 - loss_i: 0.0024
# Epoch 125/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0310 - loss: 0.0156 - loss_u1: 0.0022 - loss_u2: 0.0134 - loss_i: 0.0023
# Epoch 126/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0307 - loss: 0.0154 - loss_u1: 0.0021 - loss_u2: 0.0133 - loss_i: 0.0023
# Epoch 127/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0304 - loss: 0.0153 - loss_u1: 0.0021 - loss_u2: 0.0131 - loss_i: 0.0023
# Epoch 128/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0301 - loss: 0.0151 - loss_u1: 0.0021 - loss_u2: 0.0130 - loss_i: 0.0023
# Epoch 129/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0298 - loss: 0.0150 - loss_u1: 0.0020 - loss_u2: 0.0129 - loss_i: 0.0023
# Epoch 130/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0295 - loss: 0.0148 - loss_u1: 0.0020 - loss_u2: 0.0128 - loss_i: 0.0023
# Epoch 131/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0292 - loss: 0.0147 - loss_u1: 0.0020 - loss_u2: 0.0127 - loss_i: 0.0023
# Epoch 132/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0290 - loss: 0.0145 - loss_u1: 0.0019 - loss_u2: 0.0126 - loss_i: 0.0022
# Epoch 133/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0287 - loss: 0.0144 - loss_u1: 0.0019 - loss_u2: 0.0125 - loss_i: 0.0022
# Epoch 134/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0284 - loss: 0.0143 - loss_u1: 0.0019 - loss_u2: 0.0124 - loss_i: 0.0022
# Epoch 135/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0282 - loss: 0.0141 - loss_u1: 0.0019 - loss_u2: 0.0123 - loss_i: 0.0022
# Epoch 136/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0279 - loss: 0.0140 - loss_u1: 0.0018 - loss_u2: 0.0122 - loss_i: 0.0022
# Epoch 137/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0276 - loss: 0.0139 - loss_u1: 0.0018 - loss_u2: 0.0121 - loss_i: 0.0021
# Epoch 138/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0274 - loss: 0.0137 - loss_u1: 0.0018 - loss_u2: 0.0120 - loss_i: 0.0021
# Epoch 139/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0271 - loss: 0.0136 - loss_u1: 0.0018 - loss_u2: 0.0119 - loss_i: 0.0021
# Epoch 140/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0269 - loss: 0.0135 - loss_u1: 0.0017 - loss_u2: 0.0118 - loss_i: 0.0021
# Epoch 141/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0266 - loss: 0.0134 - loss_u1: 0.0017 - loss_u2: 0.0117 - loss_i: 0.0021
# Epoch 142/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0264 - loss: 0.0132 - loss_u1: 0.0017 - loss_u2: 0.0116 - loss_i: 0.0020
# Epoch 143/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0262 - loss: 0.0131 - loss_u1: 0.0017 - loss_u2: 0.0115 - loss_i: 0.0020
# Epoch 144/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0259 - loss: 0.0130 - loss_u1: 0.0016 - loss_u2: 0.0114 - loss_i: 0.0020
# Epoch 145/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0257 - loss: 0.0129 - loss_u1: 0.0016 - loss_u2: 0.0113 - loss_i: 0.0020
# Epoch 146/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0255 - loss: 0.0128 - loss_u1: 0.0016 - loss_u2: 0.0112 - loss_i: 0.0020
# Epoch 147/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0252 - loss: 0.0127 - loss_u1: 0.0016 - loss_u2: 0.0111 - loss_i: 0.0019
# Epoch 148/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0250 - loss: 0.0125 - loss_u1: 0.0016 - loss_u2: 0.0110 - loss_i: 0.0019
# Epoch 149/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0248 - loss: 0.0124 - loss_u1: 0.0015 - loss_u2: 0.0109 - loss_i: 0.0019
# Epoch 150/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0246 - loss: 0.0123 - loss_u1: 0.0015 - loss_u2: 0.0108 - loss_i: 0.0019
# Epoch 151/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0244 - loss: 0.0122 - loss_u1: 0.0015 - loss_u2: 0.0107 - loss_i: 0.0018
# Epoch 152/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0241 - loss: 0.0121 - loss_u1: 0.0015 - loss_u2: 0.0106 - loss_i: 0.0018
# Epoch 153/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0239 - loss: 0.0120 - loss_u1: 0.0015 - loss_u2: 0.0105 - loss_i: 0.0018
# Epoch 154/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0237 - loss: 0.0119 - loss_u1: 0.0015 - loss_u2: 0.0105 - loss_i: 0.0018
# Epoch 155/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0235 - loss: 0.0118 - loss_u1: 0.0014 - loss_u2: 0.0104 - loss_i: 0.0017
# Epoch 156/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0233 - loss: 0.0117 - loss_u1: 0.0014 - loss_u2: 0.0103 - loss_i: 0.0017
# Epoch 157/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0231 - loss: 0.0116 - loss_u1: 0.0014 - loss_u2: 0.0102 - loss_i: 0.0017
# Epoch 158/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0229 - loss: 0.0115 - loss_u1: 0.0014 - loss_u2: 0.0101 - loss_i: 0.0017
# Epoch 159/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0227 - loss: 0.0114 - loss_u1: 0.0014 - loss_u2: 0.0100 - loss_i: 0.0016
# Epoch 160/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0225 - loss: 0.0113 - loss_u1: 0.0013 - loss_u2: 0.0100 - loss_i: 0.0016
# Epoch 161/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0223 - loss: 0.0112 - loss_u1: 0.0013 - loss_u2: 0.0099 - loss_i: 0.0016
# Epoch 162/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0222 - loss: 0.0111 - loss_u1: 0.0013 - loss_u2: 0.0098 - loss_i: 0.0016
# Epoch 163/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0220 - loss: 0.0110 - loss_u1: 0.0013 - loss_u2: 0.0097 - loss_i: 0.0016
# Epoch 164/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0218 - loss: 0.0109 - loss_u1: 0.0013 - loss_u2: 0.0097 - loss_i: 0.0015
# Epoch 165/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0216 - loss: 0.0108 - loss_u1: 0.0013 - loss_u2: 0.0096 - loss_i: 0.0015
# Epoch 166/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0214 - loss: 0.0108 - loss_u1: 0.0012 - loss_u2: 0.0095 - loss_i: 0.0015
# Epoch 167/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0213 - loss: 0.0107 - loss_u1: 0.0012 - loss_u2: 0.0094 - loss_i: 0.0015
# Epoch 168/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0211 - loss: 0.0106 - loss_u1: 0.0012 - loss_u2: 0.0094 - loss_i: 0.0014
# Epoch 169/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0209 - loss: 0.0105 - loss_u1: 0.0012 - loss_u2: 0.0093 - loss_i: 0.0014
# Epoch 170/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0208 - loss: 0.0104 - loss_u1: 0.0012 - loss_u2: 0.0092 - loss_i: 0.0014
# Epoch 171/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0206 - loss: 0.0103 - loss_u1: 0.0012 - loss_u2: 0.0092 - loss_i: 0.0014
# Epoch 172/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0205 - loss: 0.0103 - loss_u1: 0.0012 - loss_u2: 0.0091 - loss_i: 0.0014
# Epoch 173/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0203 - loss: 0.0102 - loss_u1: 0.0012 - loss_u2: 0.0090 - loss_i: 0.0013
# Epoch 174/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0202 - loss: 0.0101 - loss_u1: 0.0011 - loss_u2: 0.0090 - loss_i: 0.0013
# Epoch 175/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0200 - loss: 0.0100 - loss_u1: 0.0011 - loss_u2: 0.0089 - loss_i: 0.0013
# Epoch 176/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0199 - loss: 0.0100 - loss_u1: 0.0011 - loss_u2: 0.0088 - loss_i: 0.0013
# Epoch 177/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0197 - loss: 0.0099 - loss_u1: 0.0011 - loss_u2: 0.0088 - loss_i: 0.0013
# Epoch 178/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0196 - loss: 0.0098 - loss_u1: 0.0011 - loss_u2: 0.0087 - loss_i: 0.0013
# Epoch 179/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0194 - loss: 0.0097 - loss_u1: 0.0011 - loss_u2: 0.0087 - loss_i: 0.0012
# Epoch 180/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0193 - loss: 0.0097 - loss_u1: 0.0011 - loss_u2: 0.0086 - loss_i: 0.0012
# Epoch 181/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0192 - loss: 0.0096 - loss_u1: 0.0011 - loss_u2: 0.0085 - loss_i: 0.0012
# Epoch 182/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0190 - loss: 0.0095 - loss_u1: 0.0011 - loss_u2: 0.0085 - loss_i: 0.0012
# Epoch 183/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0189 - loss: 0.0095 - loss_u1: 0.0011 - loss_u2: 0.0084 - loss_i: 0.0012
# Epoch 184/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0188 - loss: 0.0094 - loss_u1: 0.0011 - loss_u2: 0.0084 - loss_i: 0.0012
# Epoch 185/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0186 - loss: 0.0094 - loss_u1: 0.0010 - loss_u2: 0.0083 - loss_i: 0.0011
# Epoch 186/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0185 - loss: 0.0093 - loss_u1: 0.0010 - loss_u2: 0.0083 - loss_i: 0.0011
# Epoch 187/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0184 - loss: 0.0092 - loss_u1: 0.0010 - loss_u2: 0.0082 - loss_i: 0.0011
# Epoch 188/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0183 - loss: 0.0092 - loss_u1: 0.0010 - loss_u2: 0.0081 - loss_i: 0.0011
# Epoch 189/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0182 - loss: 0.0091 - loss_u1: 0.0010 - loss_u2: 0.0081 - loss_i: 0.0011
# Epoch 190/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0180 - loss: 0.0090 - loss_u1: 0.0010 - loss_u2: 0.0080 - loss_i: 0.0011
# Epoch 191/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0179 - loss: 0.0090 - loss_u1: 0.0010 - loss_u2: 0.0080 - loss_i: 0.0011
# Epoch 192/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0178 - loss: 0.0089 - loss_u1: 9.9613e-04 - loss_u2: 0.0079 - loss_i: 0.0011
# Epoch 193/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0177 - loss: 0.0089 - loss_u1: 9.9034e-04 - loss_u2: 0.0079 - loss_i: 0.0011
# Epoch 194/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0176 - loss: 0.0088 - loss_u1: 9.8474e-04 - loss_u2: 0.0078 - loss_i: 0.0010
# Epoch 195/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0175 - loss: 0.0088 - loss_u1: 9.7930e-04 - loss_u2: 0.0078 - loss_i: 0.0010
# Epoch 196/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0174 - loss: 0.0087 - loss_u1: 9.7404e-04 - loss_u2: 0.0077 - loss_i: 0.0010
# Epoch 197/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0172 - loss: 0.0086 - loss_u1: 9.6894e-04 - loss_u2: 0.0077 - loss_i: 0.0010
# Epoch 198/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0171 - loss: 0.0086 - loss_u1: 9.6399e-04 - loss_u2: 0.0076 - loss_i: 0.0010
# Epoch 199/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0170 - loss: 0.0085 - loss_u1: 9.5920e-04 - loss_u2: 0.0076 - loss_i: 9.9292e-04
# Epoch 200/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0169 - loss: 0.0085 - loss_u1: 9.5454e-04 - loss_u2: 0.0075 - loss_i: 9.8418e-04
# Epoch 201/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0168 - loss: 0.0084 - loss_u1: 9.5003e-04 - loss_u2: 0.0075 - loss_i: 9.7573e-04
# Epoch 202/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0167 - loss: 0.0084 - loss_u1: 9.4565e-04 - loss_u2: 0.0074 - loss_i: 9.6756e-04
# Epoch 203/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0166 - loss: 0.0083 - loss_u1: 9.4139e-04 - loss_u2: 0.0074 - loss_i: 9.5968e-04
# Epoch 204/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0165 - loss: 0.0083 - loss_u1: 9.3726e-04 - loss_u2: 0.0073 - loss_i: 9.5206e-04
# Epoch 205/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0164 - loss: 0.0082 - loss_u1: 9.3325e-04 - loss_u2: 0.0073 - loss_i: 9.4471e-04
# Epoch 206/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0163 - loss: 0.0082 - loss_u1: 9.2935e-04 - loss_u2: 0.0072 - loss_i: 9.3761e-04
# Epoch 207/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0162 - loss: 0.0081 - loss_u1: 9.2557e-04 - loss_u2: 0.0072 - loss_i: 9.3076e-04
# Epoch 208/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0161 - loss: 0.0081 - loss_u1: 9.2189e-04 - loss_u2: 0.0072 - loss_i: 9.2416e-04
# Epoch 209/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0160 - loss: 0.0080 - loss_u1: 9.1830e-04 - loss_u2: 0.0071 - loss_i: 9.1779e-04
# Epoch 210/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0159 - loss: 0.0080 - loss_u1: 9.1482e-04 - loss_u2: 0.0071 - loss_i: 9.1166e-04
# Epoch 211/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0158 - loss: 0.0079 - loss_u1: 9.1143e-04 - loss_u2: 0.0070 - loss_i: 9.0575e-04
# Epoch 212/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0157 - loss: 0.0079 - loss_u1: 9.0813e-04 - loss_u2: 0.0070 - loss_i: 9.0006e-04
# Epoch 213/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0156 - loss: 0.0078 - loss_u1: 9.0492e-04 - loss_u2: 0.0069 - loss_i: 8.9457e-04
# Epoch 214/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0156 - loss: 0.0078 - loss_u1: 9.0179e-04 - loss_u2: 0.0069 - loss_i: 8.8930e-04
# Epoch 215/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0155 - loss: 0.0078 - loss_u1: 8.9873e-04 - loss_u2: 0.0069 - loss_i: 8.8422e-04
# Epoch 216/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0154 - loss: 0.0077 - loss_u1: 8.9575e-04 - loss_u2: 0.0068 - loss_i: 8.7934e-04
# Epoch 217/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0153 - loss: 0.0077 - loss_u1: 8.9284e-04 - loss_u2: 0.0068 - loss_i: 8.7465e-04
# Epoch 218/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0152 - loss: 0.0076 - loss_u1: 8.9001e-04 - loss_u2: 0.0067 - loss_i: 8.7014e-04
# Epoch 219/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0151 - loss: 0.0076 - loss_u1: 8.8723e-04 - loss_u2: 0.0067 - loss_i: 8.6581e-04
# Epoch 220/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0150 - loss: 0.0075 - loss_u1: 8.8452e-04 - loss_u2: 0.0066 - loss_i: 8.6166e-04
# Epoch 221/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0149 - loss: 0.0075 - loss_u1: 8.8187e-04 - loss_u2: 0.0066 - loss_i: 8.5767e-04
# Epoch 222/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0148 - loss: 0.0074 - loss_u1: 8.7928e-04 - loss_u2: 0.0066 - loss_i: 8.5386e-04
# Epoch 223/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0148 - loss: 0.0074 - loss_u1: 8.7674e-04 - loss_u2: 0.0065 - loss_i: 8.5020e-04
# Epoch 224/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0147 - loss: 0.0074 - loss_u1: 8.7426e-04 - loss_u2: 0.0065 - loss_i: 8.4671e-04
# Epoch 225/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0146 - loss: 0.0073 - loss_u1: 8.7182e-04 - loss_u2: 0.0064 - loss_i: 8.4337e-04
# Epoch 226/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0145 - loss: 0.0073 - loss_u1: 8.6944e-04 - loss_u2: 0.0064 - loss_i: 8.4018e-04
# Epoch 227/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0144 - loss: 0.0072 - loss_u1: 8.6710e-04 - loss_u2: 0.0064 - loss_i: 8.3714e-04
# Epoch 228/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0144 - loss: 0.0072 - loss_u1: 8.6480e-04 - loss_u2: 0.0063 - loss_i: 8.3425e-04
# Epoch 229/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0143 - loss: 0.0072 - loss_u1: 8.6254e-04 - loss_u2: 0.0063 - loss_i: 8.3150e-04
# Epoch 230/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0142 - loss: 0.0071 - loss_u1: 8.6033e-04 - loss_u2: 0.0063 - loss_i: 8.2888e-04
# Epoch 231/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0141 - loss: 0.0071 - loss_u1: 8.5815e-04 - loss_u2: 0.0062 - loss_i: 8.2641e-04
# Epoch 232/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0140 - loss: 0.0070 - loss_u1: 8.5601e-04 - loss_u2: 0.0062 - loss_i: 8.2407e-04
# Epoch 233/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0140 - loss: 0.0070 - loss_u1: 8.5391e-04 - loss_u2: 0.0061 - loss_i: 8.2186e-04
# Epoch 234/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0139 - loss: 0.0070 - loss_u1: 8.5183e-04 - loss_u2: 0.0061 - loss_i: 8.1978e-04
# Epoch 235/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0138 - loss: 0.0069 - loss_u1: 8.4979e-04 - loss_u2: 0.0061 - loss_i: 8.1782e-04
# Epoch 236/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0137 - loss: 0.0069 - loss_u1: 8.4778e-04 - loss_u2: 0.0060 - loss_i: 8.1598e-04
# Epoch 237/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0137 - loss: 0.0068 - loss_u1: 8.4580e-04 - loss_u2: 0.0060 - loss_i: 8.1426e-04
# Epoch 238/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0136 - loss: 0.0068 - loss_u1: 8.4384e-04 - loss_u2: 0.0060 - loss_i: 8.1266e-04
# Epoch 239/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0135 - loss: 0.0068 - loss_u1: 8.4190e-04 - loss_u2: 0.0059 - loss_i: 8.1117e-04
# Epoch 240/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0134 - loss: 0.0067 - loss_u1: 8.3999e-04 - loss_u2: 0.0059 - loss_i: 8.0979e-04
# Epoch 241/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0134 - loss: 0.0067 - loss_u1: 8.3810e-04 - loss_u2: 0.0059 - loss_i: 8.0851e-04
# Epoch 242/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0133 - loss: 0.0067 - loss_u1: 8.3623e-04 - loss_u2: 0.0058 - loss_i: 8.0733e-04
# Epoch 243/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0132 - loss: 0.0066 - loss_u1: 8.3437e-04 - loss_u2: 0.0058 - loss_i: 8.0624e-04
# Epoch 244/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0132 - loss: 0.0066 - loss_u1: 8.3253e-04 - loss_u2: 0.0058 - loss_i: 8.0525e-04
# Epoch 245/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0131 - loss: 0.0066 - loss_u1: 8.3070e-04 - loss_u2: 0.0057 - loss_i: 8.0434e-04
# Epoch 246/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0130 - loss: 0.0065 - loss_u1: 8.2889e-04 - loss_u2: 0.0057 - loss_i: 8.0352e-04
# Epoch 247/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0130 - loss: 0.0065 - loss_u1: 8.2708e-04 - loss_u2: 0.0057 - loss_i: 8.0278e-04
# Epoch 248/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0129 - loss: 0.0065 - loss_u1: 8.2528e-04 - loss_u2: 0.0056 - loss_i: 8.0210e-04
# Epoch 249/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0128 - loss: 0.0064 - loss_u1: 8.2348e-04 - loss_u2: 0.0056 - loss_i: 8.0149e-04
# Epoch 250/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0128 - loss: 0.0064 - loss_u1: 8.2169e-04 - loss_u2: 0.0056 - loss_i: 8.0095e-04
# Epoch 251/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0127 - loss: 0.0064 - loss_u1: 8.1990e-04 - loss_u2: 0.0055 - loss_i: 8.0046e-04
# Epoch 252/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0126 - loss: 0.0063 - loss_u1: 8.1810e-04 - loss_u2: 0.0055 - loss_i: 8.0002e-04
# Epoch 253/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0126 - loss: 0.0063 - loss_u1: 8.1631e-04 - loss_u2: 0.0055 - loss_i: 7.9963e-04
# Epoch 254/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0125 - loss: 0.0063 - loss_u1: 8.1451e-04 - loss_u2: 0.0054 - loss_i: 7.9927e-04
# Epoch 255/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0124 - loss: 0.0062 - loss_u1: 8.1270e-04 - loss_u2: 0.0054 - loss_i: 7.9895e-04
# Epoch 256/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0124 - loss: 0.0062 - loss_u1: 8.1088e-04 - loss_u2: 0.0054 - loss_i: 7.9866e-04
# Epoch 257/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0123 - loss: 0.0062 - loss_u1: 8.0905e-04 - loss_u2: 0.0054 - loss_i: 7.9838e-04
# Epoch 258/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0122 - loss: 0.0061 - loss_u1: 8.0721e-04 - loss_u2: 0.0053 - loss_i: 7.9812e-04
# Epoch 259/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0122 - loss: 0.0061 - loss_u1: 8.0536e-04 - loss_u2: 0.0053 - loss_i: 7.9787e-04
# Epoch 260/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0121 - loss: 0.0061 - loss_u1: 8.0349e-04 - loss_u2: 0.0053 - loss_i: 7.9763e-04
# Epoch 261/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0121 - loss: 0.0060 - loss_u1: 8.0160e-04 - loss_u2: 0.0052 - loss_i: 7.9738e-04
# Epoch 262/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0120 - loss: 0.0060 - loss_u1: 7.9969e-04 - loss_u2: 0.0052 - loss_i: 7.9712e-04
# Epoch 263/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0120 - loss: 0.0060 - loss_u1: 7.9776e-04 - loss_u2: 0.0052 - loss_i: 7.9685e-04
# Epoch 264/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0119 - loss: 0.0060 - loss_u1: 7.9581e-04 - loss_u2: 0.0052 - loss_i: 7.9656e-04
# Epoch 265/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0118 - loss: 0.0059 - loss_u1: 7.9384e-04 - loss_u2: 0.0051 - loss_i: 7.9624e-04
# Epoch 266/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0118 - loss: 0.0059 - loss_u1: 7.9185e-04 - loss_u2: 0.0051 - loss_i: 7.9590e-04
# Epoch 267/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0117 - loss: 0.0059 - loss_u1: 7.8983e-04 - loss_u2: 0.0051 - loss_i: 7.9553e-04
# Epoch 268/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0117 - loss: 0.0058 - loss_u1: 7.8779e-04 - loss_u2: 0.0051 - loss_i: 7.9511e-04
# Epoch 269/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0116 - loss: 0.0058 - loss_u1: 7.8572e-04 - loss_u2: 0.0050 - loss_i: 7.9466e-04
# Epoch 270/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0116 - loss: 0.0058 - loss_u1: 7.8363e-04 - loss_u2: 0.0050 - loss_i: 7.9416e-04
# Epoch 271/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0115 - loss: 0.0058 - loss_u1: 7.8151e-04 - loss_u2: 0.0050 - loss_i: 7.9361e-04
# Epoch 272/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0114 - loss: 0.0057 - loss_u1: 7.7937e-04 - loss_u2: 0.0050 - loss_i: 7.9301e-04
# Epoch 273/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0114 - loss: 0.0057 - loss_u1: 7.7720e-04 - loss_u2: 0.0049 - loss_i: 7.9235e-04
# Epoch 274/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0113 - loss: 0.0057 - loss_u1: 7.7502e-04 - loss_u2: 0.0049 - loss_i: 7.9165e-04
# Epoch 275/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0113 - loss: 0.0057 - loss_u1: 7.7281e-04 - loss_u2: 0.0049 - loss_i: 7.9088e-04
# Epoch 276/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0112 - loss: 0.0056 - loss_u1: 7.7057e-04 - loss_u2: 0.0049 - loss_i: 7.9005e-04
# Epoch 277/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0112 - loss: 0.0056 - loss_u1: 7.6832e-04 - loss_u2: 0.0048 - loss_i: 7.8917e-04
# Epoch 278/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0111 - loss: 0.0056 - loss_u1: 7.6605e-04 - loss_u2: 0.0048 - loss_i: 7.8822e-04
# Epoch 279/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0111 - loss: 0.0056 - loss_u1: 7.6376e-04 - loss_u2: 0.0048 - loss_i: 7.8722e-04
# Epoch 280/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0110 - loss: 0.0055 - loss_u1: 7.6145e-04 - loss_u2: 0.0048 - loss_i: 7.8615e-04
# Epoch 281/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0110 - loss: 0.0055 - loss_u1: 7.5913e-04 - loss_u2: 0.0047 - loss_i: 7.8502e-04
# Epoch 282/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0109 - loss: 0.0055 - loss_u1: 7.5679e-04 - loss_u2: 0.0047 - loss_i: 7.8383e-04
# Epoch 283/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0109 - loss: 0.0055 - loss_u1: 7.5444e-04 - loss_u2: 0.0047 - loss_i: 7.8258e-04
# Epoch 284/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0108 - loss: 0.0054 - loss_u1: 7.5208e-04 - loss_u2: 0.0047 - loss_i: 7.8127e-04
# Epoch 285/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0108 - loss: 0.0054 - loss_u1: 7.4971e-04 - loss_u2: 0.0047 - loss_i: 7.7990e-04
# Epoch 286/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0107 - loss: 0.0054 - loss_u1: 7.4734e-04 - loss_u2: 0.0046 - loss_i: 7.7848e-04
# Epoch 287/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0107 - loss: 0.0054 - loss_u1: 7.4495e-04 - loss_u2: 0.0046 - loss_i: 7.7699e-04
# Epoch 288/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0106 - loss: 0.0053 - loss_u1: 7.4256e-04 - loss_u2: 0.0046 - loss_i: 7.7545e-04
# Epoch 289/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0106 - loss: 0.0053 - loss_u1: 7.4017e-04 - loss_u2: 0.0046 - loss_i: 7.7386e-04
# Epoch 290/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0105 - loss: 0.0053 - loss_u1: 7.3778e-04 - loss_u2: 0.0045 - loss_i: 7.7221e-04
# Epoch 291/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0105 - loss: 0.0053 - loss_u1: 7.3538e-04 - loss_u2: 0.0045 - loss_i: 7.7051e-04
# Epoch 292/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0105 - loss: 0.0052 - loss_u1: 7.3298e-04 - loss_u2: 0.0045 - loss_i: 7.6876e-04
# Epoch 293/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0104 - loss: 0.0052 - loss_u1: 7.3059e-04 - loss_u2: 0.0045 - loss_i: 7.6696e-04
# Epoch 294/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0104 - loss: 0.0052 - loss_u1: 7.2819e-04 - loss_u2: 0.0045 - loss_i: 7.6511e-04
# Epoch 295/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0103 - loss: 0.0052 - loss_u1: 7.2580e-04 - loss_u2: 0.0044 - loss_i: 7.6320e-04
# Epoch 296/500
# ...
# Epoch 406/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 4.1631e-04 - loss_u2: 0.0030 - loss_i: 2.9455e-04
# Epoch 407/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 4.1478e-04 - loss_u2: 0.0030 - loss_i: 2.9284e-04
# Epoch 408/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 4.1327e-04 - loss_u2: 0.0030 - loss_i: 2.9118e-04
# Epoch 409/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0068 - loss: 0.0034 - loss_u1: 4.1179e-04 - loss_u2: 0.0030 - loss_i: 2.8956e-04
# Epoch 410/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0067 - loss: 0.0034 - loss_u1: 4.1033e-04 - loss_u2: 0.0030 - loss_i: 2.8798e-04
# Epoch 411/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0067 - loss: 0.0034 - loss_u1: 4.0891e-04 - loss_u2: 0.0030 - loss_i: 2.8645e-04
# Epoch 412/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0067 - loss: 0.0034 - loss_u1: 4.0750e-04 - loss_u2: 0.0029 - loss_i: 2.8496e-04
# Epoch 413/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0067 - loss: 0.0033 - loss_u1: 4.0613e-04 - loss_u2: 0.0029 - loss_i: 2.8350e-04
# Epoch 414/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0067 - loss: 0.0033 - loss_u1: 4.0478e-04 - loss_u2: 0.0029 - loss_i: 2.8208e-04
# Epoch 415/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0067 - loss: 0.0033 - loss_u1: 4.0345e-04 - loss_u2: 0.0029 - loss_i: 2.8070e-04
# Epoch 416/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 4.0214e-04 - loss_u2: 0.0029 - loss_i: 2.7935e-04
# Epoch 417/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 4.0086e-04 - loss_u2: 0.0029 - loss_i: 2.7803e-04
# Epoch 418/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 3.9960e-04 - loss_u2: 0.0029 - loss_i: 2.7675e-04
# Epoch 419/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 3.9836e-04 - loss_u2: 0.0029 - loss_i: 2.7550e-04
# Epoch 420/500
# 10/10 [==============================] - 0s 35ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 3.9714e-04 - loss_u2: 0.0029 - loss_i: 2.7427e-04
# Epoch 421/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0066 - loss: 0.0033 - loss_u1: 3.9594e-04 - loss_u2: 0.0029 - loss_i: 2.7308e-04
# Epoch 422/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 3.9476e-04 - loss_u2: 0.0029 - loss_i: 2.7191e-04
# Epoch 423/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 3.9361e-04 - loss_u2: 0.0029 - loss_i: 2.7078e-04
# Epoch 424/500
# 10/10 [==============================] - 0s 22ms/step - loss_adaptive: 0.0065 - loss: 0.0033 - loss_u1: 3.9247e-04 - loss_u2: 0.0029 - loss_i: 2.6967e-04
# Epoch 425/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0065 - loss: 0.0032 - loss_u1: 3.9135e-04 - loss_u2: 0.0029 - loss_i: 2.6858e-04
# Epoch 426/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0065 - loss: 0.0032 - loss_u1: 3.9025e-04 - loss_u2: 0.0029 - loss_i: 2.6752e-04
# Epoch 427/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0065 - loss: 0.0032 - loss_u1: 3.8916e-04 - loss_u2: 0.0028 - loss_i: 2.6648e-04
# Epoch 428/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8810e-04 - loss_u2: 0.0028 - loss_i: 2.6547e-04
# Epoch 429/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8705e-04 - loss_u2: 0.0028 - loss_i: 2.6448e-04
# Epoch 430/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8601e-04 - loss_u2: 0.0028 - loss_i: 2.6351e-04
# Epoch 431/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8500e-04 - loss_u2: 0.0028 - loss_i: 2.6256e-04
# Epoch 432/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8400e-04 - loss_u2: 0.0028 - loss_i: 2.6163e-04
# Epoch 433/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8302e-04 - loss_u2: 0.0028 - loss_i: 2.6073e-04
# Epoch 434/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0064 - loss: 0.0032 - loss_u1: 3.8205e-04 - loss_u2: 0.0028 - loss_i: 2.5984e-04
# Epoch 435/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 3.8109e-04 - loss_u2: 0.0028 - loss_i: 2.5897e-04
# Epoch 436/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 3.8015e-04 - loss_u2: 0.0028 - loss_i: 2.5813e-04
# Epoch 437/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 3.7923e-04 - loss_u2: 0.0028 - loss_i: 2.5730e-04
# Epoch 438/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0063 - loss: 0.0032 - loss_u1: 3.7832e-04 - loss_u2: 0.0028 - loss_i: 2.5649e-04
# Epoch 439/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0063 - loss: 0.0031 - loss_u1: 3.7742e-04 - loss_u2: 0.0028 - loss_i: 2.5569e-04
# Epoch 440/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0063 - loss: 0.0031 - loss_u1: 3.7654e-04 - loss_u2: 0.0028 - loss_i: 2.5492e-04
# Epoch 441/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0063 - loss: 0.0031 - loss_u1: 3.7567e-04 - loss_u2: 0.0028 - loss_i: 2.5416e-04
# Epoch 442/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7481e-04 - loss_u2: 0.0028 - loss_i: 2.5341e-04
# Epoch 443/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7397e-04 - loss_u2: 0.0027 - loss_i: 2.5269e-04
# Epoch 444/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7314e-04 - loss_u2: 0.0027 - loss_i: 2.5198e-04
# Epoch 445/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7232e-04 - loss_u2: 0.0027 - loss_i: 2.5128e-04
# Epoch 446/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7151e-04 - loss_u2: 0.0027 - loss_i: 2.5061e-04
# Epoch 447/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.7071e-04 - loss_u2: 0.0027 - loss_i: 2.4994e-04
# Epoch 448/500
# 10/10 [==============================] - 0s 33ms/step - loss_adaptive: 0.0062 - loss: 0.0031 - loss_u1: 3.6993e-04 - loss_u2: 0.0027 - loss_i: 2.4929e-04
# Epoch 449/500
# 10/10 [==============================] - 0s 31ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 3.6916e-04 - loss_u2: 0.0027 - loss_i: 2.4866e-04
# Epoch 450/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 3.6839e-04 - loss_u2: 0.0027 - loss_i: 2.4804e-04
# Epoch 451/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 3.6764e-04 - loss_u2: 0.0027 - loss_i: 2.4744e-04
# Epoch 452/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 3.6690e-04 - loss_u2: 0.0027 - loss_i: 2.4685e-04
# Epoch 453/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0061 - loss: 0.0031 - loss_u1: 3.6617e-04 - loss_u2: 0.0027 - loss_i: 2.4628e-04
# Epoch 454/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0061 - loss: 0.0030 - loss_u1: 3.6545e-04 - loss_u2: 0.0027 - loss_i: 2.4572e-04
# Epoch 455/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0061 - loss: 0.0030 - loss_u1: 3.6474e-04 - loss_u2: 0.0027 - loss_i: 2.4517e-04
# Epoch 456/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0061 - loss: 0.0030 - loss_u1: 3.6404e-04 - loss_u2: 0.0027 - loss_i: 2.4464e-04
# Epoch 457/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6335e-04 - loss_u2: 0.0027 - loss_i: 2.4412e-04
# Epoch 458/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6267e-04 - loss_u2: 0.0027 - loss_i: 2.4362e-04
# Epoch 459/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6200e-04 - loss_u2: 0.0027 - loss_i: 2.4313e-04
# Epoch 460/500
# 10/10 [==============================] - 0s 23ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6134e-04 - loss_u2: 0.0026 - loss_i: 2.4265e-04
# Epoch 461/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6069e-04 - loss_u2: 0.0026 - loss_i: 2.4219e-04
# Epoch 462/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.6004e-04 - loss_u2: 0.0026 - loss_i: 2.4174e-04
# Epoch 463/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.5941e-04 - loss_u2: 0.0026 - loss_i: 2.4131e-04
# Epoch 464/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.5878e-04 - loss_u2: 0.0026 - loss_i: 2.4089e-04
# Epoch 465/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0060 - loss: 0.0030 - loss_u1: 3.5817e-04 - loss_u2: 0.0026 - loss_i: 2.4049e-04
# Epoch 466/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 3.5756e-04 - loss_u2: 0.0026 - loss_i: 2.4010e-04
# Epoch 467/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 3.5696e-04 - loss_u2: 0.0026 - loss_i: 2.3972e-04
# Epoch 468/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 3.5637e-04 - loss_u2: 0.0026 - loss_i: 2.3936e-04
# Epoch 469/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 3.5578e-04 - loss_u2: 0.0026 - loss_i: 2.3902e-04
# Epoch 470/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0059 - loss: 0.0030 - loss_u1: 3.5521e-04 - loss_u2: 0.0026 - loss_i: 2.3869e-04
# Epoch 471/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0059 - loss: 0.0029 - loss_u1: 3.5464e-04 - loss_u2: 0.0026 - loss_i: 2.3837e-04
# Epoch 472/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0059 - loss: 0.0029 - loss_u1: 3.5409e-04 - loss_u2: 0.0026 - loss_i: 2.3807e-04
# Epoch 473/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0059 - loss: 0.0029 - loss_u1: 3.5353e-04 - loss_u2: 0.0026 - loss_i: 2.3778e-04
# Epoch 474/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5299e-04 - loss_u2: 0.0026 - loss_i: 2.3751e-04
# Epoch 475/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5246e-04 - loss_u2: 0.0026 - loss_i: 2.3726e-04
# Epoch 476/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5193e-04 - loss_u2: 0.0026 - loss_i: 2.3702e-04
# Epoch 477/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5141e-04 - loss_u2: 0.0026 - loss_i: 2.3680e-04
# Epoch 478/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5090e-04 - loss_u2: 0.0026 - loss_i: 2.3659e-04
# Epoch 479/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.5040e-04 - loss_u2: 0.0026 - loss_i: 2.3640e-04
# Epoch 480/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.4990e-04 - loss_u2: 0.0025 - loss_i: 2.3623e-04
# Epoch 481/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.4942e-04 - loss_u2: 0.0025 - loss_i: 2.3608e-04
# Epoch 482/500
# 10/10 [==============================] - 0s 32ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.4894e-04 - loss_u2: 0.0025 - loss_i: 2.3594e-04
# Epoch 483/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0058 - loss: 0.0029 - loss_u1: 3.4847e-04 - loss_u2: 0.0025 - loss_i: 2.3582e-04
# Epoch 484/500
# 10/10 [==============================] - 0s 29ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 3.4800e-04 - loss_u2: 0.0025 - loss_i: 2.3572e-04
# Epoch 485/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 3.4755e-04 - loss_u2: 0.0025 - loss_i: 2.3564e-04
# Epoch 486/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 3.4710e-04 - loss_u2: 0.0025 - loss_i: 2.3557e-04
# Epoch 487/500
# 10/10 [==============================] - 0s 24ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 3.4666e-04 - loss_u2: 0.0025 - loss_i: 2.3553e-04
# Epoch 488/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0057 - loss: 0.0029 - loss_u1: 3.4623e-04 - loss_u2: 0.0025 - loss_i: 2.3550e-04
# Epoch 489/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0057 - loss: 0.0028 - loss_u1: 3.4580e-04 - loss_u2: 0.0025 - loss_i: 2.3550e-04
# Epoch 490/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0057 - loss: 0.0028 - loss_u1: 3.4538e-04 - loss_u2: 0.0025 - loss_i: 2.3551e-04
# Epoch 491/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0057 - loss: 0.0028 - loss_u1: 3.4498e-04 - loss_u2: 0.0025 - loss_i: 2.3555e-04
# Epoch 492/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0057 - loss: 0.0028 - loss_u1: 3.4457e-04 - loss_u2: 0.0025 - loss_i: 2.3560e-04
# Epoch 493/500
# 10/10 [==============================] - 0s 30ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4418e-04 - loss_u2: 0.0025 - loss_i: 2.3568e-04
# Epoch 494/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4380e-04 - loss_u2: 0.0025 - loss_i: 2.3577e-04
# Epoch 495/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4342e-04 - loss_u2: 0.0025 - loss_i: 2.3589e-04
# Epoch 496/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4305e-04 - loss_u2: 0.0025 - loss_i: 2.3603e-04
# Epoch 497/500
# 10/10 [==============================] - 0s 25ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4269e-04 - loss_u2: 0.0025 - loss_i: 2.3619e-04
# Epoch 498/500
# 10/10 [==============================] - 0s 26ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4234e-04 - loss_u2: 0.0025 - loss_i: 2.3637e-04
# Epoch 499/500
# 10/10 [==============================] - 0s 27ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4199e-04 - loss_u2: 0.0025 - loss_i: 2.3658e-04
# Epoch 500/500
# 10/10 [==============================] - 0s 28ms/step - loss_adaptive: 0.0056 - loss: 0.0028 - loss_u1: 3.4166e-04 - loss_u2: 0.0025 - loss_i: 2.3680e-04

# %%
func = function_factory(couple_model, couple_model.loss_Total,
              (X_u1_train,X_u2_train), (u1_train,u2_train), (X_f1_train,X_f2_train), X_i_train )
params_1d_m1 = tf.dynamic_stitch(func.idx[0], couple_model.m1.trainable_variables)
params_1d_m2 = tf.dynamic_stitch(func.idx[1], couple_model.m2.trainable_variables)
params_1d = tf.concat([params_1d_m1,params_1d_m2],axis=0)
## L-BFGS 优化阶段
results = tfp.optimizer.lbfgs_minimize(
    value_and_gradients_function=func,
    initial_position=params_1d, 
    num_correction_pairs=20, 
    x_tolerance = 0,
    f_relative_tolerance = 0,
    tolerance = 1*np.finfo(float).eps,
    parallel_iterations = 1,
    max_line_search_iterations = 100,
    max_iterations=1000)
#上述代码运行了3次，实际上的max_iterations=3000,输出log中的Iter!=max_iterations, Iter=func调用次数
# Out:
# Iter: 50 loss: 1.1330532680033226e-05
# Iter: 100 loss: 1.1126889561230079e-05
# Iter: 150 loss: 1.0949716277091062e-05
# Iter: 200 loss: 1.0885738908650815e-05
# Iter: 250 loss: 1.0785095245871144e-05
# Iter: 300 loss: 1.0676675476654581e-05
# Iter: 350 loss: 1.0618945508860627e-05
# Iter: 400 loss: 1.061718038522584e-05
# Iter: 450 loss: 1.0356013853775964e-05
# Iter: 500 loss: 1.025785726323046e-05
# Iter: 550 loss: 1.018018614811541e-05
# Iter: 600 loss: 1.0106531535395913e-05
# Iter: 650 loss: 1.0039316764716818e-05
# Iter: 700 loss: 9.9896734915737157e-06
# Iter: 750 loss: 9.9164320967905663e-06
# Iter: 800 loss: 9.870255196208248e-06
# Iter: 850 loss: 9.7860532246539754e-06
# Iter: 900 loss: 9.7007534366276087e-06
# Iter: 950 loss: 9.58915578181172e-06
# Iter: 1000 loss: 9.4957818554027249e-06
# Iter: 1050 loss: 9.38833202781811e-06
# Iter: 1100 loss: 9.2933721017644948e-06
# Iter: 1150 loss: 9.2186997249201842e-06
# Iter: 1200 loss: 9.1581435315074372e-06
# Iter: 1250 loss: 9.1131298708497352e-06
# Iter: 1300 loss: 9.0699327815461689e-06
# Iter: 1350 loss: 9.0128107054906926e-06
# Iter: 1400 loss: 8.9505769879895716e-06
# Iter: 1450 loss: 8.8677387290119677e-06
# Iter: 1500 loss: 8.80113658343823e-06
# Iter: 1550 loss: 8.7507928576579277e-06
# Iter: 1600 loss: 8.6822857551278028e-06
# Iter: 1650 loss: 8.6131864395725888e-06
# Iter: 1700 loss: 8.5384236425197143e-06
# Iter: 1750 loss: 8.4687523336869978e-06
# Iter: 1800 loss: 8.4180810891484656e-06
# Iter: 1850 loss: 8.3553725247335512e-06
# Iter: 1900 loss: 8.3235851851596049e-06
# Iter: 1950 loss: 8.2703913576677359e-06
# Iter: 2000 loss: 8.2244722168446941e-06
# Iter: 2050 loss: 8.1820813538951076e-06
# Iter: 2100 loss: 8.1164312589560855e-06
# Iter: 2150 loss: 8.0387202467998352e-06
# Iter: 2200 loss: 8.003812069198e-06
# Iter: 2250 loss: 7.9340937145177123e-06
# Iter: 2300 loss: 7.87763690734865e-06
# Iter: 2350 loss: 7.8169291518083778e-06
# Iter: 2400 loss: 7.7677632790483544e-06
# Iter: 2450 loss: 7.7031816759438462e-06
# Iter: 2500 loss: 7.6750170208556182e-06
# Iter: 2550 loss: 7.6377279123688576e-06
# Iter: 2600 loss: 7.5847279056399108e-06
# Iter: 2650 loss: 7.5514765075953829e-06
# Iter: 2700 loss: 7.5049234259249969e-06
# Iter: 2750 loss: 7.4215962445840781e-06
# Iter: 2800 loss: 7.3790592536085336e-06
# Iter: 2850 loss: 7.3014411624886814e-06
# Iter: 2900 loss: 7.2340407500211855e-06
# Iter: 2950 loss: 7.1234466516974124e-06

# %%
"""history_u1 = model_u1.fit(
    X_u1_train,
    u1_train,
    batch_size=64,
    epochs=10,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    #validation_data=(x_val, y_val),
)
history_u2 = model_u2.fit(
    X_u2_train,
    u2_train,
    batch_size=64,
    epochs=10,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    #validation_data=(x_val, y_val),
)"""

# %% [markdown]
# # Plot

# %%
U1_pred = pred_data(X_u1,Y_u1,T_u1,model_u1)
U2_pred = pred_data(X_u2,Y_u2,T_u2,model_u2)
####################################################
plt.figure(1) 
ax1 = plt.axes(projection="3d")
ax1.patch.set_facecolor("white")   #设置 axes 背景颜色

ax1.plot_surface(X_u1,Y_u1,U1,alpha=0.9) #生成曲面z，alpha调节透明度，cmap调节曲面色调
ax1.plot_surface(X_u2,Y_u2,U2,alpha=0.9)

ax1.set_xlabel("X")   
ax1.set_ylabel("Y")
ax1.set_zlabel("U")
ax1.set_title("Real U")
######################################################
plt.figure(2) 
ax2 = plt.axes(projection="3d")
ax2.patch.set_facecolor("white") 

### u1
ax2.plot_surface(X_u1,Y_u1,U1_pred,alpha=0.9)

###u2
ax2.plot_surface(X_u2,Y_u2,U2_pred,alpha=0.9)

ax2.set_xlabel("X")   
ax2.set_ylabel("Y")
ax2.set_zlabel("U")
ax2.set_title("Pred U")
###############################
plt.show()

# %%
u1_real = U1.numpy().flatten()
u1_pred = U1_pred.numpy().flatten()
u2_real = U2.numpy().flatten()
u2_pred = U2_pred.numpy().flatten()

error_u1 = np.linalg.norm((u1_real-u1_pred),2)/np.linalg.norm(u1_real,2)  
print('Test Error For u1:  %.5f'  % (error_u1))

error_u2 = np.linalg.norm((u2_real-u2_pred),2)/np.linalg.norm(u2_real,2)  
print('Test Error For u2:  %.5f'  % (error_u2))
# Out:
# Test Error For u1:  0.01425
# Test Error For u2:  0.00487
