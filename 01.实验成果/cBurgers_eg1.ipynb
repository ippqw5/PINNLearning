# %% [markdown]
# # Import

# %%
pip install pyDOE

# %%
from sympy import*
import numpy as np
from pyDOE import lhs         #Latin Hypercube Sampling
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   
import tensorflow as tf
from tensorflow import keras
import tensorflow_probability as tfp #TFP needs TF>= 2.3
import time

tf.random.set_seed(1234)
np.random.seed(1234)

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Setting

# %%
x = symbols('x')
t = symbols('t')

a = 1 
b = 1
eta = -2

u1 = exp(-t)*sin(x)
u2 = exp(-t)*sin(x)


u1 = lambdify((x,t),u1)
u2 = lambdify((x,t),u2)

# %% [markdown]
# # TrainingData & TestData

# %%
def trainingdata(N_u,N_f,omga,u):    

    x_range = omga[0]
    t_range = [0.,1.]

    all_X_u_train = []
    all_u_train = []

    # Initial Condition t=0, 
    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[1],t_range[0]])
    initial_X = lb + (ub-lb)*lhs(2,N_u)
    initial_u = u(initial_X[:,0], initial_X[:,1]).reshape(-1,1)
    
    all_X_u_train.append(initial_X)
    all_u_train.append(initial_u)

    # BC Condition

    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[0],t_range[1]])
    BC_X1 = lb + (ub-lb)*lhs(2,N_u)
    BC_u1 = u(BC_X1[:,0],BC_X1[:,1]).reshape(-1,1) 
    all_X_u_train.append(BC_X1)
    all_u_train.append(BC_u1) 
    
    lb = np.array([x_range[1],t_range[0]])
    ub = np.array([x_range[1],t_range[1]])
    BC_X2 = lb + (ub-lb)*lhs(2,N_u)
    BC_u2 = u(BC_X2[:,0],BC_X2[:,1]).reshape(-1,1) 
    all_X_u_train.append(BC_X2)
    all_u_train.append(BC_u2) 

    all_X_u_train =  np.vstack(all_X_u_train)
    all_u_train = np.vstack(all_u_train)
    
    idx = np.random.choice(all_X_u_train.shape[0],all_X_u_train.shape[0], replace=False) 
    
    X_u_train = all_X_u_train[idx,:]
    u_train = all_u_train[idx,:]
            
    '''Collocation Points'''
    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[1],t_range[1]])
    X_f_train = lb + (ub-lb)*lhs(2,N_f) 
    X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    
    return X_u_train,u_train,X_f_train

def ds_train_n_batch(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train,n = 5):
    batch_u1 = int(len(X_u1_train)/n) # = int(len(u1_train)/n)


    batch_u2 = int(len(X_u2_train)/n) # = int(len(u2_train)/n)

    
    batch_f = int(len(X_f_train)/n)
    
    ds_u1 = tf.data.Dataset.from_tensor_slices( ((X_u1_train,u1_train)) ).batch( batch_u1 )
    
    ds_u2 = tf.data.Dataset.from_tensor_slices( ((X_u2_train,u2_train)) ).batch( batch_u2 )
    
    ds_f = tf.data.Dataset.from_tensor_slices(X_f_train).batch(batch_f)

    ds_train = tf.data.Dataset.zip((ds_u1,ds_u2,ds_f))
    return ds_train

def ds_test_n_batch(x1_test,u1_test,x2_test,u2_test,n=5):
  batch_u1 = int(len(u1_test)/n)
  batch_u2 = int(len(u2_test)/n)

  ds_u1 = tf.data.Dataset.from_tensor_slices( (x1_test,u1_test) ).batch(batch_u1)
  ds_u2 = tf.data.Dataset.from_tensor_slices( (x2_test,u2_test) ).batch(batch_u2)

  ds_test = tf.data.Dataset.zip((ds_u1,ds_u2))
  return ds_test

def test_data(N,omga,u):
  x_range = omga[0]
  t_range = omga[1]

  lb = np.array([x_range[0],t_range[0]])
  ub = np.array([x_range[1],t_range[1]])
  x_test = lb + (ub-lb)*lhs(2,N)
  u_test = u(x_test[:,0],x_test[:,1]).reshape((-1,1)) 

  return x_test,u_test

# %% [markdown]
# # Plot

# %%
def plot_real_data(N,omga,u):
  # Output: X,T shape=(N,N)
  x_range = tf.linspace(omga[0][0],omga[0][1],N)
  t_range = tf.linspace(omga[1][0],omga[1][1],N)

  X,T = tf.meshgrid(x_range,t_range)

  U = u(X,T)
  return X,T,U

def plot_pred_data(X,T,model):
  #Input: X,T shape=(N,N)
  #Output: U_pred shape=(N,N)
  Shape = X.shape
  dim = len(Shape)
  X = tf.reshape(X,shape=(Shape[0]**dim,1))
  T = tf.reshape(T,shape=(Shape[0]**dim,1))

  Inputs = tf.concat([X,T],axis=1)
  U_pred = model(Inputs)
  U_pred = tf.reshape(U_pred,shape=Shape)
  return U_pred

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pyparsing import col
#plt.rcParams['font.sans-serif'] = ['SimHei']  # 步骤一（替换sans-serif字体）
plt.rcParams['axes.unicode_minus'] = False   # 步骤二（解决坐标轴负数的负号显示问题）
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import math

# %%
def plot_Adam_history(history_saw_cp,start_epoch=0.05):

  fig = plt.figure(figsize=(10,6))
  ax1 = fig.add_subplot(211)
  epoches = len(history_saw_cp.history['loss'])
  start = int(epoches*start_epoch)
  x = np.arange(start,epoches,1)

  line1, = ax1.plot(x,history_saw_cp.history['loss'][start:],'g:')
  line2, = ax1.plot(x,history_saw_cp.history['loss_u1'][start:],'r:')
  line3, = ax1.plot(x,history_saw_cp.history['loss_u2'][start:],'b:')
  ax1.legend(handles=[line1,line2,line3],labels=['loss','loss_u1','loss_u2'])
  ax1.set_ylabel('loss')
  ax1.set_xlabel('epoches')
  ax1.autoscale()

  ax2 = fig.add_subplot(212)
  line4, = ax2.plot(x,history_saw_cp.history['val_err_u1'][start:],'r:')
  line5, = ax2.plot(x,history_saw_cp.history['val_err_u2'][start:],'b:')
  ax2.legend(handles=[line4,line5],labels=["err_u1","err_u2",])
  ax2.set_ylabel("error_rate")
  ax2.set_xlabel("epochs")
  ax2.autoscale()
  fig.suptitle("Adam")

  plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
  plt.show()

  fig.savefig("2d_cBurgers_eg1_Adam_history.png")
  return fig

# %%
def plot_Lbfgs_history(histroy,max_iterations):

  fig_lbfgs,ax = plt.subplots()
  ax.plot(histroy,'b:')
  ax.set_xlabel("num_objective_evaluations")
  ax.set_ylabel("loss")
  ax.set_title("L-BFGS Max_Iterations={}".format(max_iterations))
  
  plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
  plt.show()

  fig_lbfgs.savefig("2d_cBurgers_eg1_lbfgs_history.png")
  return fig_lbfgs

# %% [markdown]
# # PINN Model

# %% [markdown]
# ## Single PINN

# %%
class SinglePinn(keras.Sequential): 
    def __init__(self,Layers,name = None): 
        super(SinglePinn, self).__init__(name=name)
        self.add(keras.Input(shape=(Layers[0],) ,dtype=tf.float64))
        for i in range(1,len(Layers)-1):
            self.add(keras.layers.Dense(Layers[i], dtype=tf.float64,
                kernel_regularizer=keras.regularizers.l2(0.01), 
                activity_regularizer=keras.regularizers.l1(0.01), 
                activation='tanh'))
        self.add(keras.layers.Dense(Layers[-1],dtype=tf.float64, name="outputs"))

    @tf.function
    def loss_U(self,X_u_train,u_train):
        u= self(X_u_train,training=True)
        loss_u = tf.reduce_mean(tf.square(u_train - u))
        return loss_u

# %% [markdown]
# ## Coupled PINN

# %%
class CoupledPinnLoss(keras.losses.Loss):
  def __init__(self,model,name="pinn_loss"):
      super().__init__(name=name)
      self.model = model
  def __call__(self,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train):
  
    loss_u1_BC = self.model.m1.loss_U(X_u1_train,u1_train)
    loss_u2_BC = self.model.m2.loss_U(X_u2_train,u2_train) 
    loss_u1_PDE,loss_u2_PDE = self.model.loss_PDE(X_f_train)

    loss_u1_total = loss_u1_BC + loss_u1_PDE 
    loss_u2_total = loss_u2_BC + loss_u2_PDE 

    loss = loss_u1_total + loss_u2_total
    return loss, loss_u1_total, loss_u2_total

# %%
class CoupledPinn(keras.Model):
  def __init__(self,model_u1,model_u2,a,b,eta,name=None):
    super().__init__(name=name)
    self.m1 = model_u1 
    self.m2 = model_u2
    self.a = tf.constant(a,dtype=tf.float64)
    self.b = tf.constant(b,dtype=tf.float64)
    self.eta = tf.constant(eta,dtype=tf.float64)

    # Metrics
    self.loss_tracker = keras.metrics.Mean(name="loss")
    self.loss_u1 = keras.metrics.Mean(name="loss_u1")
    self.loss_u2 = keras.metrics.Mean(name="loss_u2")

    self.u1_error = keras.metrics.Mean(name="err_u1")
    self.u2_error = keras.metrics.Mean(name="err_u2")
    
  @property
  def metrics(self):
      # We list our `Metric` objects here so that `reset_states()` can be
      # called automatically at the start of each epoch
      # or at the start of `evaluate()`.
      # If you don't implement this property, you have to call
      # `reset_states()` yourself at the time of your choosing.
      m = [self.loss_tracker,
           self.loss_u1,
           self.loss_u2,
           self.u1_error,
           self.u2_error]
      return m 

  @tf.function
  def loss_PDE(self,X_f_train):
      x = X_f_train[:,0:1]
      t = X_f_train[:,1:2]
    
      with tf.GradientTape(persistent=True) as tape:
          tape.watch([x,t])
          X = tf.stack([x[:,0],t[:,0]],axis=1)

          U1 = self.m1(X,training=True)
          U2 = self.m2(X,training=True)

          U1_x = tape.gradient(U1,x)
          U2_x = tape.gradient(U2,x)
      
      U1_xx = tape.gradient(U1_x, x)
      U2_xx = tape.gradient(U2_x, x)

      U1_t = tape.gradient(U1,t)
      U2_t = tape.gradient(U2,t)

      del tape

      loss_u1_PDE = U1_t - U1_xx + self.eta * U1 * U1_x + self.a * U1_x * U2 + U1 * U2_x
      loss_u2_PDE = U2_t - U2_xx + self.eta * U2 * U2_x + self.b * U1_x * U2 + U1 * U2_x

      loss_u1_PDE = tf.reduce_mean(tf.square(loss_u1_PDE)) 
      loss_u2_PDE = tf.reduce_mean(tf.square(loss_u2_PDE))

      return loss_u1_PDE,loss_u2_PDE
      

  """耦合区域 PINN训练方法"""
  @tf.function
  def train_step(self,data):
      (X_u1_train,u1_train),(X_u2_train,u2_train),X_f_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss,loss_u1_total,loss_u2_total = self.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)
      
      # Compute gradients
      #gradients = tape.gradient(loss,self.trainable_variables)

      gradients_u1 = tape.gradient(loss,self.m1.trainable_variables)
      gradients_u2 = tape.gradient(loss,self.m2.trainable_variables)

      del tape

      # Updata parameters
      #self.optimizer.apply_gradients(zip(gradients,self.trainable_variables))

      self.m1.optimizer.apply_gradients(zip(gradients_u1,self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_u2,self.m2.trainable_variables))

      # Updata loss Metric
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_u1_total)
      self.loss_u2.update_state(loss_u2_total)


      metrics = {m.name : m.result() for m in self.metrics[:,-2]}

      return metrics

  @tf.function
  def test_step(self,data):
    (x1_test,u1_test),(x2_test,u2_test) = data
    # Updata test Metric
    u1_pred = self.m1(x1_test)
    u2_pred = self.m2(x2_test)
    err_u1 = tf.linalg.norm(u1_test-u1_pred) / tf.linalg.norm(u1_test)
    err_u2 = tf.linalg.norm(u2_test-u2_pred) / tf.linalg.norm(u2_test)  

    self.u1_error.update_state(err_u1) 
    self.u2_error.update_state(err_u2)
    
    return {self.u1_error.name:self.u1_error.result(),
            self.u2_error.name:self.u2_error.result()}

# %% [markdown]
# ## Self-Adaptive-Weight Couple PINN

# %%
class SawCoupledPinnLoss(keras.losses.Loss):
  def __init__(self,model,name="saw_couple_pinn_loss"):
      super().__init__(name=name)
      self.model = model
  
  @tf.function
  def __call__(self,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train):
  
    loss_u1_BC = self.model.m1.loss_U(X_u1_train,u1_train)
    loss_u2_BC = self.model.m2.loss_U(X_u2_train,u2_train) 
    loss_u1_PDE,loss_u2_PDE = self.model.loss_PDE(X_f_train)

    #loss = (10*loss_u1_BC+loss_u1_PDE) + (10*loss_u2_BC+loss_u2_PDE)
    loss_adaptive = (5*loss_u1_BC+loss_u1_PDE) + self.model.alpha*(5*loss_u2_BC+loss_u2_PDE)

    # update alpha
    self.model.alpha.assign( (loss_u1_BC+loss_u1_PDE) /(loss_u2_BC+loss_u2_PDE+self.model.eps))

    return loss_adaptive, loss_u1_BC,loss_u2_BC, loss_u1_PDE,loss_u2_PDE

# %%
class SawCouplePinn(CoupledPinn):
  def __init__(self,model_u1,model_u2,a,b,eta,name=None):
    super().__init__(model_u1,model_u2,a,b,eta,name=name)
    # Self-Adaptive-Weights    
    self.eps = tf.constant(1e-10,dtype=tf.float64)
    self.alpha = tf.Variable(1.0,dtype = tf.float64, trainable = False, name='alpha')

  
  """Self-Adaptive-Weights 耦合PINN训练方法"""
  @tf.function
  def train_step(self,data):
  
      (X_u1_train,u1_train),(X_u2_train,u2_train),X_f_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss_adaptive,loss_u1_BC,loss_u2_BC,loss_u1_PDE,loss_u2_PDE = self.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)

      loss_u1 = loss_u1_BC + loss_u1_PDE
      loss_u2 = loss_u2_BC + loss_u2_PDE
      loss = loss_u1 + loss_u2


      # Compute gradients
      #gradients = tape.gradient(loss_adaptive,self.trainable_variables)

      gradients_u1 = tape.gradient(loss_adaptive,self.m1.trainable_variables)
      gradients_u2 = tape.gradient(loss_adaptive,self.m2.trainable_variables)

      del tape

      # Update parameters
      #self.optimizer.apply_gradients(zip(gradients,self.trainable_variables))

      self.m1.optimizer.apply_gradients(zip(gradients_u1,self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_u2,self.m2.trainable_variables))

      # Updata loss Metric
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_u1)
      self.loss_u2.update_state(loss_u2)


      metrics = {m.name : m.result() for m in self.metrics[:-2]}

      return metrics

# %% [markdown]
# ## function factory

# %%
def function_factory(model,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train,untrainable_nums=0):
    """A factory to create a function required by tfp.optimizer.lbfgs_minimize.
    Args:
        model [in]: an instance of `tf.keras.Model` or its subclasses.
        loss [in]: a loss function in model
    Returns:
        A function that has a signature of:
            loss_value, gradients = f(model_parameters).
    """

    # obtain the shapes of all trainable parameters in the model
    if untrainable_nums == 0:
      shapes = tf.shape_n(model.trainable_variables[:])
    else:
      shapes = tf.shape_n(model.trainable_variables[:-untrainable_nums])
    n_tensors = len(shapes)
    trainable_nums = n_tensors

    # we'll use tf.dynamic_stitch and tf.dynamic_partition later, so we need to
    # prepare required information first
    count = 0
    idx = [] # stitch indices
    part = [] # partition indices

    for i, shape in enumerate(shapes):
          n = np.product(shape)
          idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32), shape))
          part.extend([i]*n)
          count += n

    part = tf.constant(part)

    @tf.function
    def assign_new_model_parameters(params_1d):
        """A function updating the model's parameters with a 1D tf.Tensor.
        Args:
            params_1d [in]: a 1D tf.Tensor representing the model's trainable parameters.
        """

        params = tf.dynamic_partition(params_1d, part, n_tensors)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            model.trainable_variables[i].assign(tf.reshape(param, shape))

    # now create a function that will be returned by this factory
    @tf.function
    def f(params_1d):
        """A function that can be used by tfp.optimizer.lbfgs_minimize.
        This function is created by function_factory.
        Args:
           params_1d [in]: a 1D tf.Tensor.
        Returns:
            A scalar loss and the gradients w.r.t. the `params_1d`.
        """
        
        # update the parameters in the model
        assign_new_model_parameters(params_1d)
        # use GradientTape so that we can calculate the gradient of loss w.r.t. parameters
        with tf.GradientTape() as tape:
            
            # calculate the loss
            loss_total = model.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)[0]

        # calculate gradients and convert to 1D tf.Tensor
        grads = tape.gradient(loss_total, model.trainable_variables[:trainable_nums])
        grads = tf.dynamic_stitch(idx, grads)

        del tape

        # print out iteration & loss
        f.num_objective_evaluations.assign_add(1)
        if (f.num_objective_evaluations % 50 == 0) :
          tf.print("num_objective_evaluations:", f.num_objective_evaluations,
                   "loss:",loss_total)

        # store loss value and k so we can retrieve later
        tf.py_function(f.loss_history.append, inp=[loss_total], Tout=[])

        return loss_total, grads

    # store these information as members so we can use them outside the scope
    f.num_objective_evaluations = tf.Variable(0)
    f.idx = idx
    f.part = part
    f.shapes = shapes
    f.assign_new_model_parameters = assign_new_model_parameters
    f.loss_history = []
    f.count = count

    return f

# %% [markdown]
# # Train

# %%
""" Training Data """

omga1 = [[-np.pi,np.pi],[0.,1.]]  # (x,t)的取值范围 
omga2 = [[-np.pi,np.pi],[0.,1.]]  # (x,t)的取值范围  



N_u1 = 200 ; N_f = 2000; omga = omga1;  u = u1
X_u1_train,u1_train,X_f_train= trainingdata(N_u1,N_f,omga,u)


N_u2 = 200; N_f = 2000; omga = omga2;  u = u2
X_u2_train,u2_train,X_f_train= trainingdata(N_u2,N_f,omga,u)


""" test Data """
N = 10000
x1_test,u1_test = test_data(N,omga1,u1)
x2_test,u2_test = test_data(N,omga2,u2)


""" DataSet  """
ds_train = ds_train_n_batch(X_u1_train, u1_train,  X_u2_train , u2_train ,  X_f_train ,n = 10)
ds_test = ds_test_n_batch(x1_test,u1_test,x2_test,u2_test,n=1)

# %%
Layers=[2,40,40,40,40,1]

model_u1 = SinglePinn(Layers,name="model_u1")
model_u1.compile(optimizer=keras.optimizers.Adam())

model_u2 = SinglePinn(Layers,name="model_u2")
model_u2.compile(optimizer=keras.optimizers.Adam())

# %%
saw_couple_model=SawCouplePinn(model_u1,model_u2,a,b,eta,name="saw_couple_pinn");
saw_couple_model.compile( loss=SawCoupledPinnLoss(saw_couple_model),
          optimizer=keras.optimizers.Adam() )

# %%
history_saw_cp_1 = saw_couple_model.fit(ds_train,validation_data=ds_test,epochs=500) #saw耦合PINN训练 Adam
# Out:
# Epoch 1/500
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# 10/10 [==============================] - 42s 130ms/step - loss: 0.2658 - loss_u1: 0.1275 - loss_u2: 0.1383 - val_err_u1: 0.6661 - val_err_u2: 0.6450
# Epoch 2/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.2609 - loss_u1: 0.1193 - loss_u2: 0.1417 - val_err_u1: 0.5112 - val_err_u2: 0.4883
# Epoch 3/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.3004 - loss_u1: 0.1424 - loss_u2: 0.1580 - val_err_u1: 0.3645 - val_err_u2: 0.4456
# Epoch 4/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3770 - loss_u1: 0.1828 - loss_u2: 0.1942 - val_err_u1: 0.3039 - val_err_u2: 0.4509
# Epoch 5/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3970 - loss_u1: 0.1882 - loss_u2: 0.2088 - val_err_u1: 0.2642 - val_err_u2: 0.4472
# Epoch 6/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3263 - loss_u1: 0.1425 - loss_u2: 0.1838 - val_err_u1: 0.1998 - val_err_u2: 0.4296
# Epoch 7/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2321 - loss_u1: 0.0860 - loss_u2: 0.1461 - val_err_u1: 0.1434 - val_err_u2: 0.3825
# Epoch 8/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.1735 - loss_u1: 0.0546 - loss_u2: 0.1189 - val_err_u1: 0.1158 - val_err_u2: 0.3255
# Epoch 9/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.1513 - loss_u1: 0.0419 - loss_u2: 0.1094 - val_err_u1: 0.1138 - val_err_u2: 0.2484
# Epoch 10/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1432 - loss_u1: 0.0354 - loss_u2: 0.1078 - val_err_u1: 0.1083 - val_err_u2: 0.1692
# Epoch 11/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.1332 - loss_u1: 0.0312 - loss_u2: 0.1020 - val_err_u1: 0.0923 - val_err_u2: 0.1454
# Epoch 12/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1181 - loss_u1: 0.0275 - loss_u2: 0.0906 - val_err_u1: 0.0785 - val_err_u2: 0.1366
# Epoch 13/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.1009 - loss_u1: 0.0229 - loss_u2: 0.0780 - val_err_u1: 0.0704 - val_err_u2: 0.1349
# Epoch 14/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0864 - loss_u1: 0.0187 - loss_u2: 0.0676 - val_err_u1: 0.0680 - val_err_u2: 0.1237
# Epoch 15/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0743 - loss_u1: 0.0161 - loss_u2: 0.0582 - val_err_u1: 0.0669 - val_err_u2: 0.1125
# Epoch 16/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0635 - loss_u1: 0.0137 - loss_u2: 0.0498 - val_err_u1: 0.0597 - val_err_u2: 0.1062
# Epoch 17/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0543 - loss_u1: 0.0120 - loss_u2: 0.0423 - val_err_u1: 0.0567 - val_err_u2: 0.0924
# Epoch 18/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0464 - loss_u1: 0.0108 - loss_u2: 0.0356 - val_err_u1: 0.0602 - val_err_u2: 0.0813
# Epoch 19/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0396 - loss_u1: 0.0099 - loss_u2: 0.0297 - val_err_u1: 0.0680 - val_err_u2: 0.0729
# Epoch 20/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0338 - loss_u1: 0.0093 - loss_u2: 0.0245 - val_err_u1: 0.0730 - val_err_u2: 0.0661
# Epoch 21/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0290 - loss_u1: 0.0088 - loss_u2: 0.0202 - val_err_u1: 0.0681 - val_err_u2: 0.0607
# Epoch 22/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0252 - loss_u1: 0.0085 - loss_u2: 0.0167 - val_err_u1: 0.0587 - val_err_u2: 0.0550
# Epoch 23/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0223 - loss_u1: 0.0083 - loss_u2: 0.0140 - val_err_u1: 0.0532 - val_err_u2: 0.0499
# Epoch 24/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0200 - loss_u1: 0.0081 - loss_u2: 0.0119 - val_err_u1: 0.0526 - val_err_u2: 0.0456
# Epoch 25/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0183 - loss_u1: 0.0079 - loss_u2: 0.0104 - val_err_u1: 0.0510 - val_err_u2: 0.0423
# Epoch 26/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0170 - loss_u1: 0.0077 - loss_u2: 0.0093 - val_err_u1: 0.0487 - val_err_u2: 0.0400
# Epoch 27/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0161 - loss_u1: 0.0075 - loss_u2: 0.0085 - val_err_u1: 0.0484 - val_err_u2: 0.0393
# Epoch 28/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0154 - loss_u1: 0.0074 - loss_u2: 0.0080 - val_err_u1: 0.0479 - val_err_u2: 0.0398
# Epoch 29/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0148 - loss_u1: 0.0072 - loss_u2: 0.0076 - val_err_u1: 0.0474 - val_err_u2: 0.0387
# Epoch 30/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0144 - loss_u1: 0.0071 - loss_u2: 0.0074 - val_err_u1: 0.0461 - val_err_u2: 0.0362
# Epoch 31/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0141 - loss_u1: 0.0069 - loss_u2: 0.0072 - val_err_u1: 0.0451 - val_err_u2: 0.0347
# Epoch 32/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0137 - loss_u1: 0.0067 - loss_u2: 0.0070 - val_err_u1: 0.0445 - val_err_u2: 0.0345
# Epoch 33/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0135 - loss_u1: 0.0066 - loss_u2: 0.0069 - val_err_u1: 0.0438 - val_err_u2: 0.0338
# Epoch 34/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0132 - loss_u1: 0.0064 - loss_u2: 0.0068 - val_err_u1: 0.0430 - val_err_u2: 0.0332
# Epoch 35/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0130 - loss_u1: 0.0063 - loss_u2: 0.0067 - val_err_u1: 0.0424 - val_err_u2: 0.0332
# Epoch 36/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0128 - loss_u1: 0.0062 - loss_u2: 0.0066 - val_err_u1: 0.0418 - val_err_u2: 0.0331
# Epoch 37/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0126 - loss_u1: 0.0060 - loss_u2: 0.0066 - val_err_u1: 0.0411 - val_err_u2: 0.0332
# Epoch 38/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0125 - loss_u1: 0.0059 - loss_u2: 0.0065 - val_err_u1: 0.0405 - val_err_u2: 0.0334
# Epoch 39/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0123 - loss_u1: 0.0058 - loss_u2: 0.0065 - val_err_u1: 0.0400 - val_err_u2: 0.0337
# Epoch 40/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0122 - loss_u1: 0.0057 - loss_u2: 0.0064 - val_err_u1: 0.0395 - val_err_u2: 0.0341
# Epoch 41/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0120 - loss_u1: 0.0056 - loss_u2: 0.0064 - val_err_u1: 0.0391 - val_err_u2: 0.0344
# Epoch 42/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0119 - loss_u1: 0.0055 - loss_u2: 0.0063 - val_err_u1: 0.0388 - val_err_u2: 0.0347
# Epoch 43/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0117 - loss_u1: 0.0054 - loss_u2: 0.0063 - val_err_u1: 0.0384 - val_err_u2: 0.0349
# Epoch 44/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0115 - loss_u1: 0.0053 - loss_u2: 0.0062 - val_err_u1: 0.0379 - val_err_u2: 0.0349
# Epoch 45/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0114 - loss_u1: 0.0052 - loss_u2: 0.0061 - val_err_u1: 0.0374 - val_err_u2: 0.0349
# Epoch 46/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0112 - loss_u1: 0.0051 - loss_u2: 0.0061 - val_err_u1: 0.0366 - val_err_u2: 0.0349
# Epoch 47/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0110 - loss_u1: 0.0050 - loss_u2: 0.0060 - val_err_u1: 0.0358 - val_err_u2: 0.0348
# Epoch 48/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0108 - loss_u1: 0.0049 - loss_u2: 0.0059 - val_err_u1: 0.0349 - val_err_u2: 0.0347
# Epoch 49/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0107 - loss_u1: 0.0048 - loss_u2: 0.0059 - val_err_u1: 0.0340 - val_err_u2: 0.0347
# Epoch 50/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0105 - loss_u1: 0.0047 - loss_u2: 0.0058 - val_err_u1: 0.0332 - val_err_u2: 0.0347
# Epoch 51/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0104 - loss_u1: 0.0047 - loss_u2: 0.0057 - val_err_u1: 0.0325 - val_err_u2: 0.0348
# Epoch 52/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0102 - loss_u1: 0.0046 - loss_u2: 0.0057 - val_err_u1: 0.0319 - val_err_u2: 0.0348
# Epoch 53/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0101 - loss_u1: 0.0045 - loss_u2: 0.0056 - val_err_u1: 0.0313 - val_err_u2: 0.0349
# Epoch 54/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0100 - loss_u1: 0.0044 - loss_u2: 0.0055 - val_err_u1: 0.0309 - val_err_u2: 0.0349
# Epoch 55/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0098 - loss_u1: 0.0044 - loss_u2: 0.0055 - val_err_u1: 0.0305 - val_err_u2: 0.0350
# Epoch 56/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0097 - loss_u1: 0.0043 - loss_u2: 0.0054 - val_err_u1: 0.0301 - val_err_u2: 0.0350
# Epoch 57/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0096 - loss_u1: 0.0042 - loss_u2: 0.0053 - val_err_u1: 0.0297 - val_err_u2: 0.0351
# Epoch 58/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0094 - loss_u1: 0.0042 - loss_u2: 0.0053 - val_err_u1: 0.0293 - val_err_u2: 0.0351
# Epoch 59/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0093 - loss_u1: 0.0041 - loss_u2: 0.0052 - val_err_u1: 0.0290 - val_err_u2: 0.0352
# Epoch 60/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0092 - loss_u1: 0.0041 - loss_u2: 0.0051 - val_err_u1: 0.0287 - val_err_u2: 0.0353
# Epoch 61/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0091 - loss_u1: 0.0040 - loss_u2: 0.0051 - val_err_u1: 0.0284 - val_err_u2: 0.0353
# Epoch 62/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0089 - loss_u1: 0.0039 - loss_u2: 0.0050 - val_err_u1: 0.0281 - val_err_u2: 0.0354
# Epoch 63/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0088 - loss_u1: 0.0039 - loss_u2: 0.0049 - val_err_u1: 0.0278 - val_err_u2: 0.0354
# Epoch 64/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0087 - loss_u1: 0.0038 - loss_u2: 0.0049 - val_err_u1: 0.0275 - val_err_u2: 0.0354
# Epoch 65/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0086 - loss_u1: 0.0038 - loss_u2: 0.0048 - val_err_u1: 0.0272 - val_err_u2: 0.0355
# Epoch 66/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0085 - loss_u1: 0.0037 - loss_u2: 0.0048 - val_err_u1: 0.0270 - val_err_u2: 0.0355
# Epoch 67/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0084 - loss_u1: 0.0037 - loss_u2: 0.0047 - val_err_u1: 0.0267 - val_err_u2: 0.0355
# Epoch 68/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0083 - loss_u1: 0.0036 - loss_u2: 0.0047 - val_err_u1: 0.0265 - val_err_u2: 0.0356
# Epoch 69/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0082 - loss_u1: 0.0036 - loss_u2: 0.0046 - val_err_u1: 0.0262 - val_err_u2: 0.0356
# Epoch 70/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0081 - loss_u1: 0.0035 - loss_u2: 0.0046 - val_err_u1: 0.0260 - val_err_u2: 0.0356
# Epoch 71/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0080 - loss_u1: 0.0035 - loss_u2: 0.0045 - val_err_u1: 0.0257 - val_err_u2: 0.0356
# Epoch 72/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0079 - loss_u1: 0.0034 - loss_u2: 0.0045 - val_err_u1: 0.0255 - val_err_u2: 0.0356
# Epoch 73/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0078 - loss_u1: 0.0034 - loss_u2: 0.0044 - val_err_u1: 0.0253 - val_err_u2: 0.0356
# Epoch 74/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0077 - loss_u1: 0.0033 - loss_u2: 0.0044 - val_err_u1: 0.0251 - val_err_u2: 0.0356
# Epoch 75/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0076 - loss_u1: 0.0033 - loss_u2: 0.0043 - val_err_u1: 0.0249 - val_err_u2: 0.0356
# Epoch 76/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0075 - loss_u1: 0.0032 - loss_u2: 0.0043 - val_err_u1: 0.0246 - val_err_u2: 0.0356
# Epoch 77/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0074 - loss_u1: 0.0032 - loss_u2: 0.0042 - val_err_u1: 0.0244 - val_err_u2: 0.0356
# Epoch 78/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0073 - loss_u1: 0.0032 - loss_u2: 0.0042 - val_err_u1: 0.0242 - val_err_u2: 0.0356
# Epoch 79/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0072 - loss_u1: 0.0031 - loss_u2: 0.0041 - val_err_u1: 0.0240 - val_err_u2: 0.0356
# Epoch 80/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0072 - loss_u1: 0.0031 - loss_u2: 0.0041 - val_err_u1: 0.0238 - val_err_u2: 0.0355
# Epoch 81/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0071 - loss_u1: 0.0030 - loss_u2: 0.0040 - val_err_u1: 0.0236 - val_err_u2: 0.0355
# Epoch 82/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0070 - loss_u1: 0.0030 - loss_u2: 0.0040 - val_err_u1: 0.0234 - val_err_u2: 0.0354
# Epoch 83/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0069 - loss_u1: 0.0030 - loss_u2: 0.0039 - val_err_u1: 0.0232 - val_err_u2: 0.0354
# Epoch 84/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0068 - loss_u1: 0.0029 - loss_u2: 0.0039 - val_err_u1: 0.0231 - val_err_u2: 0.0353
# Epoch 85/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0068 - loss_u1: 0.0029 - loss_u2: 0.0039 - val_err_u1: 0.0229 - val_err_u2: 0.0353
# Epoch 86/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0067 - loss_u1: 0.0029 - loss_u2: 0.0038 - val_err_u1: 0.0227 - val_err_u2: 0.0352
# Epoch 87/500
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0066 - loss_u1: 0.0028 - loss_u2: 0.0038 - val_err_u1: 0.0225 - val_err_u2: 0.0352
# Epoch 88/500
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0065 - loss_u1: 0.0028 - loss_u2: 0.0037 - val_err_u1: 0.0223 - val_err_u2: 0.0351
# Epoch 89/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0065 - loss_u1: 0.0028 - loss_u2: 0.0037 - val_err_u1: 0.0221 - val_err_u2: 0.0350
# Epoch 90/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0064 - loss_u1: 0.0027 - loss_u2: 0.0037 - val_err_u1: 0.0219 - val_err_u2: 0.0350
# Epoch 91/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0063 - loss_u1: 0.0027 - loss_u2: 0.0036 - val_err_u1: 0.0218 - val_err_u2: 0.0349
# Epoch 92/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0062 - loss_u1: 0.0027 - loss_u2: 0.0036 - val_err_u1: 0.0216 - val_err_u2: 0.0348
# Epoch 93/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0062 - loss_u1: 0.0026 - loss_u2: 0.0035 - val_err_u1: 0.0214 - val_err_u2: 0.0348
# Epoch 94/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0061 - loss_u1: 0.0026 - loss_u2: 0.0035 - val_err_u1: 0.0212 - val_err_u2: 0.0347
# Epoch 95/500
# 10/10 [==============================] - 0s 39ms/step - loss: 0.0060 - loss_u1: 0.0026 - loss_u2: 0.0035 - val_err_u1: 0.0211 - val_err_u2: 0.0346
# Epoch 96/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0060 - loss_u1: 0.0025 - loss_u2: 0.0034 - val_err_u1: 0.0209 - val_err_u2: 0.0346
# Epoch 97/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0059 - loss_u1: 0.0025 - loss_u2: 0.0034 - val_err_u1: 0.0207 - val_err_u2: 0.0345
# Epoch 98/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0059 - loss_u1: 0.0025 - loss_u2: 0.0034 - val_err_u1: 0.0206 - val_err_u2: 0.0345
# Epoch 99/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0058 - loss_u1: 0.0025 - loss_u2: 0.0033 - val_err_u1: 0.0204 - val_err_u2: 0.0344
# Epoch 100/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0057 - loss_u1: 0.0024 - loss_u2: 0.0033 - val_err_u1: 0.0203 - val_err_u2: 0.0344
# Epoch 101/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0057 - loss_u1: 0.0024 - loss_u2: 0.0033 - val_err_u1: 0.0201 - val_err_u2: 0.0343
# Epoch 102/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0056 - loss_u1: 0.0024 - loss_u2: 0.0032 - val_err_u1: 0.0199 - val_err_u2: 0.0343
# Epoch 103/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0055 - loss_u1: 0.0023 - loss_u2: 0.0032 - val_err_u1: 0.0198 - val_err_u2: 0.0343
# Epoch 104/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0055 - loss_u1: 0.0023 - loss_u2: 0.0032 - val_err_u1: 0.0196 - val_err_u2: 0.0343
# Epoch 105/500
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0054 - loss_u1: 0.0023 - loss_u2: 0.0031 - val_err_u1: 0.0195 - val_err_u2: 0.0343
# Epoch 106/500
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0054 - loss_u1: 0.0023 - loss_u2: 0.0031 - val_err_u1: 0.0193 - val_err_u2: 0.0343
# Epoch 107/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0053 - loss_u1: 0.0022 - loss_u2: 0.0031 - val_err_u1: 0.0192 - val_err_u2: 0.0343
# Epoch 108/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0053 - loss_u1: 0.0022 - loss_u2: 0.0030 - val_err_u1: 0.0190 - val_err_u2: 0.0344
# Epoch 109/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0052 - loss_u1: 0.0022 - loss_u2: 0.0030 - val_err_u1: 0.0189 - val_err_u2: 0.0345
# Epoch 110/500
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0052 - loss_u1: 0.0022 - loss_u2: 0.0030 - val_err_u1: 0.0188 - val_err_u2: 0.0345
# Epoch 111/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0051 - loss_u1: 0.0022 - loss_u2: 0.0030 - val_err_u1: 0.0186 - val_err_u2: 0.0346
# Epoch 112/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0051 - loss_u1: 0.0021 - loss_u2: 0.0029 - val_err_u1: 0.0185 - val_err_u2: 0.0348
# Epoch 113/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0050 - loss_u1: 0.0021 - loss_u2: 0.0029 - val_err_u1: 0.0184 - val_err_u2: 0.0349
# Epoch 114/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0050 - loss_u1: 0.0021 - loss_u2: 0.0029 - val_err_u1: 0.0183 - val_err_u2: 0.0350
# Epoch 115/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0049 - loss_u1: 0.0021 - loss_u2: 0.0028 - val_err_u1: 0.0181 - val_err_u2: 0.0352
# Epoch 116/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0049 - loss_u1: 0.0020 - loss_u2: 0.0028 - val_err_u1: 0.0180 - val_err_u2: 0.0353
# Epoch 117/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0048 - loss_u1: 0.0020 - loss_u2: 0.0028 - val_err_u1: 0.0179 - val_err_u2: 0.0355
# Epoch 118/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0048 - loss_u1: 0.0020 - loss_u2: 0.0028 - val_err_u1: 0.0178 - val_err_u2: 0.0356
# Epoch 119/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0047 - loss_u1: 0.0020 - loss_u2: 0.0027 - val_err_u1: 0.0177 - val_err_u2: 0.0358
# Epoch 120/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0047 - loss_u1: 0.0020 - loss_u2: 0.0027 - val_err_u1: 0.0176 - val_err_u2: 0.0359
# Epoch 121/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0046 - loss_u1: 0.0019 - loss_u2: 0.0027 - val_err_u1: 0.0174 - val_err_u2: 0.0360
# Epoch 122/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0046 - loss_u1: 0.0019 - loss_u2: 0.0027 - val_err_u1: 0.0173 - val_err_u2: 0.0361
# Epoch 123/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0045 - loss_u1: 0.0019 - loss_u2: 0.0026 - val_err_u1: 0.0172 - val_err_u2: 0.0361
# Epoch 124/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0045 - loss_u1: 0.0019 - loss_u2: 0.0026 - val_err_u1: 0.0171 - val_err_u2: 0.0361
# Epoch 125/500
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0045 - loss_u1: 0.0019 - loss_u2: 0.0026 - val_err_u1: 0.0169 - val_err_u2: 0.0361
# Epoch 126/500
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0044 - loss_u1: 0.0018 - loss_u2: 0.0026 - val_err_u1: 0.0168 - val_err_u2: 0.0361
# Epoch 127/500
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0044 - loss_u1: 0.0018 - loss_u2: 0.0026 - val_err_u1: 0.0166 - val_err_u2: 0.0360
# Epoch 128/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0043 - loss_u1: 0.0018 - loss_u2: 0.0025 - val_err_u1: 0.0164 - val_err_u2: 0.0360
# Epoch 129/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0043 - loss_u1: 0.0018 - loss_u2: 0.0025 - val_err_u1: 0.0163 - val_err_u2: 0.0359
# Epoch 130/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0043 - loss_u1: 0.0018 - loss_u2: 0.0025 - val_err_u1: 0.0161 - val_err_u2: 0.0357
# Epoch 131/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0042 - loss_u1: 0.0018 - loss_u2: 0.0025 - val_err_u1: 0.0159 - val_err_u2: 0.0356
# Epoch 132/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0042 - loss_u1: 0.0017 - loss_u2: 0.0025 - val_err_u1: 0.0158 - val_err_u2: 0.0355
# Epoch 133/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0042 - loss_u1: 0.0017 - loss_u2: 0.0024 - val_err_u1: 0.0156 - val_err_u2: 0.0353
# Epoch 134/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0041 - loss_u1: 0.0017 - loss_u2: 0.0024 - val_err_u1: 0.0154 - val_err_u2: 0.0352
# Epoch 135/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0041 - loss_u1: 0.0017 - loss_u2: 0.0024 - val_err_u1: 0.0152 - val_err_u2: 0.0350
# Epoch 136/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0041 - loss_u1: 0.0017 - loss_u2: 0.0024 - val_err_u1: 0.0151 - val_err_u2: 0.0349
# Epoch 137/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0040 - loss_u1: 0.0017 - loss_u2: 0.0024 - val_err_u1: 0.0149 - val_err_u2: 0.0347
# Epoch 138/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0040 - loss_u1: 0.0016 - loss_u2: 0.0024 - val_err_u1: 0.0147 - val_err_u2: 0.0346
# Epoch 139/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0040 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0146 - val_err_u2: 0.0344
# Epoch 140/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0039 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0144 - val_err_u2: 0.0343
# Epoch 141/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0039 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0142 - val_err_u2: 0.0342
# Epoch 142/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0039 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0141 - val_err_u2: 0.0340
# Epoch 143/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0039 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0139 - val_err_u2: 0.0339
# Epoch 144/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0038 - loss_u1: 0.0016 - loss_u2: 0.0023 - val_err_u1: 0.0137 - val_err_u2: 0.0338
# Epoch 145/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0038 - loss_u1: 0.0015 - loss_u2: 0.0023 - val_err_u1: 0.0136 - val_err_u2: 0.0337
# Epoch 146/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0038 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0134 - val_err_u2: 0.0335
# Epoch 147/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0037 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0132 - val_err_u2: 0.0334
# Epoch 148/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0037 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0131 - val_err_u2: 0.0333
# Epoch 149/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0037 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0129 - val_err_u2: 0.0332
# Epoch 150/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0037 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0128 - val_err_u2: 0.0331
# Epoch 151/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0036 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0126 - val_err_u2: 0.0331
# Epoch 152/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0036 - loss_u1: 0.0015 - loss_u2: 0.0022 - val_err_u1: 0.0125 - val_err_u2: 0.0330
# Epoch 153/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0036 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0123 - val_err_u2: 0.0329
# Epoch 154/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0036 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0122 - val_err_u2: 0.0328
# Epoch 155/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0035 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0121 - val_err_u2: 0.0328
# Epoch 156/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0035 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0120 - val_err_u2: 0.0327
# Epoch 157/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0035 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0119 - val_err_u2: 0.0326
# Epoch 158/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0035 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0118 - val_err_u2: 0.0326
# Epoch 159/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0034 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0117 - val_err_u2: 0.0325
# Epoch 160/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0034 - loss_u1: 0.0014 - loss_u2: 0.0021 - val_err_u1: 0.0116 - val_err_u2: 0.0325
# Epoch 161/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0034 - loss_u1: 0.0014 - loss_u2: 0.0020 - val_err_u1: 0.0116 - val_err_u2: 0.0324
# Epoch 162/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0034 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0115 - val_err_u2: 0.0323
# Epoch 163/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0033 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0115 - val_err_u2: 0.0323
# Epoch 164/500
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0033 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0115 - val_err_u2: 0.0322
# Epoch 165/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0033 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0114 - val_err_u2: 0.0321
# Epoch 166/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0033 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0114 - val_err_u2: 0.0321
# Epoch 167/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0033 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0114 - val_err_u2: 0.0320
# Epoch 168/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0032 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0114 - val_err_u2: 0.0319
# Epoch 169/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0032 - loss_u1: 0.0013 - loss_u2: 0.0020 - val_err_u1: 0.0113 - val_err_u2: 0.0319
# Epoch 170/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0032 - loss_u1: 0.0013 - loss_u2: 0.0019 - val_err_u1: 0.0113 - val_err_u2: 0.0318
# Epoch 171/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0032 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0112 - val_err_u2: 0.0317
# Epoch 172/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0032 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0112 - val_err_u2: 0.0316
# Epoch 173/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0031 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0111 - val_err_u2: 0.0316
# Epoch 174/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0031 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0110 - val_err_u2: 0.0315
# Epoch 175/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0031 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0109 - val_err_u2: 0.0314
# Epoch 176/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0031 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0109 - val_err_u2: 0.0313
# Epoch 177/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0031 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0108 - val_err_u2: 0.0312
# Epoch 178/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0030 - loss_u1: 0.0012 - loss_u2: 0.0019 - val_err_u1: 0.0107 - val_err_u2: 0.0311
# Epoch 179/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0030 - loss_u1: 0.0012 - loss_u2: 0.0018 - val_err_u1: 0.0107 - val_err_u2: 0.0310
# Epoch 180/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0030 - loss_u1: 0.0012 - loss_u2: 0.0018 - val_err_u1: 0.0107 - val_err_u2: 0.0308
# Epoch 181/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0030 - loss_u1: 0.0012 - loss_u2: 0.0018 - val_err_u1: 0.0107 - val_err_u2: 0.0307
# Epoch 182/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0030 - loss_u1: 0.0012 - loss_u2: 0.0018 - val_err_u1: 0.0109 - val_err_u2: 0.0306
# Epoch 183/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0111 - val_err_u2: 0.0304
# Epoch 184/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0114 - val_err_u2: 0.0303
# Epoch 185/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0118 - val_err_u2: 0.0301
# Epoch 186/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0122 - val_err_u2: 0.0300
# Epoch 187/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0126 - val_err_u2: 0.0299
# Epoch 188/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0029 - loss_u1: 0.0011 - loss_u2: 0.0018 - val_err_u1: 0.0128 - val_err_u2: 0.0297
# Epoch 189/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0028 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0129 - val_err_u2: 0.0296
# Epoch 190/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0028 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0128 - val_err_u2: 0.0296
# Epoch 191/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0028 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0125 - val_err_u2: 0.0295
# Epoch 192/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0028 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0120 - val_err_u2: 0.0295
# Epoch 193/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0028 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0115 - val_err_u2: 0.0295
# Epoch 194/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0027 - loss_u1: 0.0011 - loss_u2: 0.0017 - val_err_u1: 0.0109 - val_err_u2: 0.0296
# Epoch 195/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0027 - loss_u1: 0.0010 - loss_u2: 0.0017 - val_err_u1: 0.0103 - val_err_u2: 0.0297
# Epoch 196/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0027 - loss_u1: 0.0010 - loss_u2: 0.0017 - val_err_u1: 0.0099 - val_err_u2: 0.0299
# Epoch 197/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0027 - loss_u1: 0.0010 - loss_u2: 0.0017 - val_err_u1: 0.0096 - val_err_u2: 0.0302
# Epoch 198/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0027 - loss_u1: 0.0010 - loss_u2: 0.0017 - val_err_u1: 0.0095 - val_err_u2: 0.0305
# Epoch 199/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0027 - loss_u1: 0.0010 - loss_u2: 0.0017 - val_err_u1: 0.0096 - val_err_u2: 0.0308
# Epoch 200/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0027 - loss_u1: 9.9816e-04 - loss_u2: 0.0017 - val_err_u1: 0.0099 - val_err_u2: 0.0311
# Epoch 201/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0027 - loss_u1: 9.9381e-04 - loss_u2: 0.0017 - val_err_u1: 0.0104 - val_err_u2: 0.0314
# Epoch 202/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0027 - loss_u1: 9.9033e-04 - loss_u2: 0.0017 - val_err_u1: 0.0109 - val_err_u2: 0.0316
# Epoch 203/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0026 - loss_u1: 9.8730e-04 - loss_u2: 0.0017 - val_err_u1: 0.0115 - val_err_u2: 0.0318
# Epoch 204/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0026 - loss_u1: 9.8426e-04 - loss_u2: 0.0017 - val_err_u1: 0.0121 - val_err_u2: 0.0319
# Epoch 205/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0026 - loss_u1: 9.8081e-04 - loss_u2: 0.0016 - val_err_u1: 0.0126 - val_err_u2: 0.0319
# Epoch 206/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0026 - loss_u1: 9.7661e-04 - loss_u2: 0.0016 - val_err_u1: 0.0131 - val_err_u2: 0.0318
# Epoch 207/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0026 - loss_u1: 9.7147e-04 - loss_u2: 0.0016 - val_err_u1: 0.0134 - val_err_u2: 0.0317
# Epoch 208/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0026 - loss_u1: 9.6537e-04 - loss_u2: 0.0016 - val_err_u1: 0.0135 - val_err_u2: 0.0315
# Epoch 209/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0026 - loss_u1: 9.5842e-04 - loss_u2: 0.0016 - val_err_u1: 0.0136 - val_err_u2: 0.0313
# Epoch 210/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0026 - loss_u1: 9.5091e-04 - loss_u2: 0.0016 - val_err_u1: 0.0135 - val_err_u2: 0.0310
# Epoch 211/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0025 - loss_u1: 9.4318e-04 - loss_u2: 0.0016 - val_err_u1: 0.0134 - val_err_u2: 0.0308
# Epoch 212/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0025 - loss_u1: 9.3556e-04 - loss_u2: 0.0016 - val_err_u1: 0.0133 - val_err_u2: 0.0306
# Epoch 213/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0025 - loss_u1: 9.2833e-04 - loss_u2: 0.0016 - val_err_u1: 0.0131 - val_err_u2: 0.0304
# Epoch 214/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0025 - loss_u1: 9.2167e-04 - loss_u2: 0.0016 - val_err_u1: 0.0130 - val_err_u2: 0.0303
# Epoch 215/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0025 - loss_u1: 9.1566e-04 - loss_u2: 0.0015 - val_err_u1: 0.0129 - val_err_u2: 0.0302
# Epoch 216/500
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0025 - loss_u1: 9.1026e-04 - loss_u2: 0.0015 - val_err_u1: 0.0128 - val_err_u2: 0.0302
# Epoch 217/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0024 - loss_u1: 9.0537e-04 - loss_u2: 0.0015 - val_err_u1: 0.0127 - val_err_u2: 0.0302
# Epoch 218/500
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0024 - loss_u1: 9.0082e-04 - loss_u2: 0.0015 - val_err_u1: 0.0127 - val_err_u2: 0.0302
# Epoch 219/500
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0024 - loss_u1: 8.9645e-04 - loss_u2: 0.0015 - val_err_u1: 0.0126 - val_err_u2: 0.0301
# Epoch 220/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0024 - loss_u1: 8.9209e-04 - loss_u2: 0.0015 - val_err_u1: 0.0124 - val_err_u2: 0.0301
# Epoch 221/500
# 10/10 [==============================] - 0s 39ms/step - loss: 0.0024 - loss_u1: 8.8761e-04 - loss_u2: 0.0015 - val_err_u1: 0.0123 - val_err_u2: 0.0301
# Epoch 222/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0024 - loss_u1: 8.8290e-04 - loss_u2: 0.0015 - val_err_u1: 0.0121 - val_err_u2: 0.0300
# Epoch 223/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0024 - loss_u1: 8.7796e-04 - loss_u2: 0.0015 - val_err_u1: 0.0119 - val_err_u2: 0.0299
# Epoch 224/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0024 - loss_u1: 8.7281e-04 - loss_u2: 0.0015 - val_err_u1: 0.0118 - val_err_u2: 0.0298
# Epoch 225/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0024 - loss_u1: 8.6753e-04 - loss_u2: 0.0015 - val_err_u1: 0.0117 - val_err_u2: 0.0297
# Epoch 226/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0023 - loss_u1: 8.6224e-04 - loss_u2: 0.0015 - val_err_u1: 0.0116 - val_err_u2: 0.0296
# Epoch 227/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0023 - loss_u1: 8.5705e-04 - loss_u2: 0.0015 - val_err_u1: 0.0116 - val_err_u2: 0.0295
# Epoch 228/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0023 - loss_u1: 8.5205e-04 - loss_u2: 0.0015 - val_err_u1: 0.0116 - val_err_u2: 0.0294
# Epoch 229/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0023 - loss_u1: 8.4728e-04 - loss_u2: 0.0015 - val_err_u1: 0.0117 - val_err_u2: 0.0294
# Epoch 230/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0023 - loss_u1: 8.4273e-04 - loss_u2: 0.0014 - val_err_u1: 0.0118 - val_err_u2: 0.0294
# Epoch 231/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0023 - loss_u1: 8.3834e-04 - loss_u2: 0.0014 - val_err_u1: 0.0118 - val_err_u2: 0.0295
# Epoch 232/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0023 - loss_u1: 8.3399e-04 - loss_u2: 0.0014 - val_err_u1: 0.0118 - val_err_u2: 0.0295
# Epoch 233/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0023 - loss_u1: 8.2957e-04 - loss_u2: 0.0014 - val_err_u1: 0.0118 - val_err_u2: 0.0296
# Epoch 234/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0022 - loss_u1: 8.2500e-04 - loss_u2: 0.0014 - val_err_u1: 0.0117 - val_err_u2: 0.0297
# Epoch 235/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0022 - loss_u1: 8.2025e-04 - loss_u2: 0.0014 - val_err_u1: 0.0116 - val_err_u2: 0.0299
# Epoch 236/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0022 - loss_u1: 8.1535e-04 - loss_u2: 0.0014 - val_err_u1: 0.0116 - val_err_u2: 0.0300
# Epoch 237/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0022 - loss_u1: 8.1041e-04 - loss_u2: 0.0014 - val_err_u1: 0.0116 - val_err_u2: 0.0301
# Epoch 238/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0022 - loss_u1: 8.0554e-04 - loss_u2: 0.0014 - val_err_u1: 0.0117 - val_err_u2: 0.0303
# Epoch 239/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0022 - loss_u1: 8.0088e-04 - loss_u2: 0.0014 - val_err_u1: 0.0119 - val_err_u2: 0.0304
# Epoch 240/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0022 - loss_u1: 7.9655e-04 - loss_u2: 0.0014 - val_err_u1: 0.0121 - val_err_u2: 0.0305
# Epoch 241/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0022 - loss_u1: 7.9262e-04 - loss_u2: 0.0014 - val_err_u1: 0.0123 - val_err_u2: 0.0306
# Epoch 242/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0022 - loss_u1: 7.8911e-04 - loss_u2: 0.0014 - val_err_u1: 0.0126 - val_err_u2: 0.0307
# Epoch 243/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0022 - loss_u1: 7.8599e-04 - loss_u2: 0.0014 - val_err_u1: 0.0129 - val_err_u2: 0.0308
# Epoch 244/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0022 - loss_u1: 7.8318e-04 - loss_u2: 0.0014 - val_err_u1: 0.0132 - val_err_u2: 0.0309
# Epoch 245/500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0022 - loss_u1: 7.8058e-04 - loss_u2: 0.0014 - val_err_u1: 0.0135 - val_err_u2: 0.0309
# Epoch 246/500
# 10/10 [==============================] - 0s 51ms/step - loss: 0.0021 - loss_u1: 7.7804e-04 - loss_u2: 0.0014 - val_err_u1: 0.0137 - val_err_u2: 0.0309
# Epoch 247/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0021 - loss_u1: 7.7543e-04 - loss_u2: 0.0014 - val_err_u1: 0.0139 - val_err_u2: 0.0309
# Epoch 248/500
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0021 - loss_u1: 7.7260e-04 - loss_u2: 0.0014 - val_err_u1: 0.0141 - val_err_u2: 0.0308
# Epoch 249/500
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0021 - loss_u1: 7.6945e-04 - loss_u2: 0.0014 - val_err_u1: 0.0142 - val_err_u2: 0.0307
# Epoch 250/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0021 - loss_u1: 7.6591e-04 - loss_u2: 0.0013 - val_err_u1: 0.0142 - val_err_u2: 0.0306
# Epoch 251/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0021 - loss_u1: 7.6193e-04 - loss_u2: 0.0013 - val_err_u1: 0.0141 - val_err_u2: 0.0304
# Epoch 252/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0021 - loss_u1: 7.5756e-04 - loss_u2: 0.0013 - val_err_u1: 0.0141 - val_err_u2: 0.0303
# Epoch 253/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0021 - loss_u1: 7.5287e-04 - loss_u2: 0.0013 - val_err_u1: 0.0139 - val_err_u2: 0.0301
# Epoch 254/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0021 - loss_u1: 7.4795e-04 - loss_u2: 0.0013 - val_err_u1: 0.0138 - val_err_u2: 0.0299
# Epoch 255/500
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0020 - loss_u1: 7.4293e-04 - loss_u2: 0.0013 - val_err_u1: 0.0137 - val_err_u2: 0.0297
# Epoch 256/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0020 - loss_u1: 7.3795e-04 - loss_u2: 0.0013 - val_err_u1: 0.0136 - val_err_u2: 0.0296
# Epoch 257/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0020 - loss_u1: 7.3311e-04 - loss_u2: 0.0013 - val_err_u1: 0.0135 - val_err_u2: 0.0294
# Epoch 258/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0020 - loss_u1: 7.2852e-04 - loss_u2: 0.0013 - val_err_u1: 0.0135 - val_err_u2: 0.0294
# Epoch 259/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0020 - loss_u1: 7.2424e-04 - loss_u2: 0.0013 - val_err_u1: 0.0134 - val_err_u2: 0.0293
# Epoch 260/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0020 - loss_u1: 7.2031e-04 - loss_u2: 0.0013 - val_err_u1: 0.0135 - val_err_u2: 0.0293
# Epoch 261/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0020 - loss_u1: 7.1675e-04 - loss_u2: 0.0013 - val_err_u1: 0.0135 - val_err_u2: 0.0293
# Epoch 262/500
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0020 - loss_u1: 7.1354e-04 - loss_u2: 0.0013 - val_err_u1: 0.0136 - val_err_u2: 0.0294
# Epoch 263/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0020 - loss_u1: 7.1066e-04 - loss_u2: 0.0013 - val_err_u1: 0.0137 - val_err_u2: 0.0294
# Epoch 264/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0020 - loss_u1: 7.0809e-04 - loss_u2: 0.0013 - val_err_u1: 0.0138 - val_err_u2: 0.0295
# Epoch 265/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0020 - loss_u1: 7.0579e-04 - loss_u2: 0.0012 - val_err_u1: 0.0139 - val_err_u2: 0.0296
# Epoch 266/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0019 - loss_u1: 7.0370e-04 - loss_u2: 0.0012 - val_err_u1: 0.0141 - val_err_u2: 0.0297
# Epoch 267/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0019 - loss_u1: 7.0177e-04 - loss_u2: 0.0012 - val_err_u1: 0.0142 - val_err_u2: 0.0298
# Epoch 268/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0019 - loss_u1: 6.9995e-04 - loss_u2: 0.0012 - val_err_u1: 0.0144 - val_err_u2: 0.0299
# Epoch 269/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0019 - loss_u1: 6.9818e-04 - loss_u2: 0.0012 - val_err_u1: 0.0145 - val_err_u2: 0.0300
# Epoch 270/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0019 - loss_u1: 6.9640e-04 - loss_u2: 0.0012 - val_err_u1: 0.0147 - val_err_u2: 0.0301
# Epoch 271/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0019 - loss_u1: 6.9453e-04 - loss_u2: 0.0012 - val_err_u1: 0.0148 - val_err_u2: 0.0301
# Epoch 272/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0019 - loss_u1: 6.9252e-04 - loss_u2: 0.0012 - val_err_u1: 0.0149 - val_err_u2: 0.0302
# Epoch 273/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0019 - loss_u1: 6.9033e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0302
# Epoch 274/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0019 - loss_u1: 6.8791e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0301
# Epoch 275/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0019 - loss_u1: 6.8523e-04 - loss_u2: 0.0012 - val_err_u1: 0.0151 - val_err_u2: 0.0301
# Epoch 276/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0019 - loss_u1: 6.8231e-04 - loss_u2: 0.0012 - val_err_u1: 0.0151 - val_err_u2: 0.0300
# Epoch 277/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0019 - loss_u1: 6.7915e-04 - loss_u2: 0.0012 - val_err_u1: 0.0151 - val_err_u2: 0.0299
# Epoch 278/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0019 - loss_u1: 6.7578e-04 - loss_u2: 0.0012 - val_err_u1: 0.0151 - val_err_u2: 0.0298
# Epoch 279/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0019 - loss_u1: 6.7226e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0298
# Epoch 280/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0019 - loss_u1: 6.6864e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0297
# Epoch 281/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0018 - loss_u1: 6.6499e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0296
# Epoch 282/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0018 - loss_u1: 6.6137e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0295
# Epoch 283/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0018 - loss_u1: 6.5784e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0295
# Epoch 284/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0018 - loss_u1: 6.5444e-04 - loss_u2: 0.0012 - val_err_u1: 0.0150 - val_err_u2: 0.0294
# Epoch 285/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0018 - loss_u1: 6.5122e-04 - loss_u2: 0.0012 - val_err_u1: 0.0151 - val_err_u2: 0.0294
# Epoch 286/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0018 - loss_u1: 6.4821e-04 - loss_u2: 0.0011 - val_err_u1: 0.0151 - val_err_u2: 0.0294
# Epoch 287/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0018 - loss_u1: 6.4541e-04 - loss_u2: 0.0011 - val_err_u1: 0.0152 - val_err_u2: 0.0294
# Epoch 288/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0018 - loss_u1: 6.4283e-04 - loss_u2: 0.0011 - val_err_u1: 0.0152 - val_err_u2: 0.0294
# Epoch 289/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0018 - loss_u1: 6.4046e-04 - loss_u2: 0.0011 - val_err_u1: 0.0153 - val_err_u2: 0.0294
# Epoch 290/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0018 - loss_u1: 6.3828e-04 - loss_u2: 0.0011 - val_err_u1: 0.0154 - val_err_u2: 0.0294
# Epoch 291/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0018 - loss_u1: 6.3627e-04 - loss_u2: 0.0011 - val_err_u1: 0.0155 - val_err_u2: 0.0295
# Epoch 292/500
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0018 - loss_u1: 6.3438e-04 - loss_u2: 0.0011 - val_err_u1: 0.0156 - val_err_u2: 0.0295
# Epoch 293/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0018 - loss_u1: 6.3259e-04 - loss_u2: 0.0011 - val_err_u1: 0.0157 - val_err_u2: 0.0295
# Epoch 294/500
# ...
# Epoch 408/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0012 - loss_u1: 4.3771e-04 - loss_u2: 7.7016e-04 - val_err_u1: 0.0183 - val_err_u2: 0.0267
# Epoch 409/500
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0012 - loss_u1: 4.3591e-04 - loss_u2: 7.6750e-04 - val_err_u1: 0.0183 - val_err_u2: 0.0266
# Epoch 410/500
# 10/10 [==============================] - 0s 32ms/step - loss: 0.0012 - loss_u1: 4.3406e-04 - loss_u2: 7.6479e-04 - val_err_u1: 0.0183 - val_err_u2: 0.0266
# Epoch 411/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0012 - loss_u1: 4.3214e-04 - loss_u2: 7.6202e-04 - val_err_u1: 0.0182 - val_err_u2: 0.0265
# Epoch 412/500
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0012 - loss_u1: 4.3015e-04 - loss_u2: 7.5918e-04 - val_err_u1: 0.0182 - val_err_u2: 0.0264
# Epoch 413/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0012 - loss_u1: 4.2807e-04 - loss_u2: 7.5626e-04 - val_err_u1: 0.0182 - val_err_u2: 0.0263
# Epoch 414/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0012 - loss_u1: 4.2589e-04 - loss_u2: 7.5325e-04 - val_err_u1: 0.0182 - val_err_u2: 0.0262
# Epoch 415/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0012 - loss_u1: 4.2359e-04 - loss_u2: 7.5013e-04 - val_err_u1: 0.0181 - val_err_u2: 0.0261
# Epoch 416/500
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0012 - loss_u1: 4.2117e-04 - loss_u2: 7.4689e-04 - val_err_u1: 0.0181 - val_err_u2: 0.0260
# Epoch 417/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0012 - loss_u1: 4.1859e-04 - loss_u2: 7.4350e-04 - val_err_u1: 0.0180 - val_err_u2: 0.0258
# Epoch 418/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0012 - loss_u1: 4.1584e-04 - loss_u2: 7.3995e-04 - val_err_u1: 0.0179 - val_err_u2: 0.0257
# Epoch 419/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0011 - loss_u1: 4.1289e-04 - loss_u2: 7.3621e-04 - val_err_u1: 0.0178 - val_err_u2: 0.0255
# Epoch 420/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0011 - loss_u1: 4.0972e-04 - loss_u2: 7.3225e-04 - val_err_u1: 0.0177 - val_err_u2: 0.0253
# Epoch 421/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0011 - loss_u1: 4.0629e-04 - loss_u2: 7.2805e-04 - val_err_u1: 0.0176 - val_err_u2: 0.0251
# Epoch 422/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0011 - loss_u1: 4.0256e-04 - loss_u2: 7.2356e-04 - val_err_u1: 0.0175 - val_err_u2: 0.0249
# Epoch 423/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0011 - loss_u1: 3.9849e-04 - loss_u2: 7.1874e-04 - val_err_u1: 0.0173 - val_err_u2: 0.0247
# Epoch 424/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0011 - loss_u1: 3.9403e-04 - loss_u2: 7.1354e-04 - val_err_u1: 0.0171 - val_err_u2: 0.0244
# Epoch 425/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0011 - loss_u1: 3.8913e-04 - loss_u2: 7.0792e-04 - val_err_u1: 0.0168 - val_err_u2: 0.0241
# Epoch 426/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0011 - loss_u1: 3.8373e-04 - loss_u2: 7.0182e-04 - val_err_u1: 0.0166 - val_err_u2: 0.0237
# Epoch 427/500
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0011 - loss_u1: 3.7777e-04 - loss_u2: 6.9518e-04 - val_err_u1: 0.0162 - val_err_u2: 0.0233
# Epoch 428/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0011 - loss_u1: 3.7120e-04 - loss_u2: 6.8794e-04 - val_err_u1: 0.0158 - val_err_u2: 0.0229
# Epoch 429/500
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0010 - loss_u1: 3.6395e-04 - loss_u2: 6.8004e-04 - val_err_u1: 0.0153 - val_err_u2: 0.0224
# Epoch 430/500
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0010 - loss_u1: 3.5599e-04 - loss_u2: 6.7144e-04 - val_err_u1: 0.0147 - val_err_u2: 0.0218
# Epoch 431/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0010 - loss_u1: 3.4729e-04 - loss_u2: 6.6211e-04 - val_err_u1: 0.0141 - val_err_u2: 0.0212
# Epoch 432/500
# 10/10 [==============================] - 0s 28ms/step - loss: 9.8990e-04 - loss_u1: 3.3786e-04 - loss_u2: 6.5205e-04 - val_err_u1: 0.0133 - val_err_u2: 0.0206
# Epoch 433/500
# 10/10 [==============================] - 0s 30ms/step - loss: 9.6905e-04 - loss_u1: 3.2775e-04 - loss_u2: 6.4130e-04 - val_err_u1: 0.0124 - val_err_u2: 0.0199
# Epoch 434/500
# 10/10 [==============================] - 0s 31ms/step - loss: 9.4705e-04 - loss_u1: 3.1709e-04 - loss_u2: 6.2996e-04 - val_err_u1: 0.0114 - val_err_u2: 0.0192
# Epoch 435/500
# 10/10 [==============================] - 0s 29ms/step - loss: 9.2426e-04 - loss_u1: 3.0607e-04 - loss_u2: 6.1819e-04 - val_err_u1: 0.0103 - val_err_u2: 0.0185
# Epoch 436/500
# 10/10 [==============================] - 0s 28ms/step - loss: 9.0117e-04 - loss_u1: 2.9495e-04 - loss_u2: 6.0622e-04 - val_err_u1: 0.0092 - val_err_u2: 0.0178
# Epoch 437/500
# 10/10 [==============================] - 0s 32ms/step - loss: 8.7838e-04 - loss_u1: 2.8404e-04 - loss_u2: 5.9435e-04 - val_err_u1: 0.0080 - val_err_u2: 0.0172
# Epoch 438/500
# 10/10 [==============================] - 0s 31ms/step - loss: 8.5654e-04 - loss_u1: 2.7367e-04 - loss_u2: 5.8287e-04 - val_err_u1: 0.0068 - val_err_u2: 0.0167
# Epoch 439/500
# 10/10 [==============================] - 0s 32ms/step - loss: 8.3625e-04 - loss_u1: 2.6414e-04 - loss_u2: 5.7211e-04 - val_err_u1: 0.0058 - val_err_u2: 0.0163
# Epoch 440/500
# 10/10 [==============================] - 0s 27ms/step - loss: 8.1797e-04 - loss_u1: 2.5566e-04 - loss_u2: 5.6231e-04 - val_err_u1: 0.0049 - val_err_u2: 0.0160
# Epoch 441/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.0195e-04 - loss_u1: 2.4834e-04 - loss_u2: 5.5361e-04 - val_err_u1: 0.0044 - val_err_u2: 0.0158
# Epoch 442/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.8827e-04 - loss_u1: 2.4219e-04 - loss_u2: 5.4608e-04 - val_err_u1: 0.0041 - val_err_u2: 0.0156
# Epoch 443/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.7683e-04 - loss_u1: 2.3715e-04 - loss_u2: 5.3968e-04 - val_err_u1: 0.0041 - val_err_u2: 0.0155
# Epoch 444/500
# 10/10 [==============================] - 0s 34ms/step - loss: 7.6747e-04 - loss_u1: 2.3314e-04 - loss_u2: 5.3433e-04 - val_err_u1: 0.0042 - val_err_u2: 0.0155
# Epoch 445/500
# 10/10 [==============================] - 0s 27ms/step - loss: 7.5997e-04 - loss_u1: 2.3008e-04 - loss_u2: 5.2989e-04 - val_err_u1: 0.0044 - val_err_u2: 0.0154
# Epoch 446/500
# 10/10 [==============================] - 0s 27ms/step - loss: 7.5414e-04 - loss_u1: 2.2788e-04 - loss_u2: 5.2626e-04 - val_err_u1: 0.0047 - val_err_u2: 0.0154
# Epoch 447/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.4980e-04 - loss_u1: 2.2647e-04 - loss_u2: 5.2334e-04 - val_err_u1: 0.0051 - val_err_u2: 0.0153
# Epoch 448/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.4681e-04 - loss_u1: 2.2576e-04 - loss_u2: 5.2104e-04 - val_err_u1: 0.0054 - val_err_u2: 0.0152
# Epoch 449/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.4501e-04 - loss_u1: 2.2572e-04 - loss_u2: 5.1929e-04 - val_err_u1: 0.0058 - val_err_u2: 0.0151
# Epoch 450/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.4429e-04 - loss_u1: 2.2630e-04 - loss_u2: 5.1800e-04 - val_err_u1: 0.0062 - val_err_u2: 0.0150
# Epoch 451/500
# 10/10 [==============================] - 0s 32ms/step - loss: 7.4454e-04 - loss_u1: 2.2749e-04 - loss_u2: 5.1705e-04 - val_err_u1: 0.0067 - val_err_u2: 0.0149
# Epoch 452/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.4565e-04 - loss_u1: 2.2928e-04 - loss_u2: 5.1637e-04 - val_err_u1: 0.0073 - val_err_u2: 0.0147
# Epoch 453/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.4754e-04 - loss_u1: 2.3166e-04 - loss_u2: 5.1588e-04 - val_err_u1: 0.0078 - val_err_u2: 0.0145
# Epoch 454/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.5014e-04 - loss_u1: 2.3461e-04 - loss_u2: 5.1553e-04 - val_err_u1: 0.0085 - val_err_u2: 0.0143
# Epoch 455/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.5343e-04 - loss_u1: 2.3813e-04 - loss_u2: 5.1530e-04 - val_err_u1: 0.0092 - val_err_u2: 0.0140
# Epoch 456/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.5737e-04 - loss_u1: 2.4218e-04 - loss_u2: 5.1519e-04 - val_err_u1: 0.0099 - val_err_u2: 0.0137
# Epoch 457/500
# 10/10 [==============================] - 0s 27ms/step - loss: 7.6195e-04 - loss_u1: 2.4670e-04 - loss_u2: 5.1525e-04 - val_err_u1: 0.0106 - val_err_u2: 0.0135
# Epoch 458/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.6717e-04 - loss_u1: 2.5163e-04 - loss_u2: 5.1554e-04 - val_err_u1: 0.0113 - val_err_u2: 0.0132
# Epoch 459/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7301e-04 - loss_u1: 2.5685e-04 - loss_u2: 5.1616e-04 - val_err_u1: 0.0120 - val_err_u2: 0.0129
# Epoch 460/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7945e-04 - loss_u1: 2.6225e-04 - loss_u2: 5.1720e-04 - val_err_u1: 0.0126 - val_err_u2: 0.0127
# Epoch 461/500
# 10/10 [==============================] - 0s 35ms/step - loss: 7.8646e-04 - loss_u1: 2.6769e-04 - loss_u2: 5.1877e-04 - val_err_u1: 0.0131 - val_err_u2: 0.0125
# Epoch 462/500
# 10/10 [==============================] - 0s 27ms/step - loss: 7.9396e-04 - loss_u1: 2.7302e-04 - loss_u2: 5.2094e-04 - val_err_u1: 0.0134 - val_err_u2: 0.0124
# Epoch 463/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.0188e-04 - loss_u1: 2.7808e-04 - loss_u2: 5.2379e-04 - val_err_u1: 0.0137 - val_err_u2: 0.0123
# Epoch 464/500
# 10/10 [==============================] - 0s 28ms/step - loss: 8.1009e-04 - loss_u1: 2.8276e-04 - loss_u2: 5.2733e-04 - val_err_u1: 0.0137 - val_err_u2: 0.0124
# Epoch 465/500
# 10/10 [==============================] - 0s 37ms/step - loss: 8.1844e-04 - loss_u1: 2.8690e-04 - loss_u2: 5.3154e-04 - val_err_u1: 0.0137 - val_err_u2: 0.0125
# Epoch 466/500
# 10/10 [==============================] - 0s 37ms/step - loss: 8.2672e-04 - loss_u1: 2.9039e-04 - loss_u2: 5.3632e-04 - val_err_u1: 0.0134 - val_err_u2: 0.0127
# Epoch 467/500
# 10/10 [==============================] - 0s 36ms/step - loss: 8.3464e-04 - loss_u1: 2.9313e-04 - loss_u2: 5.4151e-04 - val_err_u1: 0.0130 - val_err_u2: 0.0130
# Epoch 468/500
# 10/10 [==============================] - 0s 49ms/step - loss: 8.4188e-04 - loss_u1: 2.9499e-04 - loss_u2: 5.4689e-04 - val_err_u1: 0.0125 - val_err_u2: 0.0134
# Epoch 469/500
# 10/10 [==============================] - 0s 39ms/step - loss: 8.4806e-04 - loss_u1: 2.9590e-04 - loss_u2: 5.5216e-04 - val_err_u1: 0.0119 - val_err_u2: 0.0139
# Epoch 470/500
# 10/10 [==============================] - 0s 32ms/step - loss: 8.5275e-04 - loss_u1: 2.9576e-04 - loss_u2: 5.5699e-04 - val_err_u1: 0.0111 - val_err_u2: 0.0145
# Epoch 471/500
# 10/10 [==============================] - 0s 31ms/step - loss: 8.5556e-04 - loss_u1: 2.9455e-04 - loss_u2: 5.6101e-04 - val_err_u1: 0.0103 - val_err_u2: 0.0151
# Epoch 472/500
# 10/10 [==============================] - 0s 28ms/step - loss: 8.5619e-04 - loss_u1: 2.9229e-04 - loss_u2: 5.6391e-04 - val_err_u1: 0.0094 - val_err_u2: 0.0156
# Epoch 473/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.5446e-04 - loss_u1: 2.8905e-04 - loss_u2: 5.6541e-04 - val_err_u1: 0.0085 - val_err_u2: 0.0162
# Epoch 474/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.5038e-04 - loss_u1: 2.8499e-04 - loss_u2: 5.6539e-04 - val_err_u1: 0.0077 - val_err_u2: 0.0167
# Epoch 475/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.4418e-04 - loss_u1: 2.8033e-04 - loss_u2: 5.6385e-04 - val_err_u1: 0.0070 - val_err_u2: 0.0171
# Epoch 476/500
# 10/10 [==============================] - 0s 29ms/step - loss: 8.3627e-04 - loss_u1: 2.7534e-04 - loss_u2: 5.6093e-04 - val_err_u1: 0.0064 - val_err_u2: 0.0174
# Epoch 477/500
# 10/10 [==============================] - 0s 28ms/step - loss: 8.2720e-04 - loss_u1: 2.7028e-04 - loss_u2: 5.5692e-04 - val_err_u1: 0.0059 - val_err_u2: 0.0176
# Epoch 478/500
# 10/10 [==============================] - 0s 26ms/step - loss: 8.1756e-04 - loss_u1: 2.6540e-04 - loss_u2: 5.5217e-04 - val_err_u1: 0.0056 - val_err_u2: 0.0177
# Epoch 479/500
# 10/10 [==============================] - 0s 30ms/step - loss: 8.0792e-04 - loss_u1: 2.6089e-04 - loss_u2: 5.4704e-04 - val_err_u1: 0.0054 - val_err_u2: 0.0177
# Epoch 480/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.9874e-04 - loss_u1: 2.5689e-04 - loss_u2: 5.4185e-04 - val_err_u1: 0.0053 - val_err_u2: 0.0176
# Epoch 481/500
# 10/10 [==============================] - 0s 35ms/step - loss: 7.9035e-04 - loss_u1: 2.5348e-04 - loss_u2: 5.3686e-04 - val_err_u1: 0.0052 - val_err_u2: 0.0175
# Epoch 482/500
# 10/10 [==============================] - 0s 27ms/step - loss: 7.8291e-04 - loss_u1: 2.5069e-04 - loss_u2: 5.3222e-04 - val_err_u1: 0.0052 - val_err_u2: 0.0173
# Epoch 483/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7647e-04 - loss_u1: 2.4847e-04 - loss_u2: 5.2799e-04 - val_err_u1: 0.0052 - val_err_u2: 0.0171
# Epoch 484/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7094e-04 - loss_u1: 2.4678e-04 - loss_u2: 5.2416e-04 - val_err_u1: 0.0052 - val_err_u2: 0.0169
# Epoch 485/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.6617e-04 - loss_u1: 2.4552e-04 - loss_u2: 5.2064e-04 - val_err_u1: 0.0053 - val_err_u2: 0.0166
# Epoch 486/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.6194e-04 - loss_u1: 2.4460e-04 - loss_u2: 5.1733e-04 - val_err_u1: 0.0054 - val_err_u2: 0.0164
# Epoch 487/500
# 10/10 [==============================] - 0s 32ms/step - loss: 7.5802e-04 - loss_u1: 2.4393e-04 - loss_u2: 5.1409e-04 - val_err_u1: 0.0056 - val_err_u2: 0.0161
# Epoch 488/500
# 10/10 [==============================] - 0s 26ms/step - loss: 7.5418e-04 - loss_u1: 2.4343e-04 - loss_u2: 5.1075e-04 - val_err_u1: 0.0059 - val_err_u2: 0.0158
# Epoch 489/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.5023e-04 - loss_u1: 2.4305e-04 - loss_u2: 5.0718e-04 - val_err_u1: 0.0063 - val_err_u2: 0.0154
# Epoch 490/500
# 10/10 [==============================] - 0s 30ms/step - loss: 7.4604e-04 - loss_u1: 2.4283e-04 - loss_u2: 5.0320e-04 - val_err_u1: 0.0069 - val_err_u2: 0.0150
# Epoch 491/500
# 10/10 [==============================] - 0s 33ms/step - loss: 7.4162e-04 - loss_u1: 2.4293e-04 - loss_u2: 4.9869e-04 - val_err_u1: 0.0077 - val_err_u2: 0.0146
# Epoch 492/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.3721e-04 - loss_u1: 2.4370e-04 - loss_u2: 4.9351e-04 - val_err_u1: 0.0088 - val_err_u2: 0.0142
# Epoch 493/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.3342e-04 - loss_u1: 2.4581e-04 - loss_u2: 4.8761e-04 - val_err_u1: 0.0102 - val_err_u2: 0.0137
# Epoch 494/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.3139e-04 - loss_u1: 2.5034e-04 - loss_u2: 4.8105e-04 - val_err_u1: 0.0121 - val_err_u2: 0.0131
# Epoch 495/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.3270e-04 - loss_u1: 2.5863e-04 - loss_u2: 4.7407e-04 - val_err_u1: 0.0142 - val_err_u2: 0.0125
# Epoch 496/500
# 10/10 [==============================] - 0s 31ms/step - loss: 7.3855e-04 - loss_u1: 2.7152e-04 - loss_u2: 4.6703e-04 - val_err_u1: 0.0166 - val_err_u2: 0.0119
# Epoch 497/500
# 10/10 [==============================] - 0s 28ms/step - loss: 7.4765e-04 - loss_u1: 2.8746e-04 - loss_u2: 4.6020e-04 - val_err_u1: 0.0189 - val_err_u2: 0.0113
# Epoch 498/500
# 10/10 [==============================] - 0s 29ms/step - loss: 7.5436e-04 - loss_u1: 3.0080e-04 - loss_u2: 4.5356e-04 - val_err_u1: 0.0205 - val_err_u2: 0.0107
# Epoch 499/500
# 10/10 [==============================] - 0s 51ms/step - loss: 7.5207e-04 - loss_u1: 3.0454e-04 - loss_u2: 4.4753e-04 - val_err_u1: 0.0211 - val_err_u2: 0.0101
# Epoch 500/500
# 10/10 [==============================] - 0s 44ms/step - loss: 7.4293e-04 - loss_u1: 2.9850e-04 - loss_u2: 4.4442e-04 - val_err_u1: 0.0206 - val_err_u2: 0.0096

# %%
saw_couple_model.save_weights("./ModelData/cBurgers_eg1/weights")

# %%
saw_couple_model.load_weights("./ModelData/cBurgers_eg1/weights")

# %%
func = function_factory(saw_couple_model,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train )

# %%
params_1d = tf.dynamic_stitch(func.idx, saw_couple_model.trainable_variables[:])
## L-BFGS 优化阶段
max_iterations = 1000
results = tfp.optimizer.lbfgs_minimize(
    value_and_gradients_function=func,
    initial_position=params_1d, 
    num_correction_pairs=20, 
    x_tolerance = 0,
    f_relative_tolerance = 0,
    tolerance = 1*np.finfo(float).eps,
    parallel_iterations = 1,
    max_line_search_iterations = 100,
    max_iterations=max_iterations)
# Out:
# num_objective_evaluations: 350 loss: 0.00055066370773464136
# num_objective_evaluations: 400 loss: 0.00044588933666720376
# num_objective_evaluations: 450 loss: 0.00038591185411724168
# num_objective_evaluations: 500 loss: 0.00034415915982282112
# num_objective_evaluations: 550 loss: 0.00030696890659800155
# num_objective_evaluations: 600 loss: 0.00028728267001999433
# num_objective_evaluations: 650 loss: 0.0002620451708781875
# num_objective_evaluations: 700 loss: 0.00024667583906456562
# num_objective_evaluations: 750 loss: 0.0002355538456309333
# num_objective_evaluations: 800 loss: 0.00024424113764507651
# num_objective_evaluations: 850 loss: 0.00021394096244633647
# num_objective_evaluations: 900 loss: 0.00020173590413993339
# num_objective_evaluations: 950 loss: 0.00018664136373444039
# num_objective_evaluations: 1000 loss: 0.00017601330462530944
# num_objective_evaluations: 1050 loss: 0.00016664864121998811
# num_objective_evaluations: 1100 loss: 0.00015864955550387488
# num_objective_evaluations: 1150 loss: 0.00015101809648543661
# num_objective_evaluations: 1200 loss: 0.00013874240194394481
# num_objective_evaluations: 1250 loss: 0.00012989785973329068
# num_objective_evaluations: 1300 loss: 0.00012144954554189785
# num_objective_evaluations: 1350 loss: 0.00011593457110349408
# num_objective_evaluations: 1400 loss: 0.00011051759366746303
# num_objective_evaluations: 1450 loss: 0.00010401426509331366
# num_objective_evaluations: 1500 loss: 9.659758890043796e-05
# num_objective_evaluations: 1550 loss: 9.0599411200344721e-05
# num_objective_evaluations: 1600 loss: 8.695175842997048e-05
# num_objective_evaluations: 1650 loss: 8.1251776222521425e-05
# num_objective_evaluations: 1700 loss: 7.5325486159341721e-05
# num_objective_evaluations: 1750 loss: 7.0962949159046352e-05
# num_objective_evaluations: 1800 loss: 6.8564589534764379e-05
# num_objective_evaluations: 1850 loss: 6.485124346369222e-05
# num_objective_evaluations: 1900 loss: 6.2479898841532775e-05
# num_objective_evaluations: 1950 loss: 6.1209375738673034e-05
# num_objective_evaluations: 2000 loss: 5.9150614680739361e-05
# num_objective_evaluations: 2050 loss: 5.65809682134715e-05
# num_objective_evaluations: 2100 loss: 5.39327459362149e-05
# num_objective_evaluations: 2150 loss: 5.0638057218310966e-05
# num_objective_evaluations: 2200 loss: 4.7891788786538174e-05
# num_objective_evaluations: 2250 loss: 4.6793756036161855e-05
# num_objective_evaluations: 2300 loss: 4.4426716439895709e-05
# num_objective_evaluations: 2350 loss: 4.2666320874797051e-05
# num_objective_evaluations: 2400 loss: 4.0910173196561191e-05
# num_objective_evaluations: 2450 loss: 3.9080542729108263e-05
# num_objective_evaluations: 2500 loss: 3.7764975544380533e-05
# num_objective_evaluations: 2550 loss: 3.6178487114909334e-05
# num_objective_evaluations: 2600 loss: 3.4194337589421144e-05
# num_objective_evaluations: 2650 loss: 3.1975056540370975e-05
# num_objective_evaluations: 2700 loss: 3.0642575366278807e-05
# num_objective_evaluations: 2750 loss: 2.9225115775327526e-05
# num_objective_evaluations: 2800 loss: 2.7790408972613e-05
# num_objective_evaluations: 2850 loss: 2.6325343838608393e-05
# num_objective_evaluations: 2900 loss: 2.4456228593038203e-05
# num_objective_evaluations: 2950 loss: 2.2975097828593153e-05
# num_objective_evaluations: 3000 loss: 2.197246086754893e-05
# num_objective_evaluations: 3050 loss: 2.1023491315692969e-05
# num_objective_evaluations: 3100 loss: 2.0670152565743534e-05
# num_objective_evaluations: 3150 loss: 1.972392303651808e-05
# num_objective_evaluations: 3200 loss: 1.9466913295921034e-05

# %%
err_u1,err_u2=saw_couple_model.evaluate(ds_test)
# Out:
# 1/1 [==============================] - 0s 89ms/step - err_u1: 6.2722e-04 - err_u2: 5.2188e-04

# %% [markdown]
# # Plotting

# %%
""" Plot Data """
N = 100
X_u1,T_u1,U1 = plot_real_data(N,omga1,u1)
X_u2,T_u2,U2 = plot_real_data(N,omga2,u2)

U1_pred = plot_pred_data(X_u1,T_u1,model_u1)
U2_pred = plot_pred_data(X_u2,T_u2,model_u2)

# %%
f = plt.figure(figsize=(12,10))
ax = f.add_subplot(211)
l1, = ax.plot(X_u1[-1,:],U1[-1,:],'b')
l2, = ax.plot(X_u1[-1,:],U1_pred[-1,:],'r--')
ax.set_xlabel('$x$',size=20)
ax.set_ylabel('$u1$',size=20)

ax.legend(handles=[l1,l2],labels=["$Exact \ u_1$","$Pred \ u_1$"])
ax.text(-3,0.25,'$This \ is \ u_1(x,1). \ err\_rate={:.4f}$'.format(err_u1),fontdict={'size':20,'color':'g'})

ax = f.add_subplot(212)
l1, = ax.plot(X_u2[-1,:],U2[-1,:],'b')
l2, = ax.plot(X_u2[-1,:],U2_pred[-1,:],'r--')
ax.set_xlabel('$x$',size=20)
ax.set_ylabel('$u2$',size=20)

ax.legend(handles=[l1,l2],labels=["$Exact \ u_2$","$Pred \ u_2$"])
ax.text(-3,0.25,'$This \ is \ u_2(x,1). \ err\_rate={:.4f}$'.format(err_u2),fontdict={'size':20,'color':'g'})
# Out:
# Text(-3, 0.25, '$This \\ is \\ u_2(x,1). \\ err\\_rate=0.0005$')

# %%
####################################################
fig1=plt.figure(figsize=(12, 4)) 
fig1.suptitle("Real U")
ax11 = fig1.add_subplot(121,projection='3d')
ax11.plot_surface(X_u1,T_u1,U1,alpha=0.8,cmap='summer')


ax12 = fig1.add_subplot(122,projection='3d')
ax12.plot_surface(X_u2,T_u2,U2,alpha=0.9,cmap='winter')

ax11.set_xlabel("X")   
ax11.set_ylabel("T")
ax11.set_zlabel("U1",color='r')


ax12.set_xlabel("X")   
ax12.set_ylabel("T")
ax12.set_zlabel("U2",color='r')

plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
fig1.savefig("2d_cBurgers_eg1_surface_real.png")
###################################################### 
fig2 = plt.figure(figsize=(12, 4)) 
fig2.suptitle("Predict U")
ax21 = fig2.add_subplot(121,projection="3d")
ax22 = fig2.add_subplot(122,projection="3d")

### u1
ax21.plot_surface(X_u1,T_u1,U1_pred,alpha=0.9,cmap='summer')
ax21.set_xlabel("X")   
ax21.set_ylabel("T")
ax21.set_zlabel("U1",color='r')


### u2
ax22.plot_surface(X_u2,T_u2,U2_pred,alpha=0.9,cmap='winter')

ax22.set_xlabel("X")   
ax22.set_ylabel("T")
ax22.set_zlabel("U2",color='r',rotation='horizontal')

plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
fig2.savefig("2d_cBurgers_eg1_surface_pred.png")
###############################

plt.show()

# %% [markdown]
# # Save Model

# %%
saw_couple_model.save_weights("./ModelData/cBurgers_eg1/weights")
