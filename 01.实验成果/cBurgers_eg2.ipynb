# %% [markdown]
# # Import

# %%
pip install pyDOE

# %%
from sympy import*
import numpy as np
from pyDOE import lhs         #Latin Hypercube Sampling
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D   
import tensorflow as tf
from tensorflow import keras
import tensorflow_probability as tfp #TFP needs TF>= 2.3
import time

tf.random.set_seed(1234)
np.random.seed(1234)

# %% [markdown]
# # Setting

# %%
x = symbols('x')
t = symbols('t')

a = 0.1
b = 0.3
eta = 2.0

a0 = 0.05
A = 0.5*a0*(4*a*b-1)/(2*a-1)
u1 = a0*(1 - tanh(A*(x-2*A*t)))
u2 = a0*( (2*b-1)/(2*a-1) - tanh(A*(x-2*A*t)) )


u1 = lambdify((x,t),u1)
u2 = lambdify((x,t),u2)

# %% [markdown]
# # TrainingData & TestData

# %%
def trainingdata(N_u,N_f,omga,u):    

    x_range = omga[0]
    t_range = omga[1]

    all_X_u_train = []
    all_u_train = []

    # Initial Condition t=0, 
    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[1],t_range[0]])
    initial_X = lb + (ub-lb)*lhs(2,N_u)
    initial_u = u(initial_X[:,0], initial_X[:,1]).reshape(-1,1)
    
    all_X_u_train.append(initial_X)
    all_u_train.append(initial_u)

    # BC Condition

    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[0],t_range[1]])
    BC_X1 = lb + (ub-lb)*lhs(2,N_u)
    BC_u1 = u(BC_X1[:,0],BC_X1[:,1]).reshape(-1,1) 
    all_X_u_train.append(BC_X1)
    all_u_train.append(BC_u1) 
    
    lb = np.array([x_range[1],t_range[0]])
    ub = np.array([x_range[1],t_range[1]])
    BC_X2 = lb + (ub-lb)*lhs(2,N_u)
    BC_u2 = u(BC_X2[:,0],BC_X2[:,1]).reshape(-1,1) 
    all_X_u_train.append(BC_X2)
    all_u_train.append(BC_u2) 

    all_X_u_train =  np.vstack(all_X_u_train)
    all_u_train = np.vstack(all_u_train)
    
    idx = np.random.choice(all_X_u_train.shape[0],all_X_u_train.shape[0], replace=False) 
    
    X_u_train = all_X_u_train[idx,:]
    u_train = all_u_train[idx,:]
            
    '''Collocation Points'''
    # Latin Hypercube sampling for collocation points 
    # N_f sets of tuples(x,t)
    lb = np.array([x_range[0],t_range[0]])
    ub = np.array([x_range[1],t_range[1]])
    X_f_train = lb + (ub-lb)*lhs(2,N_f) 
    X_f_train = np.vstack((X_f_train, X_u_train)) # append training points to collocation points 
    
    return X_u_train,u_train,X_f_train

def ds_train_n_batch(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train,n = 5):
    batch_u1 = int(len(X_u1_train)/n) # = int(len(u1_train)/n)


    batch_u2 = int(len(X_u2_train)/n) # = int(len(u2_train)/n)

    
    batch_f = int(len(X_f_train)/n)
    
    ds_u1 = tf.data.Dataset.from_tensor_slices( ((X_u1_train,u1_train)) ).batch( batch_u1 )
    
    ds_u2 = tf.data.Dataset.from_tensor_slices( ((X_u2_train,u2_train)) ).batch( batch_u2 )
    
    ds_f = tf.data.Dataset.from_tensor_slices(X_f_train).batch(batch_f)

    ds_train = tf.data.Dataset.zip((ds_u1,ds_u2,ds_f))
    return ds_train

def ds_test_n_batch(x1_test,u1_test,x2_test,u2_test,n=5):
  batch_u1 = int(len(u1_test)/n)
  batch_u2 = int(len(u2_test)/n)

  ds_u1 = tf.data.Dataset.from_tensor_slices( (x1_test,u1_test) ).batch(batch_u1)
  ds_u2 = tf.data.Dataset.from_tensor_slices( (x2_test,u2_test) ).batch(batch_u2)

  ds_test = tf.data.Dataset.zip((ds_u1,ds_u2))
  return ds_test

def test_data(N,omga,u):
  x_range = omga[0]
  t_range = omga[1]

  lb = np.array([x_range[0],t_range[0]])
  ub = np.array([x_range[1],t_range[1]])
  x_test = lb + (ub-lb)*lhs(2,N)
  u_test = u(x_test[:,0],x_test[:,1]).reshape((-1,1)) 

  return x_test,u_test

# %% [markdown]
# # Plot

# %%
def plot_real_data(N,omga,u):
  # Output: X,T shape=(N,N)
  x_range = tf.linspace(omga[0][0],omga[0][1],N)
  t_range = tf.linspace(omga[1][0],omga[1][1],N)

  X,T = tf.meshgrid(x_range,t_range)

  U = u(X,T)
  return X,T,U

def plot_pred_data(X,T,model):
  #Input: X,T shape=(N,N)
  #Output: U_pred shape=(N,N)
  Shape = X.shape
  dim = len(Shape)
  X = tf.reshape(X,shape=(Shape[0]**dim,1))
  T = tf.reshape(T,shape=(Shape[0]**dim,1))

  Inputs = tf.concat([X,T],axis=1)
  U_pred = model(Inputs)
  U_pred = tf.reshape(U_pred,shape=Shape)
  return U_pred

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pyparsing import col
#plt.rcParams['font.sans-serif'] = ['SimHei']  # 步骤一（替换sans-serif字体）
plt.rcParams['axes.unicode_minus'] = False   # 步骤二（解决坐标轴负数的负号显示问题）
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import math

# %%
def plot_Adam_history(history_saw_cp,start_epoch=0.05):

  fig = plt.figure(figsize=(10,6))
  ax1 = fig.add_subplot(211)
  epoches = len(history_saw_cp.history['loss'])
  start = int(epoches*start_epoch)
  x = np.arange(start,epoches,1)

  line1, = ax1.plot(x,history_saw_cp.history['loss'][start:],'g:')
  line2, = ax1.plot(x,history_saw_cp.history['loss_u1'][start:],'r:')
  line3, = ax1.plot(x,history_saw_cp.history['loss_u2'][start:],'b:')
  ax1.legend(handles=[line1,line2,line3],labels=['loss','loss_u1','loss_u2'])
  ax1.set_ylabel('loss')
  ax1.set_xlabel('epoches')
  ax1.autoscale()

  ax2 = fig.add_subplot(212)
  line4, = ax2.plot(x,history_saw_cp.history['val_err_u1'][start:],'r:')
  line5, = ax2.plot(x,history_saw_cp.history['val_err_u2'][start:],'b:')
  ax2.legend(handles=[line4,line5],labels=["err_u1","err_u2",])
  ax2.set_ylabel("error_rate")
  ax2.set_xlabel("epochs")
  ax2.autoscale()
  fig.suptitle("Adam")

  plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
  plt.show()

  fig.savefig("2d_cBurgers_eg2_Adam_history.png")
  return fig

# %%
def plot_Lbfgs_history(histroy,max_iterations):

  fig_lbfgs,ax = plt.subplots()
  ax.plot(histroy,'b:')
  ax.set_xlabel("num_objective_evaluations")
  ax.set_ylabel("loss")
  ax.set_title("L-BFGS Max_Iterations={}".format(max_iterations))
  
  plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
  plt.show()

  fig_lbfgs.savefig("2d_cBurgers_eg2_lbfgs_history.png")
  return fig_lbfgs

# %% [markdown]
# # PINN Model

# %% [markdown]
# ## Single PINN

# %%
class SinglePinn(keras.Sequential): 
    def __init__(self,Layers,name = None): 
        super(SinglePinn, self).__init__(name=name)
        self.add(keras.Input(shape=(Layers[0],) ,dtype=tf.float64))
        for i in range(1,len(Layers)-1):
            self.add(keras.layers.Dense(Layers[i], dtype=tf.float64,
                kernel_regularizer=keras.regularizers.l2(0.01), 
                activity_regularizer=keras.regularizers.l1(0.01), 
                activation='tanh'))
        self.add(keras.layers.Dense(Layers[-1],dtype=tf.float64, name="outputs"))

    @tf.function
    def loss_U(self,X_u_train,u_train):
        u= self(X_u_train,training=True)
        loss_u = tf.reduce_mean(tf.square(u_train - u))
        return loss_u

# %% [markdown]
# ## Coupled PINN

# %%
class CoupledPinnLoss(keras.losses.Loss):
  def __init__(self,model,name="pinn_loss"):
      super().__init__(name=name)
      self.model = model
  def __call__(self,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train):
  
    loss_u1_BC = self.model.m1.loss_U(X_u1_train,u1_train)
    loss_u2_BC = self.model.m2.loss_U(X_u2_train,u2_train) 
    loss_u1_PDE,loss_u2_PDE = self.model.loss_PDE(X_f_train)

    loss_u1_total = loss_u1_BC + loss_u1_PDE 
    loss_u2_total = loss_u2_BC + loss_u2_PDE 

    loss = loss_u1_total + loss_u2_total
    return loss, loss_u1_total, loss_u2_total

# %%
class CoupledPinn(keras.Model):
  def __init__(self,model_u1,model_u2,a,b,eta,name=None):
    super().__init__(name=name)
    self.m1 = model_u1 
    self.m2 = model_u2
    self.a = tf.constant(a,dtype=tf.float64)
    self.b = tf.constant(b,dtype=tf.float64)
    self.eta = tf.constant(eta,dtype=tf.float64)

    # Metrics
    self.loss_tracker = keras.metrics.Mean(name="loss")
    self.loss_u1 = keras.metrics.Mean(name="loss_u1")
    self.loss_u2 = keras.metrics.Mean(name="loss_u2")

    self.u1_error = keras.metrics.Mean(name="err_u1")
    self.u2_error = keras.metrics.Mean(name="err_u2")
    
  @property
  def metrics(self):
      # We list our `Metric` objects here so that `reset_states()` can be
      # called automatically at the start of each epoch
      # or at the start of `evaluate()`.
      # If you don't implement this property, you have to call
      # `reset_states()` yourself at the time of your choosing.
      m = [self.loss_tracker,
           self.loss_u1,
           self.loss_u2,
           self.u1_error,
           self.u2_error]
      return m 

  @tf.function
  def loss_PDE(self,X_f_train):
      x = X_f_train[:,0:1]
      t = X_f_train[:,1:2]
    
      with tf.GradientTape(persistent=True) as tape:
          tape.watch([x,t])
          X = tf.stack([x[:,0],t[:,0]],axis=1)

          U1 = self.m1(X,training=True)
          U2 = self.m2(X,training=True)

          U1_x = tape.gradient(U1,x)
          U2_x = tape.gradient(U2,x)
      
      U1_xx = tape.gradient(U1_x, x)
      U2_xx = tape.gradient(U2_x, x)

      U1_t = tape.gradient(U1,t)
      U2_t = tape.gradient(U2,t)

      del tape

      loss_u1_PDE = U1_t - U1_xx + self.eta * U1 * U1_x + self.a * U1_x * U2 + U1 * U2_x
      loss_u2_PDE = U2_t - U2_xx + self.eta * U2 * U2_x + self.b * U1_x * U2 + U1 * U2_x

      loss_u1_PDE = tf.reduce_mean(tf.square(loss_u1_PDE)) 
      loss_u2_PDE = tf.reduce_mean(tf.square(loss_u2_PDE))

      return loss_u1_PDE,loss_u2_PDE
      

  """耦合区域 PINN训练方法"""
  @tf.function
  def train_step(self,data):
      (X_u1_train,u1_train),(X_u2_train,u2_train),X_f_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss,loss_u1_total,loss_u2_total = self.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)
      
      # Compute gradients
      #gradients = tape.gradient(loss,self.trainable_variables)

      gradients_u1 = tape.gradient(loss,self.m1.trainable_variables)
      gradients_u2 = tape.gradient(loss,self.m2.trainable_variables)

      del tape

      # Updata parameters
      #self.optimizer.apply_gradients(zip(gradients,self.trainable_variables))

      self.m1.optimizer.apply_gradients(zip(gradients_u1,self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_u2,self.m2.trainable_variables))

      # Updata loss Metric
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_u1_total)
      self.loss_u2.update_state(loss_u2_total)


      metrics = {m.name : m.result() for m in self.metrics[:,-2]}

      return metrics

  @tf.function
  def test_step(self,data):
    (x1_test,u1_test),(x2_test,u2_test) = data
    # Updata test Metric
    u1_pred = self.m1(x1_test)
    u2_pred = self.m2(x2_test)
    err_u1 = tf.linalg.norm(u1_test-u1_pred) / tf.linalg.norm(u1_test)
    err_u2 = tf.linalg.norm(u2_test-u2_pred) / tf.linalg.norm(u2_test)  

    self.u1_error.update_state(err_u1) 
    self.u2_error.update_state(err_u2)
    
    return {self.u1_error.name:self.u1_error.result(),
            self.u2_error.name:self.u2_error.result()}

# %% [markdown]
# ## Self-Adaptive-Weight Couple PINN

# %%
class SawCoupledPinnLoss(keras.losses.Loss):
  def __init__(self,model,name="saw_couple_pinn_loss"):
      super().__init__(name=name)
      self.model = model
  
  @tf.function
  def __call__(self,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train):
  
    loss_u1_BC = self.model.m1.loss_U(X_u1_train,u1_train)
    loss_u2_BC = self.model.m2.loss_U(X_u2_train,u2_train) 
    loss_u1_PDE,loss_u2_PDE = self.model.loss_PDE(X_f_train)

    loss_adaptive = (10*loss_u1_BC+loss_u1_PDE) + (10*loss_u2_BC+loss_u2_PDE)
    #loss_adaptive = (5*loss_u1_BC+loss_u1_PDE) + self.model.alpha*(5*loss_u2_BC+loss_u2_PDE)

    # update alpha
    self.model.alpha.assign( (loss_u1_BC+loss_u1_PDE) /(loss_u2_BC+loss_u2_PDE+self.model.eps))

    return loss_adaptive, loss_u1_BC,loss_u2_BC, loss_u1_PDE,loss_u2_PDE

# %%
class SawCouplePinn(CoupledPinn):
  def __init__(self,model_u1,model_u2,a,b,eta,name=None):
    super().__init__(model_u1,model_u2,a,b,eta,name=name)
    # Self-Adaptive-Weights    
    self.eps = tf.constant(1e-10,dtype=tf.float64)
    self.alpha = tf.Variable(1.0,dtype = tf.float64, trainable = False, name='alpha')

  
  """Self-Adaptive-Weights 耦合PINN训练方法"""
  @tf.function
  def train_step(self,data):
  
      (X_u1_train,u1_train),(X_u2_train,u2_train),X_f_train = data #unpack
      with tf.GradientTape(persistent=True) as tape: 
          loss_adaptive,loss_u1_BC,loss_u2_BC,loss_u1_PDE,loss_u2_PDE = self.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)

      loss_u1 = loss_u1_BC + loss_u1_PDE
      loss_u2 = loss_u2_BC + loss_u2_PDE
      loss = loss_u1 + loss_u2


      # Compute gradients
      #gradients = tape.gradient(loss_adaptive,self.trainable_variables)

      gradients_u1 = tape.gradient(loss_adaptive,self.m1.trainable_variables)
      gradients_u2 = tape.gradient(loss_adaptive,self.m2.trainable_variables)

      del tape

      # Update parameters
      #self.optimizer.apply_gradients(zip(gradients,self.trainable_variables))

      self.m1.optimizer.apply_gradients(zip(gradients_u1,self.m1.trainable_variables))
      self.m2.optimizer.apply_gradients(zip(gradients_u2,self.m2.trainable_variables))

      # Updata loss Metric
      self.loss_tracker.update_state(loss)
      self.loss_u1.update_state(loss_u1)
      self.loss_u2.update_state(loss_u2)


      metrics = {m.name : m.result() for m in self.metrics[:-2]}

      return metrics

# %% [markdown]
# ## function factory

# %%
def function_factory(model,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train,untrainable_nums=0):
    """A factory to create a function required by tfp.optimizer.lbfgs_minimize.
    Args:
        model [in]: an instance of `tf.keras.Model` or its subclasses.
        loss [in]: a loss function in model
    Returns:
        A function that has a signature of:
            loss_value, gradients = f(model_parameters).
    """

    # obtain the shapes of all trainable parameters in the model
    if untrainable_nums == 0:
      shapes = tf.shape_n(model.trainable_variables[:])
    else:
      shapes = tf.shape_n(model.trainable_variables[:-untrainable_nums])
    n_tensors = len(shapes)
    trainable_nums = n_tensors

    # we'll use tf.dynamic_stitch and tf.dynamic_partition later, so we need to
    # prepare required information first
    count = 0
    idx = [] # stitch indices
    part = [] # partition indices

    for i, shape in enumerate(shapes):
          n = np.product(shape)
          idx.append(tf.reshape(tf.range(count, count+n, dtype=tf.int32), shape))
          part.extend([i]*n)
          count += n

    part = tf.constant(part)

    @tf.function
    def assign_new_model_parameters(params_1d):
        """A function updating the model's parameters with a 1D tf.Tensor.
        Args:
            params_1d [in]: a 1D tf.Tensor representing the model's trainable parameters.
        """

        params = tf.dynamic_partition(params_1d, part, n_tensors)
        for i, (shape, param) in enumerate(zip(shapes, params)):
            model.trainable_variables[i].assign(tf.reshape(param, shape))

    # now create a function that will be returned by this factory
    @tf.function
    def f(params_1d):
        """A function that can be used by tfp.optimizer.lbfgs_minimize.
        This function is created by function_factory.
        Args:
           params_1d [in]: a 1D tf.Tensor.
        Returns:
            A scalar loss and the gradients w.r.t. the `params_1d`.
        """
        
        # update the parameters in the model
        assign_new_model_parameters(params_1d)
        # use GradientTape so that we can calculate the gradient of loss w.r.t. parameters
        with tf.GradientTape() as tape:
            
            # calculate the loss
            loss_total = model.loss(X_u1_train,u1_train,X_u2_train,u2_train,X_f_train)[0]

        # calculate gradients and convert to 1D tf.Tensor
        grads = tape.gradient(loss_total, model.trainable_variables[:trainable_nums])
        grads = tf.dynamic_stitch(idx, grads)

        del tape

        # print out iteration & loss
        f.num_objective_evaluations.assign_add(1)
        if (f.num_objective_evaluations % 50 == 0) :
          tf.print("num_objective_evaluations:", f.num_objective_evaluations,
                   "loss:",loss_total)

        # store loss value and k so we can retrieve later
        tf.py_function(f.loss_history.append, inp=[loss_total], Tout=[])

        return loss_total, grads

    # store these information as members so we can use them outside the scope
    f.num_objective_evaluations = tf.Variable(0)
    f.idx = idx
    f.part = part
    f.shapes = shapes
    f.assign_new_model_parameters = assign_new_model_parameters
    f.loss_history = []
    f.count = count

    return f

# %% [markdown]
# # Train

# %%
""" Training Data """

omga1 = [[-10.,10.],[0.,1.]]  # (x,t)的取值范围 
omga2 = [[-10.,10.],[0.,1.]]  # (x,t)的取值范围  


N_u1 = 200 ; N_f = 2000; omga = omga1;  u = u1
X_u1_train,u1_train,X_f_train= trainingdata(N_u1,N_f,omga,u)


N_u2 = 200; N_f = 2000; omga = omga2;  u = u2
X_u2_train,u2_train,X_f_train= trainingdata(N_u2,N_f,omga,u)


""" test Data """
N = 10000
x1_test,u1_test = test_data(N,omga1,u1)
x2_test,u2_test = test_data(N,omga2,u2)


""" DataSet  """
ds_train = ds_train_n_batch(X_u1_train, u1_train,  X_u2_train , u2_train ,  X_f_train ,n = 10)
ds_test = ds_test_n_batch(x1_test,u1_test,x2_test,u2_test,n=1)

# %%
Layers=[2,40,40,40,40,1]

model_u1 = SinglePinn(Layers,name="model_u1")
model_u1.compile(optimizer=keras.optimizers.Adam())

model_u2 = SinglePinn(Layers,name="model_u2")
model_u2.compile(optimizer=keras.optimizers.Adam())

# %%
saw_couple_model=SawCouplePinn(model_u1,model_u2,a,b,eta,name="saw_couple_pinn");
saw_couple_model.compile( loss=SawCoupledPinnLoss(saw_couple_model),
          optimizer=keras.optimizers.Adam() )

# %%
history_saw_cp_1 = saw_couple_model.fit(ds_train,validation_data=ds_test,epochs=500) #saw耦合PINN训练 Adam
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 67ms/step - loss: 4.6005e-06 - loss_u1: 2.0820e-06 - loss_u2: 2.5186e-06 - val_err_u1: 0.0130 - val_err_u2: 0.0254
# Epoch 2/500
# 10/10 [==============================] - 1s 87ms/step - loss: 4.5622e-06 - loss_u1: 2.0580e-06 - loss_u2: 2.5041e-06 - val_err_u1: 0.0129 - val_err_u2: 0.0253
# Epoch 3/500
# 10/10 [==============================] - 1s 70ms/step - loss: 4.5244e-06 - loss_u1: 2.0345e-06 - loss_u2: 2.4900e-06 - val_err_u1: 0.0128 - val_err_u2: 0.0251
# Epoch 4/500
# 10/10 [==============================] - 1s 82ms/step - loss: 4.4874e-06 - loss_u1: 2.0113e-06 - loss_u2: 2.4760e-06 - val_err_u1: 0.0127 - val_err_u2: 0.0250
# Epoch 5/500
# 10/10 [==============================] - 1s 87ms/step - loss: 4.4509e-06 - loss_u1: 1.9885e-06 - loss_u2: 2.4624e-06 - val_err_u1: 0.0126 - val_err_u2: 0.0248
# Epoch 6/500
# 10/10 [==============================] - 1s 72ms/step - loss: 4.4152e-06 - loss_u1: 1.9661e-06 - loss_u2: 2.4491e-06 - val_err_u1: 0.0125 - val_err_u2: 0.0246
# Epoch 7/500
# 10/10 [==============================] - 1s 78ms/step - loss: 4.3801e-06 - loss_u1: 1.9441e-06 - loss_u2: 2.4360e-06 - val_err_u1: 0.0124 - val_err_u2: 0.0244
# Epoch 8/500
# 10/10 [==============================] - 1s 79ms/step - loss: 4.3457e-06 - loss_u1: 1.9224e-06 - loss_u2: 2.4233e-06 - val_err_u1: 0.0123 - val_err_u2: 0.0242
# Epoch 9/500
# 10/10 [==============================] - 1s 116ms/step - loss: 4.3120e-06 - loss_u1: 1.9011e-06 - loss_u2: 2.4109e-06 - val_err_u1: 0.0122 - val_err_u2: 0.0239
# Epoch 10/500
# 10/10 [==============================] - 1s 79ms/step - loss: 4.2791e-06 - loss_u1: 1.8802e-06 - loss_u2: 2.3990e-06 - val_err_u1: 0.0121 - val_err_u2: 0.0237
# Epoch 11/500
# 10/10 [==============================] - 1s 75ms/step - loss: 4.2470e-06 - loss_u1: 1.8596e-06 - loss_u2: 2.3874e-06 - val_err_u1: 0.0120 - val_err_u2: 0.0235
# Epoch 12/500
# 10/10 [==============================] - 1s 94ms/step - loss: 4.2158e-06 - loss_u1: 1.8394e-06 - loss_u2: 2.3764e-06 - val_err_u1: 0.0120 - val_err_u2: 0.0234
# Epoch 13/500
# 10/10 [==============================] - 1s 79ms/step - loss: 4.1855e-06 - loss_u1: 1.8196e-06 - loss_u2: 2.3659e-06 - val_err_u1: 0.0119 - val_err_u2: 0.0232
# Epoch 14/500
# 10/10 [==============================] - 1s 62ms/step - loss: 4.1564e-06 - loss_u1: 1.8002e-06 - loss_u2: 2.3562e-06 - val_err_u1: 0.0118 - val_err_u2: 0.0231
# Epoch 15/500
# 10/10 [==============================] - 1s 88ms/step - loss: 4.1285e-06 - loss_u1: 1.7812e-06 - loss_u2: 2.3473e-06 - val_err_u1: 0.0117 - val_err_u2: 0.0230
# Epoch 16/500
# 10/10 [==============================] - 1s 70ms/step - loss: 4.1021e-06 - loss_u1: 1.7626e-06 - loss_u2: 2.3395e-06 - val_err_u1: 0.0116 - val_err_u2: 0.0230
# Epoch 17/500
# 10/10 [==============================] - 1s 77ms/step - loss: 4.0770e-06 - loss_u1: 1.7444e-06 - loss_u2: 2.3325e-06 - val_err_u1: 0.0116 - val_err_u2: 0.0229
# Epoch 18/500
# 10/10 [==============================] - 1s 72ms/step - loss: 4.0529e-06 - loss_u1: 1.7267e-06 - loss_u2: 2.3262e-06 - val_err_u1: 0.0115 - val_err_u2: 0.0229
# Epoch 19/500
# 10/10 [==============================] - 1s 70ms/step - loss: 4.0292e-06 - loss_u1: 1.7094e-06 - loss_u2: 2.3197e-06 - val_err_u1: 0.0115 - val_err_u2: 0.0228
# Epoch 20/500
# 10/10 [==============================] - 1s 70ms/step - loss: 4.0044e-06 - loss_u1: 1.6927e-06 - loss_u2: 2.3117e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0226
# Epoch 21/500
# 10/10 [==============================] - 1s 77ms/step - loss: 3.9774e-06 - loss_u1: 1.6765e-06 - loss_u2: 2.3009e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0226
# Epoch 22/500
# 10/10 [==============================] - 1s 67ms/step - loss: 3.9470e-06 - loss_u1: 1.6608e-06 - loss_u2: 2.2862e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0226
# Epoch 23/500
# 10/10 [==============================] - 1s 71ms/step - loss: 3.9134e-06 - loss_u1: 1.6458e-06 - loss_u2: 2.2676e-06 - val_err_u1: 0.0113 - val_err_u2: 0.0227
# Epoch 24/500
# 10/10 [==============================] - 1s 78ms/step - loss: 3.8780e-06 - loss_u1: 1.6315e-06 - loss_u2: 2.2465e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0229
# Epoch 25/500
# 10/10 [==============================] - 1s 67ms/step - loss: 3.8429e-06 - loss_u1: 1.6179e-06 - loss_u2: 2.2250e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0230
# Epoch 26/500
# 10/10 [==============================] - 1s 67ms/step - loss: 3.8101e-06 - loss_u1: 1.6052e-06 - loss_u2: 2.2049e-06 - val_err_u1: 0.0114 - val_err_u2: 0.0231
# Epoch 27/500
# 10/10 [==============================] - 1s 74ms/step - loss: 3.7806e-06 - loss_u1: 1.5935e-06 - loss_u2: 2.1872e-06 - val_err_u1: 0.0115 - val_err_u2: 0.0231
# Epoch 28/500
# 10/10 [==============================] - 1s 68ms/step - loss: 3.7545e-06 - loss_u1: 1.5828e-06 - loss_u2: 2.1716e-06 - val_err_u1: 0.0116 - val_err_u2: 0.0231
# Epoch 29/500
# 10/10 [==============================] - 1s 79ms/step - loss: 3.7311e-06 - loss_u1: 1.5735e-06 - loss_u2: 2.1576e-06 - val_err_u1: 0.0118 - val_err_u2: 0.0231
# Epoch 30/500
# 10/10 [==============================] - 1s 71ms/step - loss: 3.7099e-06 - loss_u1: 1.5656e-06 - loss_u2: 2.1443e-06 - val_err_u1: 0.0120 - val_err_u2: 0.0231
# Epoch 31/500
# 10/10 [==============================] - 1s 71ms/step - loss: 3.6906e-06 - loss_u1: 1.5593e-06 - loss_u2: 2.1313e-06 - val_err_u1: 0.0123 - val_err_u2: 0.0231
# Epoch 32/500
# 10/10 [==============================] - 1s 78ms/step - loss: 3.6734e-06 - loss_u1: 1.5548e-06 - loss_u2: 2.1187e-06 - val_err_u1: 0.0127 - val_err_u2: 0.0230
# Epoch 33/500
# 10/10 [==============================] - 1s 77ms/step - loss: 3.6586e-06 - loss_u1: 1.5521e-06 - loss_u2: 2.1065e-06 - val_err_u1: 0.0131 - val_err_u2: 0.0230
# Epoch 34/500
# 10/10 [==============================] - 1s 69ms/step - loss: 3.6460e-06 - loss_u1: 1.5513e-06 - loss_u2: 2.0947e-06 - val_err_u1: 0.0137 - val_err_u2: 0.0230
# Epoch 35/500
# 10/10 [==============================] - 1s 73ms/step - loss: 3.6354e-06 - loss_u1: 1.5522e-06 - loss_u2: 2.0832e-06 - val_err_u1: 0.0143 - val_err_u2: 0.0229
# Epoch 36/500
# 10/10 [==============================] - 1s 73ms/step - loss: 3.6262e-06 - loss_u1: 1.5543e-06 - loss_u2: 2.0720e-06 - val_err_u1: 0.0150 - val_err_u2: 0.0229
# Epoch 37/500
# 10/10 [==============================] - 1s 71ms/step - loss: 3.6177e-06 - loss_u1: 1.5567e-06 - loss_u2: 2.0610e-06 - val_err_u1: 0.0157 - val_err_u2: 0.0228
# Epoch 38/500
# 10/10 [==============================] - 1s 75ms/step - loss: 3.6085e-06 - loss_u1: 1.5582e-06 - loss_u2: 2.0503e-06 - val_err_u1: 0.0163 - val_err_u2: 0.0227
# Epoch 39/500
# 10/10 [==============================] - 1s 71ms/step - loss: 3.5970e-06 - loss_u1: 1.5571e-06 - loss_u2: 2.0399e-06 - val_err_u1: 0.0168 - val_err_u2: 0.0227
# Epoch 40/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.5810e-06 - loss_u1: 1.5514e-06 - loss_u2: 2.0296e-06 - val_err_u1: 0.0170 - val_err_u2: 0.0226
# Epoch 41/500
# 10/10 [==============================] - 0s 50ms/step - loss: 3.5585e-06 - loss_u1: 1.5389e-06 - loss_u2: 2.0196e-06 - val_err_u1: 0.0168 - val_err_u2: 0.0225
# Epoch 42/500
# 10/10 [==============================] - 0s 53ms/step - loss: 3.5276e-06 - loss_u1: 1.5178e-06 - loss_u2: 2.0099e-06 - val_err_u1: 0.0161 - val_err_u2: 0.0225
# Epoch 43/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.4872e-06 - loss_u1: 1.4868e-06 - loss_u2: 2.0003e-06 - val_err_u1: 0.0150 - val_err_u2: 0.0224
# Epoch 44/500
# 10/10 [==============================] - 0s 52ms/step - loss: 3.4371e-06 - loss_u1: 1.4461e-06 - loss_u2: 1.9910e-06 - val_err_u1: 0.0135 - val_err_u2: 0.0223
# Epoch 45/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.3793e-06 - loss_u1: 1.3974e-06 - loss_u2: 1.9819e-06 - val_err_u1: 0.0119 - val_err_u2: 0.0223
# Epoch 46/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.3183e-06 - loss_u1: 1.3452e-06 - loss_u2: 1.9731e-06 - val_err_u1: 0.0106 - val_err_u2: 0.0222
# Epoch 47/500
# 10/10 [==============================] - 0s 52ms/step - loss: 3.2608e-06 - loss_u1: 1.2963e-06 - loss_u2: 1.9645e-06 - val_err_u1: 0.0098 - val_err_u2: 0.0221
# Epoch 48/500
# 10/10 [==============================] - 1s 53ms/step - loss: 3.2142e-06 - loss_u1: 1.2580e-06 - loss_u2: 1.9562e-06 - val_err_u1: 0.0096 - val_err_u2: 0.0220
# Epoch 49/500
# 10/10 [==============================] - 1s 53ms/step - loss: 3.1835e-06 - loss_u1: 1.2354e-06 - loss_u2: 1.9481e-06 - val_err_u1: 0.0099 - val_err_u2: 0.0220
# Epoch 50/500
# 10/10 [==============================] - 1s 56ms/step - loss: 3.1677e-06 - loss_u1: 1.2273e-06 - loss_u2: 1.9404e-06 - val_err_u1: 0.0103 - val_err_u2: 0.0219
# Epoch 51/500
# 10/10 [==============================] - 1s 53ms/step - loss: 3.1596e-06 - loss_u1: 1.2265e-06 - loss_u2: 1.9331e-06 - val_err_u1: 0.0104 - val_err_u2: 0.0218
# Epoch 52/500
# 10/10 [==============================] - 1s 56ms/step - loss: 3.1494e-06 - loss_u1: 1.2233e-06 - loss_u2: 1.9262e-06 - val_err_u1: 0.0101 - val_err_u2: 0.0217
# Epoch 53/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.1312e-06 - loss_u1: 1.2115e-06 - loss_u2: 1.9197e-06 - val_err_u1: 0.0095 - val_err_u2: 0.0217
# Epoch 54/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.1062e-06 - loss_u1: 1.1925e-06 - loss_u2: 1.9137e-06 - val_err_u1: 0.0090 - val_err_u2: 0.0216
# Epoch 55/500
# 10/10 [==============================] - 0s 53ms/step - loss: 3.0809e-06 - loss_u1: 1.1725e-06 - loss_u2: 1.9083e-06 - val_err_u1: 0.0089 - val_err_u2: 0.0216
# Epoch 56/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.0604e-06 - loss_u1: 1.1567e-06 - loss_u2: 1.9037e-06 - val_err_u1: 0.0089 - val_err_u2: 0.0215
# Epoch 57/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.0454e-06 - loss_u1: 1.1454e-06 - loss_u2: 1.9000e-06 - val_err_u1: 0.0090 - val_err_u2: 0.0215
# Epoch 58/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.0326e-06 - loss_u1: 1.1353e-06 - loss_u2: 1.8973e-06 - val_err_u1: 0.0089 - val_err_u2: 0.0215
# Epoch 59/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.0204e-06 - loss_u1: 1.1242e-06 - loss_u2: 1.8961e-06 - val_err_u1: 0.0088 - val_err_u2: 0.0216
# Epoch 60/500
# 10/10 [==============================] - 1s 52ms/step - loss: 3.0097e-06 - loss_u1: 1.1129e-06 - loss_u2: 1.8968e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0217
# Epoch 61/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.0020e-06 - loss_u1: 1.1021e-06 - loss_u2: 1.8999e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0218
# Epoch 62/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.9981e-06 - loss_u1: 1.0915e-06 - loss_u2: 1.9066e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0221
# Epoch 63/500
# 10/10 [==============================] - 1s 53ms/step - loss: 2.9993e-06 - loss_u1: 1.0809e-06 - loss_u2: 1.9184e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0225
# Epoch 64/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.0086e-06 - loss_u1: 1.0704e-06 - loss_u2: 1.9383e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0231
# Epoch 65/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.0310e-06 - loss_u1: 1.0601e-06 - loss_u2: 1.9710e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0241
# Epoch 66/500
# 10/10 [==============================] - 1s 64ms/step - loss: 3.0756e-06 - loss_u1: 1.0498e-06 - loss_u2: 2.0258e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0254
# Epoch 67/500
# 10/10 [==============================] - 1s 85ms/step - loss: 3.1607e-06 - loss_u1: 1.0396e-06 - loss_u2: 2.1211e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0274
# Epoch 68/500
# 10/10 [==============================] - 1s 83ms/step - loss: 3.3243e-06 - loss_u1: 1.0296e-06 - loss_u2: 2.2947e-06 - val_err_u1: 0.0086 - val_err_u2: 0.0303
# Epoch 69/500
# 10/10 [==============================] - 1s 55ms/step - loss: 3.6497e-06 - loss_u1: 1.0196e-06 - loss_u2: 2.6302e-06 - val_err_u1: 0.0086 - val_err_u2: 0.0343
# Epoch 70/500
# 10/10 [==============================] - 1s 56ms/step - loss: 4.3270e-06 - loss_u1: 1.0097e-06 - loss_u2: 3.3173e-06 - val_err_u1: 0.0085 - val_err_u2: 0.0396
# Epoch 71/500
# 10/10 [==============================] - 1s 58ms/step - loss: 5.7972e-06 - loss_u1: 9.9987e-07 - loss_u2: 4.7973e-06 - val_err_u1: 0.0084 - val_err_u2: 0.0464
# Epoch 72/500
# 10/10 [==============================] - 1s 53ms/step - loss: 9.0726e-06 - loss_u1: 9.9025e-07 - loss_u2: 8.0823e-06 - val_err_u1: 0.0082 - val_err_u2: 0.0550
# Epoch 73/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.6320e-05 - loss_u1: 9.8092e-07 - loss_u2: 1.5339e-05 - val_err_u1: 0.0080 - val_err_u2: 0.0669
# Epoch 74/500
# 10/10 [==============================] - 1s 61ms/step - loss: 3.1451e-05 - loss_u1: 9.7215e-07 - loss_u2: 3.0479e-05 - val_err_u1: 0.0078 - val_err_u2: 0.0895
# Epoch 75/500
# 10/10 [==============================] - 1s 54ms/step - loss: 5.8944e-05 - loss_u1: 9.6428e-07 - loss_u2: 5.7980e-05 - val_err_u1: 0.0075 - val_err_u2: 0.1446
# Epoch 76/500
# 10/10 [==============================] - 1s 61ms/step - loss: 9.4760e-05 - loss_u1: 9.5743e-07 - loss_u2: 9.3803e-05 - val_err_u1: 0.0073 - val_err_u2: 0.2680
# Epoch 77/500
# 10/10 [==============================] - 1s 53ms/step - loss: 1.0439e-04 - loss_u1: 9.5040e-07 - loss_u2: 1.0344e-04 - val_err_u1: 0.0070 - val_err_u2: 0.3710
# Epoch 78/500
# 10/10 [==============================] - 1s 53ms/step - loss: 5.7495e-05 - loss_u1: 9.4283e-07 - loss_u2: 5.6552e-05 - val_err_u1: 0.0068 - val_err_u2: 0.1680
# Epoch 79/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.4228e-05 - loss_u1: 9.4021e-07 - loss_u2: 1.3288e-05 - val_err_u1: 0.0066 - val_err_u2: 0.0956
# Epoch 80/500
# 10/10 [==============================] - 1s 53ms/step - loss: 8.2907e-06 - loss_u1: 9.3738e-07 - loss_u2: 7.3533e-06 - val_err_u1: 0.0064 - val_err_u2: 0.0767
# Epoch 81/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.9528e-06 - loss_u1: 9.3074e-07 - loss_u2: 3.0221e-06 - val_err_u1: 0.0061 - val_err_u2: 0.0328
# Epoch 82/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.7068e-06 - loss_u1: 9.2630e-07 - loss_u2: 3.7806e-06 - val_err_u1: 0.0060 - val_err_u2: 0.0583
# Epoch 83/500
# 10/10 [==============================] - 1s 52ms/step - loss: 4.4336e-06 - loss_u1: 9.2386e-07 - loss_u2: 3.5097e-06 - val_err_u1: 0.0059 - val_err_u2: 0.0403
# Epoch 84/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.4110e-06 - loss_u1: 9.2427e-07 - loss_u2: 2.4867e-06 - val_err_u1: 0.0059 - val_err_u2: 0.0258
# Epoch 85/500
# 10/10 [==============================] - 0s 52ms/step - loss: 2.9716e-06 - loss_u1: 9.2624e-07 - loss_u2: 2.0453e-06 - val_err_u1: 0.0059 - val_err_u2: 0.0248
# Epoch 86/500
# 10/10 [==============================] - 1s 52ms/step - loss: 2.9886e-06 - loss_u1: 9.2988e-07 - loss_u2: 2.0587e-06 - val_err_u1: 0.0060 - val_err_u2: 0.0273
# Epoch 87/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.3793e-06 - loss_u1: 9.3653e-07 - loss_u2: 2.4427e-06 - val_err_u1: 0.0062 - val_err_u2: 0.0339
# Epoch 88/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.3632e-06 - loss_u1: 9.4707e-07 - loss_u2: 3.4161e-06 - val_err_u1: 0.0066 - val_err_u2: 0.0419
# Epoch 89/500
# 10/10 [==============================] - 1s 56ms/step - loss: 6.7207e-06 - loss_u1: 9.6311e-07 - loss_u2: 5.7576e-06 - val_err_u1: 0.0072 - val_err_u2: 0.0494
# Epoch 90/500
# 10/10 [==============================] - 1s 54ms/step - loss: 1.2175e-05 - loss_u1: 9.8615e-07 - loss_u2: 1.1189e-05 - val_err_u1: 0.0080 - val_err_u2: 0.0582
# Epoch 91/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.4593e-05 - loss_u1: 1.0191e-06 - loss_u2: 2.3574e-05 - val_err_u1: 0.0091 - val_err_u2: 0.0724
# Epoch 92/500
# 10/10 [==============================] - 1s 53ms/step - loss: 4.9879e-05 - loss_u1: 1.0659e-06 - loss_u2: 4.8813e-05 - val_err_u1: 0.0105 - val_err_u2: 0.1077
# Epoch 93/500
# 10/10 [==============================] - 1s 53ms/step - loss: 9.1812e-05 - loss_u1: 1.1323e-06 - loss_u2: 9.0680e-05 - val_err_u1: 0.0124 - val_err_u2: 0.2084
# Epoch 94/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.2953e-04 - loss_u1: 1.2254e-06 - loss_u2: 1.2830e-04 - val_err_u1: 0.0147 - val_err_u2: 0.3925
# Epoch 95/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.0102e-04 - loss_u1: 1.3531e-06 - loss_u2: 9.9663e-05 - val_err_u1: 0.0176 - val_err_u2: 0.3268
# Epoch 96/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.3804e-05 - loss_u1: 1.5318e-06 - loss_u2: 3.2273e-05 - val_err_u1: 0.0210 - val_err_u2: 0.0769
# Epoch 97/500
# 10/10 [==============================] - 0s 51ms/step - loss: 1.3440e-05 - loss_u1: 1.7724e-06 - loss_u2: 1.1667e-05 - val_err_u1: 0.0245 - val_err_u2: 0.1235
# Epoch 98/500
# 10/10 [==============================] - 1s 74ms/step - loss: 7.2814e-06 - loss_u1: 2.0614e-06 - loss_u2: 5.2200e-06 - val_err_u1: 0.0280 - val_err_u2: 0.0391
# Epoch 99/500
# 10/10 [==============================] - 1s 96ms/step - loss: 6.8900e-06 - loss_u1: 2.3853e-06 - loss_u2: 4.5047e-06 - val_err_u1: 0.0305 - val_err_u2: 0.0686
# Epoch 100/500
# 10/10 [==============================] - 1s 67ms/step - loss: 6.3517e-06 - loss_u1: 2.6802e-06 - loss_u2: 3.6715e-06 - val_err_u1: 0.0306 - val_err_u2: 0.0254
# Epoch 101/500
# 10/10 [==============================] - 1s 55ms/step - loss: 5.1094e-06 - loss_u1: 2.8259e-06 - loss_u2: 2.2835e-06 - val_err_u1: 0.0272 - val_err_u2: 0.0209
# Epoch 102/500
# 10/10 [==============================] - 1s 54ms/step - loss: 4.4993e-06 - loss_u1: 2.6956e-06 - loss_u2: 1.8037e-06 - val_err_u1: 0.0195 - val_err_u2: 0.0182
# Epoch 103/500
# 10/10 [==============================] - 1s 53ms/step - loss: 3.9566e-06 - loss_u1: 2.2481e-06 - loss_u2: 1.7085e-06 - val_err_u1: 0.0091 - val_err_u2: 0.0219
# Epoch 104/500
# 10/10 [==============================] - 0s 53ms/step - loss: 3.5724e-06 - loss_u1: 1.6355e-06 - loss_u2: 1.9368e-06 - val_err_u1: 0.0075 - val_err_u2: 0.0288
# Epoch 105/500
# 10/10 [==============================] - 1s 55ms/step - loss: 3.3163e-06 - loss_u1: 1.1304e-06 - loss_u2: 2.1859e-06 - val_err_u1: 0.0134 - val_err_u2: 0.0341
# Epoch 106/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.4196e-06 - loss_u1: 8.7418e-07 - loss_u2: 2.5454e-06 - val_err_u1: 0.0137 - val_err_u2: 0.0383
# Epoch 107/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.0420e-06 - loss_u1: 7.7579e-07 - loss_u2: 3.2662e-06 - val_err_u1: 0.0112 - val_err_u2: 0.0430
# Epoch 108/500
# 10/10 [==============================] - 1s 52ms/step - loss: 5.7589e-06 - loss_u1: 7.4846e-07 - loss_u2: 5.0104e-06 - val_err_u1: 0.0110 - val_err_u2: 0.0486
# Epoch 109/500
# 10/10 [==============================] - 1s 56ms/step - loss: 9.9806e-06 - loss_u1: 7.4324e-07 - loss_u2: 9.2373e-06 - val_err_u1: 0.0123 - val_err_u2: 0.0554
# Epoch 110/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.9811e-05 - loss_u1: 7.2302e-07 - loss_u2: 1.9088e-05 - val_err_u1: 0.0119 - val_err_u2: 0.0657
# Epoch 111/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.0618e-05 - loss_u1: 7.0673e-07 - loss_u2: 3.9911e-05 - val_err_u1: 0.0116 - val_err_u2: 0.0909
# Epoch 112/500
# 10/10 [==============================] - 1s 58ms/step - loss: 7.8098e-05 - loss_u1: 6.9978e-07 - loss_u2: 7.7398e-05 - val_err_u1: 0.0118 - val_err_u2: 0.1646
# Epoch 113/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.2396e-04 - loss_u1: 6.9658e-07 - loss_u2: 1.2326e-04 - val_err_u1: 0.0117 - val_err_u2: 0.3410
# Epoch 114/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.2213e-04 - loss_u1: 6.8982e-07 - loss_u2: 1.2144e-04 - val_err_u1: 0.0116 - val_err_u2: 0.4175
# Epoch 115/500
# 10/10 [==============================] - 1s 56ms/step - loss: 5.4111e-05 - loss_u1: 6.9253e-07 - loss_u2: 5.3418e-05 - val_err_u1: 0.0120 - val_err_u2: 0.0543
# Epoch 116/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.4768e-05 - loss_u1: 6.9947e-07 - loss_u2: 1.4068e-05 - val_err_u1: 0.0118 - val_err_u2: 0.1617
# Epoch 117/500
# 10/10 [==============================] - 1s 61ms/step - loss: 8.9706e-06 - loss_u1: 7.0888e-07 - loss_u2: 8.2617e-06 - val_err_u1: 0.0128 - val_err_u2: 0.0182
# Epoch 118/500
# 10/10 [==============================] - 1s 51ms/step - loss: 4.4575e-06 - loss_u1: 8.2252e-07 - loss_u2: 3.6349e-06 - val_err_u1: 0.0150 - val_err_u2: 0.0758
# Epoch 119/500
# 10/10 [==============================] - 1s 61ms/step - loss: 5.0638e-06 - loss_u1: 9.2703e-07 - loss_u2: 4.1368e-06 - val_err_u1: 0.0145 - val_err_u2: 0.0322
# Epoch 120/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.3315e-06 - loss_u1: 9.0871e-07 - loss_u2: 2.4228e-06 - val_err_u1: 0.0166 - val_err_u2: 0.0222
# Epoch 121/500
# 10/10 [==============================] - 1s 63ms/step - loss: 4.5957e-06 - loss_u1: 2.7996e-06 - loss_u2: 1.7962e-06 - val_err_u1: 0.0445 - val_err_u2: 0.0202
# Epoch 122/500
# 10/10 [==============================] - 1s 66ms/step - loss: 5.5949e-05 - loss_u1: 5.4419e-05 - loss_u2: 1.5303e-06 - val_err_u1: 0.1846 - val_err_u2: 0.0182
# Epoch 123/500
# 10/10 [==============================] - 1s 78ms/step - loss: 2.9172e-04 - loss_u1: 2.9004e-04 - loss_u2: 1.6784e-06 - val_err_u1: 0.2292 - val_err_u2: 0.0242
# Epoch 124/500
# 10/10 [==============================] - 1s 77ms/step - loss: 3.5786e-04 - loss_u1: 3.5606e-04 - loss_u2: 1.7987e-06 - val_err_u1: 0.3042 - val_err_u2: 0.0279
# Epoch 125/500
# 10/10 [==============================] - 1s 67ms/step - loss: 1.1460e-04 - loss_u1: 1.1269e-04 - loss_u2: 1.9088e-06 - val_err_u1: 0.2700 - val_err_u2: 0.0308
# Epoch 126/500
# 10/10 [==============================] - 1s 74ms/step - loss: 7.0968e-05 - loss_u1: 6.8901e-05 - loss_u2: 2.0668e-06 - val_err_u1: 0.1180 - val_err_u2: 0.0333
# Epoch 127/500
# 10/10 [==============================] - 1s 63ms/step - loss: 2.6992e-05 - loss_u1: 2.4486e-05 - loss_u2: 2.5063e-06 - val_err_u1: 0.0701 - val_err_u2: 0.0366
# Epoch 128/500
# 10/10 [==============================] - 1s 65ms/step - loss: 1.7823e-05 - loss_u1: 1.4139e-05 - loss_u2: 3.6843e-06 - val_err_u1: 0.0679 - val_err_u2: 0.0408
# Epoch 129/500
# 10/10 [==============================] - 1s 66ms/step - loss: 1.5664e-05 - loss_u1: 8.9536e-06 - loss_u2: 6.7102e-06 - val_err_u1: 0.0401 - val_err_u2: 0.0456
# Epoch 130/500
# 10/10 [==============================] - 1s 82ms/step - loss: 1.7787e-05 - loss_u1: 3.6828e-06 - loss_u2: 1.4104e-05 - val_err_u1: 0.0153 - val_err_u2: 0.0511
# Epoch 131/500
# 10/10 [==============================] - 1s 61ms/step - loss: 3.1836e-05 - loss_u1: 1.5014e-06 - loss_u2: 3.0335e-05 - val_err_u1: 0.0115 - val_err_u2: 0.0661
# Epoch 132/500
# 10/10 [==============================] - 1s 57ms/step - loss: 6.3225e-05 - loss_u1: 1.0684e-06 - loss_u2: 6.2157e-05 - val_err_u1: 0.0110 - val_err_u2: 0.1117
# Epoch 133/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.1320e-04 - loss_u1: 1.0393e-06 - loss_u2: 1.1216e-04 - val_err_u1: 0.0118 - val_err_u2: 0.2529
# Epoch 134/500
# 10/10 [==============================] - 1s 63ms/step - loss: 1.4635e-04 - loss_u1: 1.1145e-06 - loss_u2: 1.4524e-04 - val_err_u1: 0.0141 - val_err_u2: 0.4670
# Epoch 135/500
# 10/10 [==============================] - 1s 62ms/step - loss: 9.3375e-05 - loss_u1: 1.2396e-06 - loss_u2: 9.2135e-05 - val_err_u1: 0.0168 - val_err_u2: 0.2183
# Epoch 136/500
# 10/10 [==============================] - 1s 57ms/step - loss: 2.5844e-05 - loss_u1: 1.3978e-06 - loss_u2: 2.4446e-05 - val_err_u1: 0.0198 - val_err_u2: 0.1893
# Epoch 137/500
# 10/10 [==============================] - 1s 61ms/step - loss: 1.5405e-05 - loss_u1: 1.5937e-06 - loss_u2: 1.3812e-05 - val_err_u1: 0.0221 - val_err_u2: 0.0471
# Epoch 138/500
# 10/10 [==============================] - 1s 60ms/step - loss: 5.7929e-06 - loss_u1: 1.7748e-06 - loss_u2: 4.0181e-06 - val_err_u1: 0.0228 - val_err_u2: 0.0903
# Epoch 139/500
# 10/10 [==============================] - 1s 63ms/step - loss: 7.2710e-06 - loss_u1: 1.8702e-06 - loss_u2: 5.4008e-06 - val_err_u1: 0.0206 - val_err_u2: 0.0320
# Epoch 140/500
# 10/10 [==============================] - 1s 56ms/step - loss: 4.6705e-06 - loss_u1: 1.7913e-06 - loss_u2: 2.8792e-06 - val_err_u1: 0.0153 - val_err_u2: 0.0368
# Epoch 141/500
# 10/10 [==============================] - 1s 61ms/step - loss: 3.3775e-06 - loss_u1: 1.5204e-06 - loss_u2: 1.8572e-06 - val_err_u1: 0.0092 - val_err_u2: 0.0235
# Epoch 142/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.6236e-06 - loss_u1: 1.1621e-06 - loss_u2: 1.4615e-06 - val_err_u1: 0.0096 - val_err_u2: 0.0214
# Epoch 143/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.6814e-06 - loss_u1: 8.8766e-07 - loss_u2: 1.7938e-06 - val_err_u1: 0.0132 - val_err_u2: 0.0259
# Epoch 144/500
# 10/10 [==============================] - 1s 54ms/step - loss: 2.3854e-06 - loss_u1: 7.6296e-07 - loss_u2: 1.6224e-06 - val_err_u1: 0.0143 - val_err_u2: 0.0198
# Epoch 145/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.2859e-06 - loss_u1: 7.2133e-07 - loss_u2: 1.5646e-06 - val_err_u1: 0.0143 - val_err_u2: 0.0201
# Epoch 146/500
# 10/10 [==============================] - 1s 94ms/step - loss: 2.1728e-06 - loss_u1: 7.0079e-07 - loss_u2: 1.4720e-06 - val_err_u1: 0.0147 - val_err_u2: 0.0204
# Epoch 147/500
# 10/10 [==============================] - 1s 87ms/step - loss: 2.1442e-06 - loss_u1: 6.7631e-07 - loss_u2: 1.4679e-06 - val_err_u1: 0.0144 - val_err_u2: 0.0208
# Epoch 148/500
# 10/10 [==============================] - 1s 77ms/step - loss: 2.1507e-06 - loss_u1: 6.5279e-07 - loss_u2: 1.4979e-06 - val_err_u1: 0.0136 - val_err_u2: 0.0247
# Epoch 149/500
# 10/10 [==============================] - 1s 111ms/step - loss: 2.3005e-06 - loss_u1: 6.3207e-07 - loss_u2: 1.6684e-06 - val_err_u1: 0.0133 - val_err_u2: 0.0274
# Epoch 150/500
# 10/10 [==============================] - 1s 108ms/step - loss: 2.7862e-06 - loss_u1: 6.2067e-07 - loss_u2: 2.1655e-06 - val_err_u1: 0.0129 - val_err_u2: 0.0300
# Epoch 151/500
# 10/10 [==============================] - 1s 69ms/step - loss: 4.1648e-06 - loss_u1: 6.0869e-07 - loss_u2: 3.5561e-06 - val_err_u1: 0.0129 - val_err_u2: 0.0331
# Epoch 152/500
# 10/10 [==============================] - 1s 60ms/step - loss: 7.9074e-06 - loss_u1: 6.1265e-07 - loss_u2: 7.2948e-06 - val_err_u1: 0.0128 - val_err_u2: 0.0337
# Epoch 153/500
# 10/10 [==============================] - 1s 53ms/step - loss: 1.6744e-05 - loss_u1: 6.0664e-07 - loss_u2: 1.6137e-05 - val_err_u1: 0.0128 - val_err_u2: 0.0403
# Epoch 154/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.5550e-05 - loss_u1: 6.4031e-07 - loss_u2: 3.4910e-05 - val_err_u1: 0.0136 - val_err_u2: 0.0591
# Epoch 155/500
# 10/10 [==============================] - 1s 53ms/step - loss: 7.0757e-05 - loss_u1: 6.8024e-07 - loss_u2: 7.0077e-05 - val_err_u1: 0.0138 - val_err_u2: 0.1022
# Epoch 156/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.2656e-04 - loss_u1: 7.3066e-07 - loss_u2: 1.2583e-04 - val_err_u1: 0.0148 - val_err_u2: 0.2682
# Epoch 157/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.6085e-04 - loss_u1: 9.7694e-07 - loss_u2: 1.5987e-04 - val_err_u1: 0.0194 - val_err_u2: 0.5169
# Epoch 158/500
# 10/10 [==============================] - 1s 57ms/step - loss: 9.7629e-05 - loss_u1: 2.6356e-06 - loss_u2: 9.4993e-05 - val_err_u1: 0.0371 - val_err_u2: 0.1325
# Epoch 159/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.4795e-05 - loss_u1: 2.0709e-05 - loss_u2: 2.4085e-05 - val_err_u1: 0.1117 - val_err_u2: 0.2336
# Epoch 160/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.2803e-04 - loss_u1: 2.1277e-04 - loss_u2: 1.5262e-05 - val_err_u1: 0.1829 - val_err_u2: 0.0696
# Epoch 161/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.0900e-04 - loss_u1: 2.0339e-04 - loss_u2: 5.6149e-06 - val_err_u1: 0.0389 - val_err_u2: 0.0699
# Epoch 162/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.2723e-04 - loss_u1: 1.2283e-04 - loss_u2: 4.3970e-06 - val_err_u1: 0.2213 - val_err_u2: 0.0547
# Epoch 163/500
# 10/10 [==============================] - 1s 56ms/step - loss: 7.2932e-05 - loss_u1: 6.9529e-05 - loss_u2: 3.4025e-06 - val_err_u1: 0.1774 - val_err_u2: 0.0347
# Epoch 164/500
# 10/10 [==============================] - 1s 61ms/step - loss: 4.7363e-05 - loss_u1: 4.5101e-05 - loss_u2: 2.2622e-06 - val_err_u1: 0.1207 - val_err_u2: 0.0448
# Epoch 165/500
# 10/10 [==============================] - 1s 54ms/step - loss: 2.1872e-05 - loss_u1: 1.9890e-05 - loss_u2: 1.9824e-06 - val_err_u1: 0.0996 - val_err_u2: 0.0254
# Epoch 166/500
# 10/10 [==============================] - 0s 51ms/step - loss: 1.5806e-05 - loss_u1: 1.3651e-05 - loss_u2: 2.1548e-06 - val_err_u1: 0.0900 - val_err_u2: 0.0335
# Epoch 167/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.3283e-05 - loss_u1: 1.1450e-05 - loss_u2: 1.8325e-06 - val_err_u1: 0.0824 - val_err_u2: 0.0188
# Epoch 168/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.0788e-05 - loss_u1: 9.0997e-06 - loss_u2: 1.6887e-06 - val_err_u1: 0.0703 - val_err_u2: 0.0273
# Epoch 169/500
# 10/10 [==============================] - 1s 54ms/step - loss: 8.6860e-06 - loss_u1: 7.1818e-06 - loss_u2: 1.5042e-06 - val_err_u1: 0.0569 - val_err_u2: 0.0156
# Epoch 170/500
# 10/10 [==============================] - 1s 55ms/step - loss: 7.0054e-06 - loss_u1: 5.4734e-06 - loss_u2: 1.5320e-06 - val_err_u1: 0.0413 - val_err_u2: 0.0216
# Epoch 171/500
# 10/10 [==============================] - 1s 56ms/step - loss: 4.8882e-06 - loss_u1: 3.5297e-06 - loss_u2: 1.3585e-06 - val_err_u1: 0.0252 - val_err_u2: 0.0180
# Epoch 172/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.2576e-06 - loss_u1: 1.9006e-06 - loss_u2: 1.3569e-06 - val_err_u1: 0.0123 - val_err_u2: 0.0193
# Epoch 173/500
# 10/10 [==============================] - 1s 58ms/step - loss: 2.2799e-06 - loss_u1: 9.8342e-07 - loss_u2: 1.2965e-06 - val_err_u1: 0.0077 - val_err_u2: 0.0222
# Epoch 174/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.0140e-06 - loss_u1: 6.5682e-07 - loss_u2: 1.3572e-06 - val_err_u1: 0.0067 - val_err_u2: 0.0225
# Epoch 175/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.0913e-06 - loss_u1: 5.7444e-07 - loss_u2: 1.5168e-06 - val_err_u1: 0.0068 - val_err_u2: 0.0250
# Epoch 176/500
# 10/10 [==============================] - 1s 53ms/step - loss: 2.6750e-06 - loss_u1: 5.5606e-07 - loss_u2: 2.1189e-06 - val_err_u1: 0.0084 - val_err_u2: 0.0272
# Epoch 177/500
# 10/10 [==============================] - 0s 50ms/step - loss: 4.3406e-06 - loss_u1: 5.2707e-07 - loss_u2: 3.8135e-06 - val_err_u1: 0.0095 - val_err_u2: 0.0247
# Epoch 178/500
# 10/10 [==============================] - 1s 55ms/step - loss: 8.6019e-06 - loss_u1: 5.0146e-07 - loss_u2: 8.1004e-06 - val_err_u1: 0.0097 - val_err_u2: 0.0285
# Epoch 179/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.8256e-05 - loss_u1: 4.9071e-07 - loss_u2: 1.7765e-05 - val_err_u1: 0.0101 - val_err_u2: 0.0402
# Epoch 180/500
# 10/10 [==============================] - 1s 52ms/step - loss: 3.6786e-05 - loss_u1: 4.8291e-07 - loss_u2: 3.6303e-05 - val_err_u1: 0.0102 - val_err_u2: 0.0623
# Epoch 181/500
# 10/10 [==============================] - 1s 61ms/step - loss: 7.0100e-05 - loss_u1: 4.7823e-07 - loss_u2: 6.9622e-05 - val_err_u1: 0.0102 - val_err_u2: 0.0934
# Epoch 182/500
# 10/10 [==============================] - 1s 62ms/step - loss: 1.2476e-04 - loss_u1: 4.7940e-07 - loss_u2: 1.2428e-04 - val_err_u1: 0.0102 - val_err_u2: 0.2538
# Epoch 183/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.6258e-04 - loss_u1: 4.8388e-07 - loss_u2: 1.6210e-04 - val_err_u1: 0.0102 - val_err_u2: 0.5305
# Epoch 184/500
# 10/10 [==============================] - 1s 53ms/step - loss: 9.9807e-05 - loss_u1: 4.8391e-07 - loss_u2: 9.9323e-05 - val_err_u1: 0.0103 - val_err_u2: 0.1234
# Epoch 185/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.5744e-05 - loss_u1: 4.9984e-07 - loss_u2: 2.5244e-05 - val_err_u1: 0.0108 - val_err_u2: 0.2440
# Epoch 186/500
# 10/10 [==============================] - 0s 48ms/step - loss: 1.7059e-05 - loss_u1: 5.4050e-07 - loss_u2: 1.6519e-05 - val_err_u1: 0.0119 - val_err_u2: 0.1080
# Epoch 187/500
# 10/10 [==============================] - 1s 53ms/step - loss: 7.4958e-06 - loss_u1: 6.8851e-07 - loss_u2: 6.8073e-06 - val_err_u1: 0.0148 - val_err_u2: 0.0452
# Epoch 188/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.9036e-06 - loss_u1: 1.1499e-06 - loss_u2: 3.7537e-06 - val_err_u1: 0.0213 - val_err_u2: 0.0678
# Epoch 189/500
# 10/10 [==============================] - 1s 59ms/step - loss: 7.6308e-06 - loss_u1: 3.9777e-06 - loss_u2: 3.6531e-06 - val_err_u1: 0.0473 - val_err_u2: 0.0382
# Epoch 190/500
# 10/10 [==============================] - 1s 58ms/step - loss: 5.3390e-05 - loss_u1: 5.0147e-05 - loss_u2: 3.2426e-06 - val_err_u1: 0.1797 - val_err_u2: 0.0619
# Epoch 191/500
# 10/10 [==============================] - 1s 55ms/step - loss: 3.2146e-04 - loss_u1: 3.1872e-04 - loss_u2: 2.7383e-06 - val_err_u1: 0.2327 - val_err_u2: 0.0426
# Epoch 192/500
# 10/10 [==============================] - 1s 65ms/step - loss: 3.1823e-04 - loss_u1: 3.1551e-04 - loss_u2: 2.7280e-06 - val_err_u1: 0.2328 - val_err_u2: 0.0533
# Epoch 193/500
# 10/10 [==============================] - 1s 57ms/step - loss: 7.6107e-05 - loss_u1: 7.3428e-05 - loss_u2: 2.6795e-06 - val_err_u1: 0.1690 - val_err_u2: 0.0408
# Epoch 194/500
# 10/10 [==============================] - 0s 52ms/step - loss: 3.4219e-05 - loss_u1: 3.1309e-05 - loss_u2: 2.9105e-06 - val_err_u1: 0.0359 - val_err_u2: 0.0530
# Epoch 195/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.0484e-05 - loss_u1: 7.8440e-06 - loss_u2: 2.6403e-06 - val_err_u1: 0.0429 - val_err_u2: 0.0351
# Epoch 196/500
# 10/10 [==============================] - 1s 55ms/step - loss: 7.7613e-06 - loss_u1: 5.0472e-06 - loss_u2: 2.7141e-06 - val_err_u1: 0.0516 - val_err_u2: 0.0460
# Epoch 197/500
# 10/10 [==============================] - 1s 57ms/step - loss: 6.6676e-06 - loss_u1: 4.3177e-06 - loss_u2: 2.3499e-06 - val_err_u1: 0.0392 - val_err_u2: 0.0263
# Epoch 198/500
# 10/10 [==============================] - 1s 55ms/step - loss: 5.0027e-06 - loss_u1: 2.7428e-06 - loss_u2: 2.2599e-06 - val_err_u1: 0.0287 - val_err_u2: 0.0366
# Epoch 199/500
# 10/10 [==============================] - 0s 52ms/step - loss: 3.5979e-06 - loss_u1: 1.7333e-06 - loss_u2: 1.8646e-06 - val_err_u1: 0.0230 - val_err_u2: 0.0176
# Epoch 200/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.0727e-06 - loss_u1: 1.3353e-06 - loss_u2: 1.7374e-06 - val_err_u1: 0.0204 - val_err_u2: 0.0264
# Epoch 201/500
# 10/10 [==============================] - 1s 57ms/step - loss: 2.6263e-06 - loss_u1: 1.2172e-06 - loss_u2: 1.4091e-06 - val_err_u1: 0.0200 - val_err_u2: 0.0167
# Epoch 202/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.5828e-06 - loss_u1: 1.2432e-06 - loss_u2: 1.3397e-06 - val_err_u1: 0.0215 - val_err_u2: 0.0201
# Epoch 203/500
# 10/10 [==============================] - 1s 55ms/step - loss: 2.5704e-06 - loss_u1: 1.3775e-06 - loss_u2: 1.1930e-06 - val_err_u1: 0.0222 - val_err_u2: 0.0216
# Epoch 204/500
# 10/10 [==============================] - 0s 51ms/step - loss: 2.9065e-06 - loss_u1: 1.4887e-06 - loss_u2: 1.4178e-06 - val_err_u1: 0.0218 - val_err_u2: 0.0211
# Epoch 205/500
# 10/10 [==============================] - 1s 53ms/step - loss: 3.4662e-06 - loss_u1: 1.5204e-06 - loss_u2: 1.9458e-06 - val_err_u1: 0.0188 - val_err_u2: 0.0181
# Epoch 206/500
# 10/10 [==============================] - 0s 52ms/step - loss: 5.2657e-06 - loss_u1: 1.3903e-06 - loss_u2: 3.8754e-06 - val_err_u1: 0.0134 - val_err_u2: 0.0229
# Epoch 207/500
# 10/10 [==============================] - 1s 54ms/step - loss: 9.0616e-06 - loss_u1: 1.1125e-06 - loss_u2: 7.9491e-06 - val_err_u1: 0.0072 - val_err_u2: 0.0269
# Epoch 208/500
# 10/10 [==============================] - 0s 53ms/step - loss: 1.6424e-05 - loss_u1: 7.7577e-07 - loss_u2: 1.5648e-05 - val_err_u1: 0.0064 - val_err_u2: 0.0545
# Epoch 209/500
# 10/10 [==============================] - 1s 64ms/step - loss: 2.8259e-05 - loss_u1: 5.3483e-07 - loss_u2: 2.7724e-05 - val_err_u1: 0.0085 - val_err_u2: 0.0779
# Epoch 210/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.6423e-05 - loss_u1: 4.3015e-07 - loss_u2: 4.5993e-05 - val_err_u1: 0.0082 - val_err_u2: 0.0899
# Epoch 211/500
# 10/10 [==============================] - 1s 59ms/step - loss: 7.8652e-05 - loss_u1: 4.0064e-07 - loss_u2: 7.8252e-05 - val_err_u1: 0.0077 - val_err_u2: 0.0994
# Epoch 212/500
# 10/10 [==============================] - 1s 77ms/step - loss: 1.3390e-04 - loss_u1: 4.0089e-07 - loss_u2: 1.3350e-04 - val_err_u1: 0.0083 - val_err_u2: 0.2972
# Epoch 213/500
# 10/10 [==============================] - 1s 89ms/step - loss: 1.5881e-04 - loss_u1: 3.9972e-07 - loss_u2: 1.5841e-04 - val_err_u1: 0.0089 - val_err_u2: 0.5416
# Epoch 214/500
# 10/10 [==============================] - 1s 77ms/step - loss: 8.7979e-05 - loss_u1: 3.8881e-07 - loss_u2: 8.7590e-05 - val_err_u1: 0.0085 - val_err_u2: 0.1038
# Epoch 215/500
# 10/10 [==============================] - 1s 60ms/step - loss: 2.3193e-05 - loss_u1: 3.7911e-07 - loss_u2: 2.2814e-05 - val_err_u1: 0.0088 - val_err_u2: 0.1736
# Epoch 216/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.1867e-05 - loss_u1: 3.7638e-07 - loss_u2: 1.1491e-05 - val_err_u1: 0.0088 - val_err_u2: 0.1604
# Epoch 217/500
# 10/10 [==============================] - 1s 52ms/step - loss: 9.3550e-06 - loss_u1: 3.7281e-07 - loss_u2: 8.9821e-06 - val_err_u1: 0.0084 - val_err_u2: 0.0610
# Epoch 218/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.3827e-06 - loss_u1: 3.6883e-07 - loss_u2: 3.0138e-06 - val_err_u1: 0.0088 - val_err_u2: 0.0487
# Epoch 219/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.5625e-06 - loss_u1: 3.8488e-07 - loss_u2: 2.1776e-06 - val_err_u1: 0.0090 - val_err_u2: 0.0460
# Epoch 220/500
# 10/10 [==============================] - 1s 63ms/step - loss: 3.5845e-06 - loss_u1: 3.7269e-07 - loss_u2: 3.2118e-06 - val_err_u1: 0.0086 - val_err_u2: 0.0604
# Epoch 221/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.4405e-06 - loss_u1: 4.0441e-07 - loss_u2: 3.0361e-06 - val_err_u1: 0.0099 - val_err_u2: 0.0592
# Epoch 222/500
# 10/10 [==============================] - 1s 56ms/step - loss: 3.3915e-06 - loss_u1: 4.3754e-07 - loss_u2: 2.9540e-06 - val_err_u1: 0.0101 - val_err_u2: 0.0669
# Epoch 223/500
# 10/10 [==============================] - 1s 56ms/step - loss: 3.5639e-06 - loss_u1: 4.6273e-07 - loss_u2: 3.1011e-06 - val_err_u1: 0.0110 - val_err_u2: 0.0573
# Epoch 224/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.4403e-06 - loss_u1: 5.9801e-07 - loss_u2: 3.8423e-06 - val_err_u1: 0.0145 - val_err_u2: 0.0739
# Epoch 225/500
# 10/10 [==============================] - 0s 50ms/step - loss: 5.8075e-06 - loss_u1: 1.6915e-06 - loss_u2: 4.1160e-06 - val_err_u1: 0.0313 - val_err_u2: 0.0647
# Epoch 226/500
# 10/10 [==============================] - 1s 58ms/step - loss: 2.5385e-05 - loss_u1: 2.0797e-05 - loss_u2: 4.5876e-06 - val_err_u1: 0.1234 - val_err_u2: 0.0804
# Epoch 227/500
# 10/10 [==============================] - 1s 57ms/step - loss: 2.9753e-04 - loss_u1: 2.9261e-04 - loss_u2: 4.9188e-06 - val_err_u1: 0.1542 - val_err_u2: 0.0708
# Epoch 228/500
# 10/10 [==============================] - 1s 54ms/step - loss: 2.6254e-04 - loss_u1: 2.5680e-04 - loss_u2: 5.7344e-06 - val_err_u1: 0.3423 - val_err_u2: 0.0895
# Epoch 229/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.7927e-04 - loss_u1: 1.7298e-04 - loss_u2: 6.2863e-06 - val_err_u1: 0.3063 - val_err_u2: 0.0813
# Epoch 230/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.0439e-04 - loss_u1: 9.6627e-05 - loss_u2: 7.7595e-06 - val_err_u1: 0.0899 - val_err_u2: 0.1068
# Epoch 231/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.5577e-05 - loss_u1: 2.6424e-05 - loss_u2: 9.1531e-06 - val_err_u1: 0.0927 - val_err_u2: 0.1043
# Epoch 232/500
# 10/10 [==============================] - 1s 58ms/step - loss: 2.5194e-05 - loss_u1: 1.2763e-05 - loss_u2: 1.2431e-05 - val_err_u1: 0.0414 - val_err_u2: 0.1422
# Epoch 233/500
# 10/10 [==============================] - 1s 58ms/step - loss: 2.1736e-05 - loss_u1: 4.5414e-06 - loss_u2: 1.7195e-05 - val_err_u1: 0.0361 - val_err_u2: 0.1603
# Epoch 234/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.0397e-05 - loss_u1: 1.8683e-06 - loss_u2: 2.8529e-05 - val_err_u1: 0.0146 - val_err_u2: 0.2379
# Epoch 235/500
# 10/10 [==============================] - 1s 56ms/step - loss: 5.2805e-05 - loss_u1: 1.1166e-06 - loss_u2: 5.1688e-05 - val_err_u1: 0.0166 - val_err_u2: 0.3304
# Epoch 236/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.0456e-04 - loss_u1: 1.0428e-06 - loss_u2: 1.0352e-04 - val_err_u1: 0.0176 - val_err_u2: 0.5149
# Epoch 237/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.7404e-04 - loss_u1: 8.0021e-07 - loss_u2: 1.7324e-04 - val_err_u1: 0.0063 - val_err_u2: 0.6461
# Epoch 238/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.5276e-04 - loss_u1: 4.3586e-07 - loss_u2: 1.5233e-04 - val_err_u1: 0.0040 - val_err_u2: 0.5134
# Epoch 239/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.1732e-04 - loss_u1: 3.9306e-07 - loss_u2: 1.1693e-04 - val_err_u1: 0.0057 - val_err_u2: 0.4005
# Epoch 240/500
# 10/10 [==============================] - 1s 61ms/step - loss: 7.9109e-05 - loss_u1: 4.3780e-07 - loss_u2: 7.8671e-05 - val_err_u1: 0.0077 - val_err_u2: 0.1957
# Epoch 241/500
# 10/10 [==============================] - 1s 61ms/step - loss: 2.5517e-05 - loss_u1: 5.0602e-07 - loss_u2: 2.5011e-05 - val_err_u1: 0.0101 - val_err_u2: 0.1486
# Epoch 242/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.3999e-05 - loss_u1: 5.6922e-07 - loss_u2: 1.3429e-05 - val_err_u1: 0.0120 - val_err_u2: 0.1603
# Epoch 243/500
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3167e-05 - loss_u1: 6.4933e-07 - loss_u2: 1.2517e-05 - val_err_u1: 0.0135 - val_err_u2: 0.1609
# Epoch 244/500
# 10/10 [==============================] - 1s 54ms/step - loss: 1.1267e-05 - loss_u1: 7.2891e-07 - loss_u2: 1.0538e-05 - val_err_u1: 0.0154 - val_err_u2: 0.1064
# Epoch 245/500
# 10/10 [==============================] - 1s 58ms/step - loss: 7.0018e-06 - loss_u1: 8.3531e-07 - loss_u2: 6.1665e-06 - val_err_u1: 0.0160 - val_err_u2: 0.0866
# Epoch 246/500
# 10/10 [==============================] - 1s 58ms/step - loss: 7.3467e-06 - loss_u1: 9.1245e-07 - loss_u2: 6.4342e-06 - val_err_u1: 0.0162 - val_err_u2: 0.1045
# Epoch 247/500
# 10/10 [==============================] - 1s 57ms/step - loss: 6.7576e-06 - loss_u1: 9.5826e-07 - loss_u2: 5.7994e-06 - val_err_u1: 0.0139 - val_err_u2: 0.0960
# Epoch 248/500
# 10/10 [==============================] - 1s 61ms/step - loss: 6.6284e-06 - loss_u1: 9.0927e-07 - loss_u2: 5.7191e-06 - val_err_u1: 0.0102 - val_err_u2: 0.0942
# Epoch 249/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.5977e-06 - loss_u1: 7.6686e-07 - loss_u2: 3.8308e-06 - val_err_u1: 0.0053 - val_err_u2: 0.0600
# Epoch 250/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.2066e-06 - loss_u1: 5.7903e-07 - loss_u2: 2.6276e-06 - val_err_u1: 0.0055 - val_err_u2: 0.0544
# Epoch 251/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.0048e-06 - loss_u1: 4.2148e-07 - loss_u2: 2.5833e-06 - val_err_u1: 0.0081 - val_err_u2: 0.0569
# Epoch 252/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.4114e-06 - loss_u1: 3.4502e-07 - loss_u2: 2.0663e-06 - val_err_u1: 0.0087 - val_err_u2: 0.0352
# Epoch 253/500
# 10/10 [==============================] - 1s 65ms/step - loss: 2.1798e-06 - loss_u1: 3.1660e-07 - loss_u2: 1.8632e-06 - val_err_u1: 0.0077 - val_err_u2: 0.0218
# Epoch 254/500
# 10/10 [==============================] - 1s 64ms/step - loss: 1.3371e-06 - loss_u1: 3.0683e-07 - loss_u2: 1.0303e-06 - val_err_u1: 0.0077 - val_err_u2: 0.0202
# Epoch 255/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.1604e-06 - loss_u1: 3.0544e-07 - loss_u2: 8.5500e-07 - val_err_u1: 0.0082 - val_err_u2: 0.0131
# Epoch 256/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.2530e-06 - loss_u1: 3.0219e-07 - loss_u2: 9.5078e-07 - val_err_u1: 0.0080 - val_err_u2: 0.0118
# Epoch 257/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.1309e-06 - loss_u1: 2.9821e-07 - loss_u2: 8.3266e-07 - val_err_u1: 0.0077 - val_err_u2: 0.0163
# Epoch 258/500
# 10/10 [==============================] - 1s 60ms/step - loss: 1.1215e-06 - loss_u1: 2.9492e-07 - loss_u2: 8.2658e-07 - val_err_u1: 0.0077 - val_err_u2: 0.0145
# Epoch 259/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.0740e-06 - loss_u1: 2.9413e-07 - loss_u2: 7.7983e-07 - val_err_u1: 0.0074 - val_err_u2: 0.0107
# Epoch 260/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.0908e-06 - loss_u1: 2.9030e-07 - loss_u2: 8.0048e-07 - val_err_u1: 0.0074 - val_err_u2: 0.0118
# Epoch 261/500
# 10/10 [==============================] - 1s 89ms/step - loss: 1.1009e-06 - loss_u1: 2.9328e-07 - loss_u2: 8.0763e-07 - val_err_u1: 0.0073 - val_err_u2: 0.0130
# Epoch 262/500
# 10/10 [==============================] - 1s 84ms/step - loss: 1.0795e-06 - loss_u1: 2.8816e-07 - loss_u2: 7.9134e-07 - val_err_u1: 0.0072 - val_err_u2: 0.0120
# Epoch 263/500
# 10/10 [==============================] - 1s 71ms/step - loss: 1.0656e-06 - loss_u1: 2.9899e-07 - loss_u2: 7.6665e-07 - val_err_u1: 0.0076 - val_err_u2: 0.0113
# Epoch 264/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.0710e-06 - loss_u1: 3.0289e-07 - loss_u2: 7.6815e-07 - val_err_u1: 0.0076 - val_err_u2: 0.0110
# Epoch 265/500
# 10/10 [==============================] - 1s 56ms/step - loss: 1.0871e-06 - loss_u1: 3.1112e-07 - loss_u2: 7.7594e-07 - val_err_u1: 0.0081 - val_err_u2: 0.0112
# Epoch 266/500
# 10/10 [==============================] - 1s 65ms/step - loss: 1.1510e-06 - loss_u1: 3.7070e-07 - loss_u2: 7.8028e-07 - val_err_u1: 0.0104 - val_err_u2: 0.0113
# Epoch 267/500
# 10/10 [==============================] - 1s 69ms/step - loss: 1.5057e-06 - loss_u1: 7.1795e-07 - loss_u2: 7.8773e-07 - val_err_u1: 0.0182 - val_err_u2: 0.0116
# Epoch 268/500
# 10/10 [==============================] - 1s 54ms/step - loss: 4.9500e-06 - loss_u1: 4.1526e-06 - loss_u2: 7.9736e-07 - val_err_u1: 0.0520 - val_err_u2: 0.0117
# Epoch 269/500
# 10/10 [==============================] - 1s 58ms/step - loss: 7.4622e-05 - loss_u1: 7.3814e-05 - loss_u2: 8.0802e-07 - val_err_u1: 0.2043 - val_err_u2: 0.0120
# Epoch 270/500
# 10/10 [==============================] - 1s 63ms/step - loss: 1.8497e-04 - loss_u1: 1.8415e-04 - loss_u2: 8.2152e-07 - val_err_u1: 0.2322 - val_err_u2: 0.0125
# Epoch 271/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3188e-04 - loss_u1: 2.3104e-04 - loss_u2: 8.3584e-07 - val_err_u1: 0.2180 - val_err_u2: 0.0127
# Epoch 272/500
# 10/10 [==============================] - 1s 64ms/step - loss: 6.3066e-05 - loss_u1: 6.2222e-05 - loss_u2: 8.4436e-07 - val_err_u1: 0.1843 - val_err_u2: 0.0144
# Epoch 273/500
# 10/10 [==============================] - 1s 54ms/step - loss: 3.8022e-05 - loss_u1: 3.7187e-05 - loss_u2: 8.3487e-07 - val_err_u1: 0.1217 - val_err_u2: 0.0140
# Epoch 274/500
# 10/10 [==============================] - 1s 52ms/step - loss: 1.9437e-05 - loss_u1: 1.8624e-05 - loss_u2: 8.1241e-07 - val_err_u1: 0.0819 - val_err_u2: 0.0143
# Epoch 275/500
# 10/10 [==============================] - 1s 58ms/step - loss: 9.2474e-06 - loss_u1: 8.4790e-06 - loss_u2: 7.6840e-07 - val_err_u1: 0.0431 - val_err_u2: 0.0117
# Epoch 276/500
# 10/10 [==============================] - 1s 55ms/step - loss: 3.7611e-06 - loss_u1: 3.0052e-06 - loss_u2: 7.5588e-07 - val_err_u1: 0.0175 - val_err_u2: 0.0102
# Epoch 277/500
# 10/10 [==============================] - 1s 54ms/step - loss: 1.8584e-06 - loss_u1: 1.0786e-06 - loss_u2: 7.7983e-07 - val_err_u1: 0.0043 - val_err_u2: 0.0121
# Epoch 278/500
# 10/10 [==============================] - 0s 50ms/step - loss: 1.6776e-06 - loss_u1: 5.2145e-07 - loss_u2: 1.1561e-06 - val_err_u1: 0.0069 - val_err_u2: 0.0222
# ...
# Epoch 409/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.5266e-06 - loss_u1: 2.9587e-07 - loss_u2: 4.2307e-06 - val_err_u1: 0.0100 - val_err_u2: 0.0755
# Epoch 410/500
# 10/10 [==============================] - 1s 66ms/step - loss: 5.6789e-06 - loss_u1: 2.5095e-06 - loss_u2: 3.1694e-06 - val_err_u1: 0.0369 - val_err_u2: 0.0549
# Epoch 411/500
# 10/10 [==============================] - 1s 56ms/step - loss: 4.0807e-05 - loss_u1: 3.8631e-05 - loss_u2: 2.1758e-06 - val_err_u1: 0.1438 - val_err_u2: 0.0408
# Epoch 412/500
# 10/10 [==============================] - 1s 61ms/step - loss: 1.2898e-04 - loss_u1: 1.2777e-04 - loss_u2: 1.2099e-06 - val_err_u1: 0.1632 - val_err_u2: 0.0303
# Epoch 413/500
# 10/10 [==============================] - 1s 59ms/step - loss: 1.7262e-04 - loss_u1: 1.7179e-04 - loss_u2: 8.3774e-07 - val_err_u1: 0.2241 - val_err_u2: 0.0292
# Epoch 414/500
# 10/10 [==============================] - 1s 58ms/step - loss: 7.3585e-05 - loss_u1: 7.2697e-05 - loss_u2: 8.8766e-07 - val_err_u1: 0.1796 - val_err_u2: 0.0181
# Epoch 415/500
# 10/10 [==============================] - 1s 59ms/step - loss: 4.3184e-05 - loss_u1: 4.2716e-05 - loss_u2: 4.6827e-07 - val_err_u1: 0.1380 - val_err_u2: 0.0062
# Epoch 416/500
# 10/10 [==============================] - 1s 58ms/step - loss: 2.3065e-05 - loss_u1: 2.2698e-05 - loss_u2: 3.6744e-07 - val_err_u1: 0.0743 - val_err_u2: 0.0075
# Epoch 417/500
# 10/10 [==============================] - 1s 60ms/step - loss: 8.7286e-06 - loss_u1: 8.3473e-06 - loss_u2: 3.8130e-07 - val_err_u1: 0.0175 - val_err_u2: 0.0065
# Epoch 418/500
# 10/10 [==============================] - 1s 64ms/step - loss: 2.1193e-06 - loss_u1: 1.7802e-06 - loss_u2: 3.3910e-07 - val_err_u1: 0.0179 - val_err_u2: 0.0086
# Epoch 419/500
# 10/10 [==============================] - 1s 60ms/step - loss: 1.0884e-06 - loss_u1: 7.5001e-07 - loss_u2: 3.3836e-07 - val_err_u1: 0.0192 - val_err_u2: 0.0078
# Epoch 420/500
# 10/10 [==============================] - 1s 56ms/step - loss: 8.7927e-07 - loss_u1: 5.4433e-07 - loss_u2: 3.3494e-07 - val_err_u1: 0.0124 - val_err_u2: 0.0062
# Epoch 421/500
# 10/10 [==============================] - 1s 60ms/step - loss: 6.4427e-07 - loss_u1: 3.0728e-07 - loss_u2: 3.3698e-07 - val_err_u1: 0.0050 - val_err_u2: 0.0067
# Epoch 422/500
# 10/10 [==============================] - 1s 65ms/step - loss: 5.0939e-07 - loss_u1: 1.8008e-07 - loss_u2: 3.2931e-07 - val_err_u1: 0.0019 - val_err_u2: 0.0068
# Epoch 423/500
# 10/10 [==============================] - 1s 56ms/step - loss: 4.5649e-07 - loss_u1: 1.3455e-07 - loss_u2: 3.2195e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0065
# Epoch 424/500
# 10/10 [==============================] - 1s 59ms/step - loss: 4.4610e-07 - loss_u1: 1.2949e-07 - loss_u2: 3.1661e-07 - val_err_u1: 0.0036 - val_err_u2: 0.0062
# Epoch 425/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.5047e-07 - loss_u1: 1.3237e-07 - loss_u2: 3.1810e-07 - val_err_u1: 0.0042 - val_err_u2: 0.0061
# Epoch 426/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.5326e-07 - loss_u1: 1.3410e-07 - loss_u2: 3.1916e-07 - val_err_u1: 0.0046 - val_err_u2: 0.0061
# Epoch 427/500
# 10/10 [==============================] - 1s 54ms/step - loss: 4.5525e-07 - loss_u1: 1.3545e-07 - loss_u2: 3.1980e-07 - val_err_u1: 0.0047 - val_err_u2: 0.0060
# Epoch 428/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.5767e-07 - loss_u1: 1.3427e-07 - loss_u2: 3.2340e-07 - val_err_u1: 0.0046 - val_err_u2: 0.0060
# Epoch 429/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.6555e-07 - loss_u1: 1.2989e-07 - loss_u2: 3.3566e-07 - val_err_u1: 0.0042 - val_err_u2: 0.0060
# Epoch 430/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.8728e-07 - loss_u1: 1.2349e-07 - loss_u2: 3.6379e-07 - val_err_u1: 0.0039 - val_err_u2: 0.0059
# Epoch 431/500
# 10/10 [==============================] - 1s 55ms/step - loss: 5.4680e-07 - loss_u1: 1.1786e-07 - loss_u2: 4.2894e-07 - val_err_u1: 0.0037 - val_err_u2: 0.0062
# Epoch 432/500
# 10/10 [==============================] - 1s 65ms/step - loss: 6.8786e-07 - loss_u1: 1.1426e-07 - loss_u2: 5.7360e-07 - val_err_u1: 0.0036 - val_err_u2: 0.0077
# Epoch 433/500
# 10/10 [==============================] - 1s 60ms/step - loss: 9.9076e-07 - loss_u1: 1.1225e-07 - loss_u2: 8.7851e-07 - val_err_u1: 0.0035 - val_err_u2: 0.0121
# Epoch 434/500
# 10/10 [==============================] - 1s 55ms/step - loss: 1.5888e-06 - loss_u1: 1.1074e-07 - loss_u2: 1.4780e-06 - val_err_u1: 0.0034 - val_err_u2: 0.0207
# Epoch 435/500
# 10/10 [==============================] - 1s 73ms/step - loss: 2.6588e-06 - loss_u1: 1.0932e-07 - loss_u2: 2.5494e-06 - val_err_u1: 0.0034 - val_err_u2: 0.0338
# Epoch 436/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.3388e-06 - loss_u1: 1.0822e-07 - loss_u2: 4.2306e-06 - val_err_u1: 0.0033 - val_err_u2: 0.0511
# Epoch 437/500
# 10/10 [==============================] - 1s 58ms/step - loss: 6.6232e-06 - loss_u1: 1.0732e-07 - loss_u2: 6.5159e-06 - val_err_u1: 0.0032 - val_err_u2: 0.0699
# Epoch 438/500
# 10/10 [==============================] - 1s 56ms/step - loss: 9.2815e-06 - loss_u1: 1.0652e-07 - loss_u2: 9.1750e-06 - val_err_u1: 0.0032 - val_err_u2: 0.0876
# Epoch 439/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.2177e-05 - loss_u1: 1.0588e-07 - loss_u2: 1.2071e-05 - val_err_u1: 0.0031 - val_err_u2: 0.1013
# Epoch 440/500
# 10/10 [==============================] - 1s 57ms/step - loss: 1.5363e-05 - loss_u1: 1.0527e-07 - loss_u2: 1.5258e-05 - val_err_u1: 0.0030 - val_err_u2: 0.1118
# Epoch 441/500
# 10/10 [==============================] - 1s 61ms/step - loss: 1.9809e-05 - loss_u1: 1.0482e-07 - loss_u2: 1.9704e-05 - val_err_u1: 0.0030 - val_err_u2: 0.1173
# Epoch 442/500
# 10/10 [==============================] - 1s 60ms/step - loss: 2.6892e-05 - loss_u1: 1.0450e-07 - loss_u2: 2.6787e-05 - val_err_u1: 0.0029 - val_err_u2: 0.1202
# Epoch 443/500
# 10/10 [==============================] - 1s 59ms/step - loss: 4.0579e-05 - loss_u1: 1.0481e-07 - loss_u2: 4.0474e-05 - val_err_u1: 0.0028 - val_err_u2: 0.1042
# Epoch 444/500
# 10/10 [==============================] - 1s 61ms/step - loss: 6.5341e-05 - loss_u1: 1.0654e-07 - loss_u2: 6.5234e-05 - val_err_u1: 0.0028 - val_err_u2: 0.1368
# Epoch 445/500
# 10/10 [==============================] - 1s 58ms/step - loss: 9.1305e-05 - loss_u1: 1.1142e-07 - loss_u2: 9.1194e-05 - val_err_u1: 0.0028 - val_err_u2: 0.3837
# Epoch 446/500
# 10/10 [==============================] - 1s 60ms/step - loss: 7.5089e-05 - loss_u1: 1.1561e-07 - loss_u2: 7.4974e-05 - val_err_u1: 0.0029 - val_err_u2: 0.2415
# Epoch 447/500
# 10/10 [==============================] - 1s 66ms/step - loss: 2.8681e-05 - loss_u1: 1.0805e-07 - loss_u2: 2.8573e-05 - val_err_u1: 0.0027 - val_err_u2: 0.2860
# Epoch 448/500
# 10/10 [==============================] - 1s 71ms/step - loss: 2.9312e-05 - loss_u1: 1.7105e-07 - loss_u2: 2.9141e-05 - val_err_u1: 0.0086 - val_err_u2: 0.1252
# Epoch 449/500
# 10/10 [==============================] - 1s 64ms/step - loss: 2.2338e-05 - loss_u1: 5.8994e-06 - loss_u2: 1.6439e-05 - val_err_u1: 0.0844 - val_err_u2: 0.1667
# Epoch 450/500
# 10/10 [==============================] - 1s 57ms/step - loss: 3.1021e-04 - loss_u1: 2.9756e-04 - loss_u2: 1.2647e-05 - val_err_u1: 0.2269 - val_err_u2: 0.1884
# Epoch 451/500
# 10/10 [==============================] - 1s 59ms/step - loss: 2.1690e-04 - loss_u1: 2.0272e-04 - loss_u2: 1.4184e-05 - val_err_u1: 0.2221 - val_err_u2: 0.0894
# Epoch 452/500
# 10/10 [==============================] - 1s 59ms/step - loss: 8.0901e-05 - loss_u1: 7.2130e-05 - loss_u2: 8.7711e-06 - val_err_u1: 0.1451 - val_err_u2: 0.1107
# Epoch 453/500
# 10/10 [==============================] - 1s 59ms/step - loss: 3.7489e-05 - loss_u1: 3.1830e-05 - loss_u2: 5.6588e-06 - val_err_u1: 0.1118 - val_err_u2: 0.1279
# Epoch 454/500
# 10/10 [==============================] - 1s 66ms/step - loss: 1.6269e-05 - loss_u1: 9.8241e-06 - loss_u2: 6.4445e-06 - val_err_u1: 0.0288 - val_err_u2: 0.0504
# Epoch 455/500
# 10/10 [==============================] - 1s 59ms/step - loss: 8.4200e-06 - loss_u1: 4.1440e-06 - loss_u2: 4.2761e-06 - val_err_u1: 0.0340 - val_err_u2: 0.0952
# Epoch 456/500
# 10/10 [==============================] - 1s 60ms/step - loss: 5.4786e-06 - loss_u1: 2.0329e-06 - loss_u2: 3.4456e-06 - val_err_u1: 0.0203 - val_err_u2: 0.0828
# Epoch 457/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.3645e-06 - loss_u1: 1.2048e-06 - loss_u2: 3.1597e-06 - val_err_u1: 0.0133 - val_err_u2: 0.0350
# Epoch 458/500
# 10/10 [==============================] - 1s 60ms/step - loss: 2.2681e-06 - loss_u1: 4.5970e-07 - loss_u2: 1.8084e-06 - val_err_u1: 0.0073 - val_err_u2: 0.0772
# Epoch 459/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.3264e-06 - loss_u1: 2.5322e-07 - loss_u2: 2.0731e-06 - val_err_u1: 0.0052 - val_err_u2: 0.0229
# Epoch 460/500
# 10/10 [==============================] - 1s 61ms/step - loss: 1.2397e-06 - loss_u1: 1.7565e-07 - loss_u2: 1.0641e-06 - val_err_u1: 0.0053 - val_err_u2: 0.0434
# Epoch 461/500
# 10/10 [==============================] - 1s 74ms/step - loss: 8.0602e-07 - loss_u1: 1.3999e-07 - loss_u2: 6.6603e-07 - val_err_u1: 0.0041 - val_err_u2: 0.0200
# Epoch 462/500
# 10/10 [==============================] - 1s 99ms/step - loss: 7.0846e-07 - loss_u1: 1.3018e-07 - loss_u2: 5.7828e-07 - val_err_u1: 0.0019 - val_err_u2: 0.0191
# Epoch 463/500
# 10/10 [==============================] - 1s 80ms/step - loss: 5.0306e-07 - loss_u1: 1.0898e-07 - loss_u2: 3.9408e-07 - val_err_u1: 0.0018 - val_err_u2: 0.0069
# Epoch 464/500
# 10/10 [==============================] - 1s 64ms/step - loss: 4.0471e-07 - loss_u1: 1.0373e-07 - loss_u2: 3.0098e-07 - val_err_u1: 0.0020 - val_err_u2: 0.0093
# Epoch 465/500
# 10/10 [==============================] - 1s 68ms/step - loss: 3.6488e-07 - loss_u1: 1.0478e-07 - loss_u2: 2.6010e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0071
# Epoch 466/500
# 10/10 [==============================] - 1s 65ms/step - loss: 3.5637e-07 - loss_u1: 1.0541e-07 - loss_u2: 2.5096e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0072
# Epoch 467/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.6186e-07 - loss_u1: 1.0330e-07 - loss_u2: 2.5856e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0063
# Epoch 468/500
# 10/10 [==============================] - 1s 56ms/step - loss: 3.5895e-07 - loss_u1: 1.0180e-07 - loss_u2: 2.5715e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0078
# Epoch 469/500
# 10/10 [==============================] - 1s 66ms/step - loss: 3.6785e-07 - loss_u1: 1.0168e-07 - loss_u2: 2.6617e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0070
# Epoch 470/500
# 10/10 [==============================] - 1s 60ms/step - loss: 3.8069e-07 - loss_u1: 1.0194e-07 - loss_u2: 2.7875e-07 - val_err_u1: 0.0026 - val_err_u2: 0.0082
# Epoch 471/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.1714e-07 - loss_u1: 1.0249e-07 - loss_u2: 3.1464e-07 - val_err_u1: 0.0027 - val_err_u2: 0.0072
# Epoch 472/500
# 10/10 [==============================] - 1s 57ms/step - loss: 5.0278e-07 - loss_u1: 1.0306e-07 - loss_u2: 3.9972e-07 - val_err_u1: 0.0027 - val_err_u2: 0.0078
# Epoch 473/500
# 10/10 [==============================] - 1s 60ms/step - loss: 7.0228e-07 - loss_u1: 1.0290e-07 - loss_u2: 5.9938e-07 - val_err_u1: 0.0025 - val_err_u2: 0.0087
# Epoch 474/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.1596e-06 - loss_u1: 1.0142e-07 - loss_u2: 1.0582e-06 - val_err_u1: 0.0023 - val_err_u2: 0.0085
# Epoch 475/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.0221e-06 - loss_u1: 9.8263e-08 - loss_u2: 1.9238e-06 - val_err_u1: 0.0021 - val_err_u2: 0.0241
# Epoch 476/500
# 10/10 [==============================] - 1s 58ms/step - loss: 3.8020e-06 - loss_u1: 9.4339e-08 - loss_u2: 3.7077e-06 - val_err_u1: 0.0023 - val_err_u2: 0.0274
# Epoch 477/500
# 10/10 [==============================] - 1s 63ms/step - loss: 6.0835e-06 - loss_u1: 9.0781e-08 - loss_u2: 5.9927e-06 - val_err_u1: 0.0024 - val_err_u2: 0.0631
# Epoch 478/500
# 10/10 [==============================] - 1s 62ms/step - loss: 1.0864e-05 - loss_u1: 8.9122e-08 - loss_u2: 1.0775e-05 - val_err_u1: 0.0024 - val_err_u2: 0.0556
# Epoch 479/500
# 10/10 [==============================] - 1s 61ms/step - loss: 1.4758e-05 - loss_u1: 8.7934e-08 - loss_u2: 1.4670e-05 - val_err_u1: 0.0023 - val_err_u2: 0.1199
# Epoch 480/500
# 10/10 [==============================] - 1s 63ms/step - loss: 2.7860e-05 - loss_u1: 8.8736e-08 - loss_u2: 2.7771e-05 - val_err_u1: 0.0023 - val_err_u2: 0.0476
# Epoch 481/500
# 10/10 [==============================] - 1s 60ms/step - loss: 4.4610e-05 - loss_u1: 8.8750e-08 - loss_u2: 4.4521e-05 - val_err_u1: 0.0024 - val_err_u2: 0.2124
# Epoch 482/500
# 10/10 [==============================] - 1s 57ms/step - loss: 7.9563e-05 - loss_u1: 9.5316e-08 - loss_u2: 7.9468e-05 - val_err_u1: 0.0024 - val_err_u2: 0.2840
# Epoch 483/500
# 10/10 [==============================] - 1s 57ms/step - loss: 8.8640e-05 - loss_u1: 9.6906e-08 - loss_u2: 8.8543e-05 - val_err_u1: 0.0025 - val_err_u2: 0.2950
# Epoch 484/500
# 10/10 [==============================] - 1s 58ms/step - loss: 4.1425e-05 - loss_u1: 9.8584e-08 - loss_u2: 4.1326e-05 - val_err_u1: 0.0029 - val_err_u2: 0.2340
# Epoch 485/500
# 10/10 [==============================] - 1s 54ms/step - loss: 2.7182e-05 - loss_u1: 9.4078e-08 - loss_u2: 2.7088e-05 - val_err_u1: 0.0023 - val_err_u2: 0.2777
# Epoch 486/500
# 10/10 [==============================] - 1s 56ms/step - loss: 2.8010e-05 - loss_u1: 8.9365e-08 - loss_u2: 2.7920e-05 - val_err_u1: 0.0033 - val_err_u2: 0.0983
# Epoch 487/500
# 10/10 [==============================] - 0s 53ms/step - loss: 1.7250e-05 - loss_u1: 9.0896e-08 - loss_u2: 1.7159e-05 - val_err_u1: 0.0029 - val_err_u2: 0.1929
# Epoch 488/500
# 10/10 [==============================] - 1s 66ms/step - loss: 1.4580e-05 - loss_u1: 8.6392e-08 - loss_u2: 1.4494e-05 - val_err_u1: 0.0028 - val_err_u2: 0.2037
# Epoch 489/500
# 10/10 [==============================] - 1s 63ms/step - loss: 1.5066e-05 - loss_u1: 9.3056e-08 - loss_u2: 1.4973e-05 - val_err_u1: 0.0035 - val_err_u2: 0.0859
# Epoch 490/500
# 10/10 [==============================] - 1s 62ms/step - loss: 9.0571e-06 - loss_u1: 9.2378e-08 - loss_u2: 8.9647e-06 - val_err_u1: 0.0036 - val_err_u2: 0.1448
# Epoch 491/500
# 10/10 [==============================] - 1s 65ms/step - loss: 7.9001e-06 - loss_u1: 8.5635e-08 - loss_u2: 7.8144e-06 - val_err_u1: 0.0030 - val_err_u2: 0.1364
# Epoch 492/500
# 10/10 [==============================] - 1s 67ms/step - loss: 7.5427e-06 - loss_u1: 8.6453e-08 - loss_u2: 7.4562e-06 - val_err_u1: 0.0041 - val_err_u2: 0.0503
# Epoch 493/500
# 10/10 [==============================] - 1s 57ms/step - loss: 4.7269e-06 - loss_u1: 2.5663e-07 - loss_u2: 4.4703e-06 - val_err_u1: 0.0105 - val_err_u2: 0.1214
# Epoch 494/500
# 10/10 [==============================] - 1s 62ms/step - loss: 6.8396e-06 - loss_u1: 2.0265e-06 - loss_u2: 4.8131e-06 - val_err_u1: 0.0356 - val_err_u2: 0.0775
# Epoch 495/500
# 10/10 [==============================] - 1s 65ms/step - loss: 4.1377e-05 - loss_u1: 3.7967e-05 - loss_u2: 3.4102e-06 - val_err_u1: 0.1497 - val_err_u2: 0.0527
# Epoch 496/500
# 10/10 [==============================] - 1s 105ms/step - loss: 1.1186e-04 - loss_u1: 1.1001e-04 - loss_u2: 1.8498e-06 - val_err_u1: 0.1372 - val_err_u2: 0.0783
# Epoch 497/500
# 10/10 [==============================] - 1s 98ms/step - loss: 1.1291e-04 - loss_u1: 1.1070e-04 - loss_u2: 2.2027e-06 - val_err_u1: 0.1978 - val_err_u2: 0.0137
# Epoch 498/500
# 10/10 [==============================] - 1s 55ms/step - loss: 4.2737e-05 - loss_u1: 4.1879e-05 - loss_u2: 8.5809e-07 - val_err_u1: 0.1360 - val_err_u2: 0.0421
# Epoch 499/500
# 10/10 [==============================] - 1s 62ms/step - loss: 2.5597e-05 - loss_u1: 2.4984e-05 - loss_u2: 6.1276e-07 - val_err_u1: 0.1244 - val_err_u2: 0.0086
# Epoch 500/500
# 10/10 [==============================] - 1s 58ms/step - loss: 1.7611e-05 - loss_u1: 1.7232e-05 - loss_u2: 3.7871e-07 - val_err_u1: 0.1044 - val_err_u2: 0.0173

# %%
saw_couple_model.save_weights("./ModelData/cBurgers_eg2/weights")

# %%
saw_couple_model.load_weights("./ModelData/cBurgers_eg2/weights")

# %%
func = function_factory(saw_couple_model,X_u1_train,u1_train,X_u2_train,u2_train,X_f_train )

# %%
params_1d = tf.dynamic_stitch(func.idx, saw_couple_model.trainable_variables[:])
## L-BFGS 优化阶段
max_iterations = 1000
results = tfp.optimizer.lbfgs_minimize(
    value_and_gradients_function=func,
    initial_position=params_1d, 
    num_correction_pairs=20, 
    x_tolerance = 0,
    f_relative_tolerance = 0,
    tolerance = 1*np.finfo(float).eps,
    parallel_iterations = 1,
    max_line_search_iterations = 100,
    max_iterations=max_iterations)
# Out:
# num_objective_evaluations: 50 loss: 3.9021805787566647e-07
# num_objective_evaluations: 100 loss: 3.185846559593703e-07
# num_objective_evaluations: 150 loss: 2.9485079222662561e-07
# num_objective_evaluations: 200 loss: 2.7701039826770744e-07
# num_objective_evaluations: 250 loss: 2.6112599696232164e-07
# num_objective_evaluations: 300 loss: 2.5326196751292564e-07
# num_objective_evaluations: 350 loss: 2.4591873495654645e-07
# num_objective_evaluations: 400 loss: 2.2817846233414076e-07
# num_objective_evaluations: 450 loss: 2.1731160598465286e-07
# num_objective_evaluations: 500 loss: 2.0984864495915461e-07
# num_objective_evaluations: 550 loss: 2.0341782127283973e-07
# num_objective_evaluations: 600 loss: 2.0030332868312221e-07
# num_objective_evaluations: 650 loss: 1.9672184919102807e-07
# num_objective_evaluations: 700 loss: 1.832735711268983e-07
# num_objective_evaluations: 750 loss: 1.803216454350303e-07
# num_objective_evaluations: 800 loss: 1.7608892730555849e-07
# num_objective_evaluations: 850 loss: 1.7364865234828484e-07
# num_objective_evaluations: 900 loss: 1.6454154871199871e-07
# num_objective_evaluations: 950 loss: 1.4766496013647613e-07
# num_objective_evaluations: 1000 loss: 1.3894622636649038e-07
# num_objective_evaluations: 1050 loss: 1.2895891825837851e-07
# num_objective_evaluations: 1100 loss: 1.2447482889014385e-07
# num_objective_evaluations: 1150 loss: 1.2097194036205005e-07
# num_objective_evaluations: 1200 loss: 1.1788316501010438e-07
# num_objective_evaluations: 1250 loss: 1.1483462501423944e-07
# num_objective_evaluations: 1300 loss: 1.11067964158186e-07
# num_objective_evaluations: 1350 loss: 1.0625880862814851e-07
# num_objective_evaluations: 1400 loss: 9.8448391734130719e-08
# num_objective_evaluations: 1450 loss: 9.7131368595470365e-08
# num_objective_evaluations: 1500 loss: 9.5723136392068688e-08
# num_objective_evaluations: 1550 loss: 9.2840132081039274e-08
# num_objective_evaluations: 1600 loss: 9.1235336221863165e-08
# num_objective_evaluations: 1650 loss: 8.8706912411238572e-08
# num_objective_evaluations: 1700 loss: 8.7745866389059081e-08
# num_objective_evaluations: 1750 loss: 8.319878355983913e-08
# num_objective_evaluations: 1800 loss: 7.9199191004184433e-08
# num_objective_evaluations: 1850 loss: 7.8388163695936758e-08
# num_objective_evaluations: 1900 loss: 7.6848356532489772e-08
# num_objective_evaluations: 1950 loss: 7.49504267170756e-08
# num_objective_evaluations: 2000 loss: 7.2108711386403551e-08
# num_objective_evaluations: 2050 loss: 7.0689271324153628e-08
# num_objective_evaluations: 2100 loss: 6.9275987539372419e-08
# num_objective_evaluations: 2150 loss: 6.7938238888080017e-08
# num_objective_evaluations: 2200 loss: 6.6790744023050986e-08
# num_objective_evaluations: 2250 loss: 6.5318987644472717e-08
# num_objective_evaluations: 2300 loss: 6.4213535826548914e-08
# num_objective_evaluations: 2350 loss: 6.3097588122554856e-08
# num_objective_evaluations: 2400 loss: 6.2287449963668545e-08
# num_objective_evaluations: 2450 loss: 6.187915497122653e-08
# num_objective_evaluations: 2500 loss: 6.0556101548877891e-08
# num_objective_evaluations: 2550 loss: 5.9638689883525078e-08
# num_objective_evaluations: 2600 loss: 5.9272597841068133e-08
# num_objective_evaluations: 2650 loss: 5.7467321796212844e-08
# num_objective_evaluations: 2700 loss: 5.5783567656803948e-08
# num_objective_evaluations: 2750 loss: 5.4203538089265254e-08
# num_objective_evaluations: 2800 loss: 5.342834141688676e-08
# num_objective_evaluations: 2850 loss: 5.2872282074898103e-08
# num_objective_evaluations: 2900 loss: 5.1618379797442508e-08
# num_objective_evaluations: 2950 loss: 5.0613871760732851e-08

# %%
err_u1,err_u2=saw_couple_model.evaluate(ds_test)
# Out:
# 1/1 [==============================] - 0s 248ms/step - err_u1: 0.0015 - err_u2: 0.0030

# %% [markdown]
# # Plotting

# %%
""" Plot Data """
N = 100
X_u1,T_u1,U1 = plot_real_data(N,omga1,u1)
X_u2,T_u2,U2 = plot_real_data(N,omga2,u2)

U1_pred = plot_pred_data(X_u1,T_u1,model_u1)
U2_pred = plot_pred_data(X_u2,T_u2,model_u2)

# %%
f = plt.figure(figsize=(12,10))
ax = f.add_subplot(211)
l1, = ax.plot(X_u1[-1,:],U1[-1,:],'b')
l2, = ax.plot(X_u1[-1,:],U1_pred[-1,:],'r--')
ax.set_xlabel('$x$',size=20)
ax.set_ylabel('$u1$',size=20)

ax.legend(handles=[l1,l2],labels=["$Exact \ u_1$","$Pred \ u_1$"])
ax.text(-10.,0.04,'$This \ is \ u_1(x,1). \ err\_rate={:.4f}$'.format(err_u1),fontdict={'size':20,'color':'g'})

ax = f.add_subplot(212)
l1, = ax.plot(X_u2[-1,:],U2[-1,:],'b')
l2, = ax.plot(X_u2[-1,:],U2_pred[-1,:],'r--')
ax.set_xlabel('$x$',size=20)
ax.set_ylabel('$u2$',size=20)

ax.legend(handles=[l1,l2],labels=["$Exact \ u_2$","$Pred \ u_2$"])
ax.text(-10,0.025,'$This \ is \ u_2(x,1). \ err\_rate={:.4f}$'.format(err_u2),fontdict={'size':20,'color':'g'})

f.savefig("2d_cBurgers_eg2.png")

# %%
####################################################
fig1=plt.figure(figsize=(12, 4)) 
fig1.suptitle("Real U")
ax11 = fig1.add_subplot(121,projection='3d')
ax11.plot_surface(X_u1,T_u1,U1,alpha=0.8,cmap='summer')


ax12 = fig1.add_subplot(122,projection='3d')
ax12.plot_surface(X_u2,T_u2,U2,alpha=0.9,cmap='winter')

ax11.set_xlabel("X")   
ax11.set_ylabel("T")
ax11.set_zlabel("U1",color='r')


ax12.set_xlabel("X")   
ax12.set_ylabel("T")
ax12.set_zlabel("U2",color='r')

plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
fig1.savefig("2d_cBurgers_eg2_surface_real.png")
###################################################### 
fig2 = plt.figure(figsize=(12, 4)) 
fig2.suptitle("Predict U")
ax21 = fig2.add_subplot(121,projection="3d")
ax22 = fig2.add_subplot(122,projection="3d")

### u1
ax21.plot_surface(X_u1,T_u1,U1_pred,alpha=0.9,cmap='summer')
ax21.set_xlabel("X")   
ax21.set_ylabel("T")
ax21.set_zlabel("U1",color='r')


### u2
ax22.plot_surface(X_u2,T_u2,U2_pred,alpha=0.9,cmap='winter')

ax22.set_xlabel("X")   
ax22.set_ylabel("T")
ax22.set_zlabel("U2",color='r',rotation='horizontal')

plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
fig2.savefig("2d_cBurgers_eg2_surface_pred.png")
###############################

plt.show()

# %% [markdown]
# # Save Model

# %%
saw_couple_model.save_weights("./ModelData/cBurgers_eg2/weights")
